# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import statsmodels.api as smi
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from statistics import mean
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, SimpleRNN, GRU, Dropout, Conv1D, MaxPooling1D, Flatten, RepeatVector
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_percentage_error, mean_absolute_error
from tensorflow.keras.optimizers import Adam, Nadam, RMSprop
from statsmodels.tsa.seasonal import seasonal_decompose
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from hyperopt import hp, Trials, fmin, tpe
import joblib
import warnings
warnings.simplefilter('ignore')

# %%
df=pd.read_csv(r'E:\A aPython Programms\Data1\Bank.csv')
df.tail(5)
# Out:
#             Date     AXISBANK   AXISVOL     BAJAJFIN  BAJAJFINVOL         BOB  \
# 3748  21-03-2024  1035.599976   9903738  6715.750000      1806092  255.699997
# 3749  22-03-2024  1033.300049   9891194  6760.899902      1125238  259.799988
# 3750  26-03-2024  1040.550049   9656767  6910.100098      1850321  261.549988
# 3751  27-03-2024  1052.849976  17027308  7022.750000      1551275  258.750000
# 3752  28-03-2024  1047.199951  10235318  7245.250000      3574518  264.049988
#
#         BOBVOL     FEDBANK    FEDVOL         HDFC  ...        KOTAK  KOTAKVOL  \
# 3748  10121220  149.949997   6212045  1445.750000  ...  1772.150024   3783681
# 3749  11402546  149.600006   8409218  1442.849976  ...  1776.400024   7061283
# 3750   8259347  149.800003   7742995  1425.400024  ...  1753.699951   5303630
# 3751  19196992  149.800003  20853016  1440.699951  ...  1775.599976   8231130
# 3752  11966752  150.199997   7208707  1447.900024  ...  1785.500000   6630072
#
#              PNB    PNBVOL         SBI    SBIVOL         REC    RECVOL  \
# 3748  121.050003  38099730  744.299988  15161161  450.250000  18429233
# 3749  122.750000  35001868  746.700012  15535921  460.100006  12531582
# 3750  123.949997  30860596  740.049988  14678342  461.399994  10475524
# 3751  122.750000  42673023  733.299988  30088789  445.600006  28138339
# 3752  124.400002  29453142  752.349976  21705116  451.000000  12637899
#
#          PIRAMAL  PIRAMALVOL
# 3748  841.599976      987716
# 3749  861.500000     1618543
# 3750  858.250000     1391794
# 3751  840.200012     1344329
# 3752  849.349976     5261416
#
# [5 rows x 25 columns]

# %%
feature_columns = ['FEDBANK', 'FEDVOL']
target_column = ['FEDBANK']
features = df[feature_columns]
target = df[target_column].shift(-5)

new_data1 = 152.35
target.iloc[-5, 0] = new_data1

new_data2 = 154.05
target.iloc[-4, 0] = new_data2

new_data3 = 154.50
target.iloc[-3, 0] = new_data3

new_data4 = 152.45
target.iloc[-2, 0] = new_data4

new_data5 = 154.55
target.iloc[-1, 0] = new_data5

target.tail(5)
# Out:
#       FEDBANK
# 3748   152.35
# 3749   154.05
# 3750   154.50
# 3751   152.45
# 3752   154.55

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_features = scaler.fit_transform(features)
scaled_target = scaler.fit_transform(target.values.reshape(-1, 1))

n_steps = 5  # Number of timesteps to look back
X, y = [], []

for i in range(n_steps, len(scaled_features)):
    X.append(scaled_features[i-n_steps:i])
    y.append(scaled_target[i])

X = np.array(X)
y = np.array(y)

split=int(0.8*len(X))
X_train, y_train= X[:split], y[:split]
X_test, y_test= X[split:], y[split:]

# %%
model_lstm = load_model('model_lstm_fed5_0.9646.keras')
model_lstm.predict(X_test)

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae_n=mean_absolute_error(y_test, predictions_lstm)
print(f"MAE_normalizeddata: {mae_n:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# R2: 0.9646
# MAPE: 0.0338
# RMSE: 4.7474
# RMSE_normalizeddata: 0.0310
# MAE_normalizeddata: 0.0244
# MAE: 3.7261

# %%
plt.figure(figsize=(9, 6))
plt.plot(y_test_actual_LSTM, color='green', label=['Actual Price'])
plt.plot(predictions_LSTM, color='red', label=['Predicted Price'])
plt.legend(['Actual Price', 'Predicted Price'], loc='upper left')

plt.text(0.75, 0.1, f'R2: {r2:.4f}\nMAPE: {mape:.4f}%\nRMSE: {rmse:.4f}\nMAE: {mae:.4f}', 
         fontsize=12, 
         bbox=dict(facecolor='white', alpha=0.5),
         transform=plt.gca().transAxes)

plt.grid(True)
plt.title('FEDBANK single model (5 step ahead)')
plt.xlabel('Time Step')
plt.ylabel('Actual vs Predicted Price')
plt.savefig('fed_5sa1l.png', dpi=600)  # Saves the plot as a PNG file
plt.show()

# %%
model_lstm.predict(X_train)

predictions_train_lstm = model_lstm.predict(X_train)
predictions_train_LSTM = scaler.inverse_transform(predictions_train_lstm)
y_train_actual_LSTM = scaler.inverse_transform(y_train.reshape(-1, 1))

r2=r2_score(y_train_actual_LSTM, predictions_train_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_train_actual_LSTM, predictions_train_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_train_actual_LSTM, predictions_train_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_train, predictions_train_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae_n=mean_absolute_error(y_train, predictions_train_lstm)
print(f"MAE_normalizeddata: {mae_n:.4f}")

mae=mean_absolute_error(y_train_actual_LSTM, predictions_train_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# R2: 0.9766
# MAPE: 0.0521
# RMSE: 3.9500
# RMSE_normalizeddata: 0.0258
# MAE_normalizeddata: 0.0185
# MAE: 2.8332

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(169, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.00398), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=30, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 12s 21ms/step - loss: 0.0122 - val_loss: 0.0012
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.9006e-04 - val_loss: 0.0020
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.3820e-04 - val_loss: 0.0014
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.0382e-04 - val_loss: 0.0020
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.1913e-04 - val_loss: 0.0018
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.3062e-04 - val_loss: 0.0015
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.1683e-04 - val_loss: 0.0015
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.4879e-04 - val_loss: 0.0015
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 7.6271e-04 - val_loss: 0.0019
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.8200e-04 - val_loss: 0.0015
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.9618e-04 - val_loss: 0.0018
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.3890e-04 - val_loss: 0.0021
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.8570e-04 - val_loss: 0.0014
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.4210e-04 - val_loss: 0.0028
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.1088e-04 - val_loss: 0.0017
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.8095e-04 - val_loss: 0.0022
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.7803e-04 - val_loss: 0.0016
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 6.2774e-04 - val_loss: 0.0033
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.0456e-04 - val_loss: 0.0019
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.6334e-04 - val_loss: 0.0016
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.4006e-04 - val_loss: 0.0017
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# R2: 0.9371
# MAPE: 0.0427
# RMSE: 6.3258
# RMSE_normalizeddata: 0.0414
# MAE: 5.0616

# %%
model_lstm.save(f"model_lstm_fedbk5h_{r2:.4f}.keras")

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(169, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.00398), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=30, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 0.0108 - val_loss: 0.0047
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 7.9127e-04 - val_loss: 0.0085
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.8689e-04 - val_loss: 0.0082
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.7897e-04 - val_loss: 0.0016
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 7.4185e-04 - val_loss: 0.0032
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 7.6988e-04 - val_loss: 0.0048
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.1739e-04 - val_loss: 0.0022
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 6.2725e-04 - val_loss: 0.0046
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 6.5260e-04 - val_loss: 0.0019
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 6.0473e-04 - val_loss: 0.0031
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 6.3196e-04 - val_loss: 0.0095
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 6.8050e-04 - val_loss: 0.0027
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 6.4475e-04 - val_loss: 0.0057
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 6.6955e-04 - val_loss: 0.0029
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 5.9487e-04 - val_loss: 0.0031
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 5.5022e-04 - val_loss: 0.0031
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.7144e-04 - val_loss: 0.0026
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 5.7024e-04 - val_loss: 0.0023
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 5.7342e-04 - val_loss: 0.0022
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 5.9769e-04 - val_loss: 0.0028
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 5.8268e-04 - val_loss: 0.0032
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 5.6423e-04 - val_loss: 0.0023
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 5.6050e-04 - val_loss: 0.0039
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 5.4564e-04 - val_loss: 0.0037
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 5.6595e-04 - val_loss: 0.0035
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.5060e-04 - val_loss: 0.0030
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.3816e-04 - val_loss: 0.0033
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.5509e-04 - val_loss: 0.0018
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.5609e-04 - val_loss: 0.0064
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.2326e-04 - val_loss: 0.0041
# Epoch 31/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.3207e-04 - val_loss: 0.0047
# Epoch 32/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.0656e-04 - val_loss: 0.0017
# Epoch 33/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.8362e-04 - val_loss: 0.0039
# Epoch 34/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.1848e-04 - val_loss: 0.0021
# Epoch 35/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.0877e-04 - val_loss: 0.0015
# Epoch 36/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.0197e-04 - val_loss: 0.0024
# Epoch 37/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.1983e-04 - val_loss: 0.0024
# Epoch 38/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.4571e-04 - val_loss: 0.0042
# Epoch 39/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.3303e-04 - val_loss: 0.0032
# Epoch 40/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.1136e-04 - val_loss: 0.0020
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step
# R2: 0.9282
# MAPE: 0.0457
# RMSE: 6.7584
# RMSE_normalizeddata: 0.0442
# MAE: 5.4335

# %%
model_lstm.save(f"model_lstm_fedbk5h_{r2:.4f}.keras")

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(169, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.00398), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=30, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 23ms/step - loss: 0.0118 - val_loss: 0.0014
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 7.9240e-04 - val_loss: 0.0021
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 7.6001e-04 - val_loss: 0.0013
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 7.2615e-04 - val_loss: 0.0018
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 7.3989e-04 - val_loss: 0.0018
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.8057e-04 - val_loss: 0.0014
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.5288e-04 - val_loss: 0.0013
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 6.5938e-04 - val_loss: 0.0025
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 6.3850e-04 - val_loss: 0.0013
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 6.4281e-04 - val_loss: 0.0033
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 6.0396e-04 - val_loss: 0.0025
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 5.7930e-04 - val_loss: 0.0044
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 6.7312e-04 - val_loss: 0.0015
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 5.7243e-04 - val_loss: 0.0024
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 5.8157e-04 - val_loss: 0.0033
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 6.2841e-04 - val_loss: 0.0057
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 6.6127e-04 - val_loss: 0.0015
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.8566e-04 - val_loss: 0.0016
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 5.6390e-04 - val_loss: 0.0022
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 5.8251e-04 - val_loss: 0.0023
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.9250e-04 - val_loss: 0.0016
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.5708e-04 - val_loss: 0.0020
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.2462e-04 - val_loss: 0.0030
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.0426e-04 - val_loss: 0.0022
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.7869e-04 - val_loss: 0.0015
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.3361e-04 - val_loss: 0.0013
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.9359e-04 - val_loss: 0.0032
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.5484e-04 - val_loss: 0.0034
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.6749e-04 - val_loss: 0.0022
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.1977e-04 - val_loss: 0.0044
# Epoch 31/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.6755e-04 - val_loss: 0.0020
# Epoch 32/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.6359e-04 - val_loss: 0.0018
# Epoch 33/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.1620e-04 - val_loss: 0.0022
# Epoch 34/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.4289e-04 - val_loss: 0.0018
# Epoch 35/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 5.8930e-04 - val_loss: 0.0022
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step
# R2: 0.9185
# MAPE: 0.0495
# RMSE: 7.2025
# RMSE_normalizeddata: 0.0471
# MAE: 5.8486

# %%
model_lstm.save(f"model_lstm_fedbk5h_{r2:.4f}.keras")

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(169, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.00398), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=30, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 18s 24ms/step - loss: 0.0146 - val_loss: 0.0013
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 7.5195e-04 - val_loss: 0.0026
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 6.9830e-04 - val_loss: 0.0021
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 6.5555e-04 - val_loss: 0.0014
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 7.9279e-04 - val_loss: 0.0064
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 6.6856e-04 - val_loss: 0.0020
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.0951e-04 - val_loss: 0.0032
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.6794e-04 - val_loss: 0.0018
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 6.2558e-04 - val_loss: 0.0020
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.1182e-04 - val_loss: 0.0016
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 6.4842e-04 - val_loss: 0.0022
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 5.8453e-04 - val_loss: 0.0025
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 6.7427e-04 - val_loss: 0.0025
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.1567e-04 - val_loss: 0.0020
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.0446e-04 - val_loss: 0.0033
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.5857e-04 - val_loss: 0.0022
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.0842e-04 - val_loss: 0.0014
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.8309e-04 - val_loss: 0.0016
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.8563e-04 - val_loss: 0.0049
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.8283e-04 - val_loss: 0.0021
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.8317e-04 - val_loss: 0.0038
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.7247e-04 - val_loss: 0.0032
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.9140e-04 - val_loss: 0.0016
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.0545e-04 - val_loss: 0.0036
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.8233e-04 - val_loss: 0.0024
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.8680e-04 - val_loss: 0.0028
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.3011e-04 - val_loss: 0.0024
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.8962e-04 - val_loss: 0.0032
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.6549e-04 - val_loss: 0.0023
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.3759e-04 - val_loss: 0.0023
# Epoch 31/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.2258e-04 - val_loss: 0.0023
# Epoch 32/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.2117e-04 - val_loss: 0.0031
# Epoch 33/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.2834e-04 - val_loss: 0.0045
# Epoch 34/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.7508e-04 - val_loss: 0.0023
# Epoch 35/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.2078e-04 - val_loss: 0.0028
# Epoch 36/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.8855e-04 - val_loss: 0.0016
# Epoch 37/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.3758e-04 - val_loss: 0.0018
# Epoch 38/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.7202e-04 - val_loss: 0.0037
# Epoch 39/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.6966e-04 - val_loss: 0.0019
# Epoch 40/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.0786e-04 - val_loss: 0.0031
# Epoch 41/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.6858e-04 - val_loss: 0.0031
# Epoch 42/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 4.7207e-04 - val_loss: 0.0017
# Epoch 43/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.0429e-04 - val_loss: 0.0033
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step
# R2: 0.8791
# MAPE: 0.0590
# RMSE: 8.7706
# RMSE_normalizeddata: 0.0574
# MAE: 7.2139

# %%
model_lstm.save(f"model_lstm_fedbk5h_{r2:.4f}.keras")

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(169, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.00398), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=30, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 20s 34ms/step - loss: 0.0162 - val_loss: 0.0012
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 7.7176e-04 - val_loss: 0.0033
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 7.6463e-04 - val_loss: 0.0012
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 6.8535e-04 - val_loss: 0.0011
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.8712e-04 - val_loss: 0.0038
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 7.4025e-04 - val_loss: 0.0019
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.7068e-04 - val_loss: 0.0033
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.3019e-04 - val_loss: 0.0047
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.7013e-04 - val_loss: 0.0030
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.4051e-04 - val_loss: 0.0014
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.2260e-04 - val_loss: 0.0011
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.1144e-04 - val_loss: 0.0013
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.3769e-04 - val_loss: 0.0018
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.0262e-04 - val_loss: 0.0021
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.0266e-04 - val_loss: 0.0014
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.2018e-04 - val_loss: 0.0032
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 5.2295e-04 - val_loss: 0.0017
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.7222e-04 - val_loss: 0.0043
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.3190e-04 - val_loss: 0.0016
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.8484e-04 - val_loss: 0.0025
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.3245e-04 - val_loss: 0.0025
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.2346e-04 - val_loss: 0.0014
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.5315e-04 - val_loss: 0.0013
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.4863e-04 - val_loss: 0.0081
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.1475e-04 - val_loss: 0.0030
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.2758e-04 - val_loss: 0.0026
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.7796e-04 - val_loss: 0.0013
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.8351e-04 - val_loss: 0.0019
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.7835e-04 - val_loss: 0.0038
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step
# R2: 0.8612
# MAPE: 0.0625
# RMSE: 9.3984
# RMSE_normalizeddata: 0.0615
# MAE: 7.7383

# %%
model_lstm.save(f"model_lstm_fedbk5h_{r2:.4f}.keras")

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(169, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.00398), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=30, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 17s 30ms/step - loss: 0.0194 - val_loss: 0.0015
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 7.4410e-04 - val_loss: 0.0017
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 7.9225e-04 - val_loss: 0.0037
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 7.5422e-04 - val_loss: 0.0017
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.4867e-04 - val_loss: 0.0013
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.2087e-04 - val_loss: 0.0033
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 7.4496e-04 - val_loss: 0.0025
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 6.6469e-04 - val_loss: 0.0012
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 6.2669e-04 - val_loss: 0.0018
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.2342e-04 - val_loss: 0.0014
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 6.6775e-04 - val_loss: 0.0015
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.5912e-04 - val_loss: 0.0024
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.6662e-04 - val_loss: 0.0057
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.1993e-04 - val_loss: 0.0030
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 7.0824e-04 - val_loss: 0.0041
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.5950e-04 - val_loss: 0.0017
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.7069e-04 - val_loss: 0.0023
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.6911e-04 - val_loss: 0.0027
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.9024e-04 - val_loss: 0.0054
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.9099e-04 - val_loss: 0.0042
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.5194e-04 - val_loss: 0.0018
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.5449e-04 - val_loss: 0.0034
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.0755e-04 - val_loss: 0.0039
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.2503e-04 - val_loss: 0.0022
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.6488e-04 - val_loss: 0.0025
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 5.9193e-04 - val_loss: 0.0031
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.1298e-04 - val_loss: 0.0038
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 5.6119e-04 - val_loss: 0.0022
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 5.7027e-04 - val_loss: 0.0033
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 5.3579e-04 - val_loss: 0.0042
# Epoch 31/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 5.6794e-04 - val_loss: 0.0043
# Epoch 32/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.6701e-04 - val_loss: 0.0022
# Epoch 33/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 5.4484e-04 - val_loss: 0.0054
# Epoch 34/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 5.5208e-04 - val_loss: 0.0034
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# R2: 0.8758
# MAPE: 0.0583
# RMSE: 8.8909
# RMSE_normalizeddata: 0.0581
# MAE: 7.2223

# %%
model_lstm.save(f"model_lstm_fedbk5h_{r2:.4f}.keras")

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(169, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.00398), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=30, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 21ms/step - loss: 0.0202 - val_loss: 0.0016
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 7.8879e-04 - val_loss: 0.0044
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.6997e-04 - val_loss: 0.0043
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 7.1049e-04 - val_loss: 0.0017
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.6928e-04 - val_loss: 0.0042
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.3314e-04 - val_loss: 0.0013
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.0547e-04 - val_loss: 0.0014
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.1577e-04 - val_loss: 0.0012
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.0499e-04 - val_loss: 0.0013
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.8359e-04 - val_loss: 0.0064
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.5555e-04 - val_loss: 0.0015
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.3308e-04 - val_loss: 0.0025
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.2871e-04 - val_loss: 0.0015
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 6.8359e-04 - val_loss: 0.0019
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.7887e-04 - val_loss: 0.0022
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.9698e-04 - val_loss: 0.0021
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.9055e-04 - val_loss: 0.0018
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.9214e-04 - val_loss: 0.0032
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.7678e-04 - val_loss: 0.0024
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.7278e-04 - val_loss: 0.0017
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.9362e-04 - val_loss: 0.0021
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.5748e-04 - val_loss: 0.0016
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.2367e-04 - val_loss: 0.0034
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.0123e-04 - val_loss: 0.0027
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.6280e-04 - val_loss: 0.0017
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.0287e-04 - val_loss: 0.0020
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.0108e-04 - val_loss: 0.0014
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.0955e-04 - val_loss: 0.0024
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.8888e-04 - val_loss: 0.0049
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.9986e-04 - val_loss: 0.0016
# Epoch 31/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.5261e-04 - val_loss: 0.0015
# Epoch 32/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.4628e-04 - val_loss: 0.0017
# Epoch 33/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.6141e-04 - val_loss: 0.0017
# Epoch 34/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.1194e-04 - val_loss: 0.0019
# Epoch 35/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 5.7504e-04 - val_loss: 0.0020
# Epoch 36/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 5.0205e-04 - val_loss: 0.0031
# Epoch 37/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 6.3660e-04 - val_loss: 0.0031
# Epoch 38/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 4.8185e-04 - val_loss: 0.0020
# Epoch 39/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.7963e-04 - val_loss: 0.0018
# Epoch 40/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.0635e-04 - val_loss: 0.0013
# Epoch 41/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.0710e-04 - val_loss: 0.0014
# Epoch 42/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.7922e-04 - val_loss: 0.0019
# Epoch 43/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.4870e-04 - val_loss: 0.0027
# Epoch 44/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.4747e-04 - val_loss: 0.0026
# Epoch 45/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.3839e-04 - val_loss: 0.0021
# Epoch 46/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 5.0571e-04 - val_loss: 0.0050
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step
# R2: 0.8161
# MAPE: 0.0705
# RMSE: 10.8185
# RMSE_normalizeddata: 0.0708
# MAE: 8.8511

# %%
model_lstm.save(f"model_lstm_fedbk5h_{r2:.4f}.keras")

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(169, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.00398), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=30, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 17s 38ms/step - loss: 0.0138 - val_loss: 0.0014
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 7.9184e-04 - val_loss: 0.0016
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.8880e-04 - val_loss: 0.0014
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.2667e-04 - val_loss: 0.0023
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.8098e-04 - val_loss: 0.0062
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.9724e-04 - val_loss: 0.0030
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.1384e-04 - val_loss: 0.0032
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.9331e-04 - val_loss: 0.0012
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.6363e-04 - val_loss: 0.0013
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.2573e-04 - val_loss: 0.0019
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.7296e-04 - val_loss: 0.0014
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.4328e-04 - val_loss: 0.0015
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.2424e-04 - val_loss: 0.0036
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.6357e-04 - val_loss: 0.0015
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.3517e-04 - val_loss: 0.0015
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.0796e-04 - val_loss: 0.0017
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.6116e-04 - val_loss: 0.0021
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.1753e-04 - val_loss: 0.0014
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 6.3071e-04 - val_loss: 0.0017
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.8477e-04 - val_loss: 0.0020
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 6.3039e-04 - val_loss: 0.0019
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 5.6020e-04 - val_loss: 0.0016
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.6085e-04 - val_loss: 0.0024
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.0463e-04 - val_loss: 0.0016
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.4595e-04 - val_loss: 0.0015
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.5789e-04 - val_loss: 0.0020
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.7294e-04 - val_loss: 0.0015
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.4671e-04 - val_loss: 0.0014
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.5534e-04 - val_loss: 0.0023
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.8266e-04 - val_loss: 0.0016
# Epoch 31/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.8107e-04 - val_loss: 0.0019
# Epoch 32/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.4344e-04 - val_loss: 0.0034
# Epoch 33/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.4457e-04 - val_loss: 0.0030
# Epoch 34/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.4052e-04 - val_loss: 0.0017
# Epoch 35/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.1505e-04 - val_loss: 0.0021
# Epoch 36/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.8227e-04 - val_loss: 0.0030
# Epoch 37/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.3886e-04 - val_loss: 0.0021
# Epoch 38/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.2570e-04 - val_loss: 0.0020
# Epoch 39/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.3249e-04 - val_loss: 0.0026
# Epoch 40/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.2589e-04 - val_loss: 0.0078
# Epoch 41/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.2790e-04 - val_loss: 0.0024
# Epoch 42/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.4069e-04 - val_loss: 0.0016
# Epoch 43/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.8024e-04 - val_loss: 0.0023
# Epoch 44/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.3965e-04 - val_loss: 0.0026
# Epoch 45/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.9285e-04 - val_loss: 0.0020
# Epoch 46/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.2401e-04 - val_loss: 0.0014
# Epoch 47/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.0751e-04 - val_loss: 0.0018
# Epoch 48/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.2232e-04 - val_loss: 0.0028
# Epoch 49/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.5795e-04 - val_loss: 0.0023
# Epoch 50/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.1235e-04 - val_loss: 0.0025
# Epoch 51/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.1235e-04 - val_loss: 0.0038
# Epoch 52/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.1341e-04 - val_loss: 0.0018
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# R2: 0.9338
# MAPE: 0.0504
# RMSE: 6.4891
# RMSE_normalizeddata: 0.0424
# MAE: 5.1675

# %%
model_lstm.save(f"model_lstm_fedbk5h_{r2:.4f}.keras")

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(169, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.00398), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=30, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0173 - val_loss: 0.0015
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.8002e-04 - val_loss: 0.0030
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.4498e-04 - val_loss: 0.0082
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.3514e-04 - val_loss: 0.0019
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.4807e-04 - val_loss: 0.0020
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.7276e-04 - val_loss: 0.0020
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.0839e-04 - val_loss: 0.0095
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.6395e-04 - val_loss: 0.0032
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.7120e-04 - val_loss: 0.0022
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.0670e-04 - val_loss: 0.0024
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.7070e-04 - val_loss: 0.0023
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.2650e-04 - val_loss: 0.0049
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.3557e-04 - val_loss: 0.0030
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.7336e-04 - val_loss: 0.0060
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.2858e-04 - val_loss: 0.0017
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.3347e-04 - val_loss: 0.0017
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.6299e-04 - val_loss: 0.0034
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.3939e-04 - val_loss: 0.0018
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.3117e-04 - val_loss: 0.0028
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.1487e-04 - val_loss: 0.0064
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.1563e-04 - val_loss: 0.0026
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.1128e-04 - val_loss: 0.0044
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.7642e-04 - val_loss: 0.0040
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.3859e-04 - val_loss: 0.0062
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.7869e-04 - val_loss: 0.0038
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.4743e-04 - val_loss: 0.0023
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.3646e-04 - val_loss: 0.0027
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.3532e-04 - val_loss: 0.0042
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.1112e-04 - val_loss: 0.0037
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.3114e-04 - val_loss: 0.0030
# Epoch 31/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.9228e-04 - val_loss: 0.0032
# Epoch 32/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.8068e-04 - val_loss: 0.0036
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
# R2: 0.8678
# MAPE: 0.0603
# RMSE: 9.1711
# RMSE_normalizeddata: 0.0600
# MAE: 7.4847

# %%
model_lstm.save(f"model_lstm_fedbk5h_{r2:.4f}.keras")

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(169, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.00398), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=30, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0156 - val_loss: 0.0016
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.0605e-04 - val_loss: 0.0021
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.4535e-04 - val_loss: 0.0147
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.8666e-04 - val_loss: 0.0012
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.6690e-04 - val_loss: 0.0017
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.8051e-04 - val_loss: 0.0016
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.5563e-04 - val_loss: 0.0033
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.6820e-04 - val_loss: 0.0024
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.0507e-04 - val_loss: 0.0028
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 7.3838e-04 - val_loss: 0.0016
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.7913e-04 - val_loss: 0.0022
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.5096e-04 - val_loss: 0.0022
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.4676e-04 - val_loss: 0.0064
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.5941e-04 - val_loss: 0.0022
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.0310e-04 - val_loss: 0.0030
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.5570e-04 - val_loss: 0.0047
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.4330e-04 - val_loss: 0.0032
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.0775e-04 - val_loss: 0.0051
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.5304e-04 - val_loss: 0.0048
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.7659e-04 - val_loss: 0.0027
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.3964e-04 - val_loss: 0.0028
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.7329e-04 - val_loss: 0.0044
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.5218e-04 - val_loss: 0.0058
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.4640e-04 - val_loss: 0.0029
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.6976e-04 - val_loss: 0.0024
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.6166e-04 - val_loss: 0.0013
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.1686e-04 - val_loss: 0.0033
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.3366e-04 - val_loss: 0.0070
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.7259e-04 - val_loss: 0.0034
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.3957e-04 - val_loss: 0.0030
# Epoch 31/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.2873e-04 - val_loss: 0.0033
# Epoch 32/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.7004e-04 - val_loss: 0.0038
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# R2: 0.8602
# MAPE: 0.0629
# RMSE: 9.4336
# RMSE_normalizeddata: 0.0617
# MAE: 7.7363

# %%
model_lstm.save(f"model_lstm_fedbk5h_{r2:.4f}.keras")
