# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as smi
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from statistics import mean
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, SimpleRNN, GRU, Dropout, Conv1D, MaxPooling1D, Flatten, RepeatVector
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_percentage_error, mean_absolute_error
from tensorflow.keras.optimizers import Adam, Nadam, RMSprop
from statsmodels.tsa.seasonal import seasonal_decompose
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from hyperopt import hp, Trials, fmin, tpe
import joblib
import warnings
warnings.simplefilter('ignore')

# %%
df=pd.read_csv(r'E:\A aPython Programms\Data1\Bank.csv')
df.head(5)
# Out:
#          Date    AXISBANK   AXISVOL  BAJAJFIN  BAJAJFINVOL        BOB  \
# 0  02-01-2009  108.379997  14261265  6.310420       141738  57.340000
# 1  05-01-2009  112.019997   9165605  6.504736      1120575  58.860001
# 2  06-01-2009  113.949997  12893855  6.660189       312830  57.750000
# 3  07-01-2009  104.419998  10571555  6.150109       166223  54.939999
# 4  09-01-2009   97.320000  25173105  6.048093        95905  54.689999
#
#     BOBVOL    FEDBANK   FEDVOL        HDFC  ...      KOTAK  KOTAKVOL  \
# 0  1700495  16.889999  1359910  101.565002  ...  97.900002   6258884
# 1  2687100  17.129999  4379460  104.410004  ...  99.637497   5956956
# 2  3162520  16.760000  1930260  110.040001  ...  96.712502   9015300
# 3  5602350  16.459999  2251090  100.925003  ...  90.762497   6482408
# 4  1806325  16.004999  4046570  101.750000  ...  86.125000   5076276
#
#           PNB   PNBVOL         SBI    SBIVOL        REC   RECVOL     PIRAMAL  \
# 0  106.430000  2973855  133.184998  24161650  29.587500  9574565  134.700485
# 1  107.160004  3037185  136.080002  26931910  30.562500  8844514  136.025497
# 2  106.089996  4110100  132.285004  35970960  29.831249  1078005  133.516418
# 3   97.660004  6538860  124.004997  37268580  28.424999  5624090  131.853104
# 4   97.129997  3834090  122.110001  24996510  28.818750  6157634  129.654144
#
#    PIRAMALVOL
# 0      222908
# 1       14449
# 2      102783
# 3       24863
# 4      301873
#
# [5 rows x 25 columns]

# %%
feature_columns = [ 'SBI', 'SBIVOL']
target_column = ['SBI']
features = df[feature_columns]
target = df[target_column].shift(-2)

new_data1 = 758.30
target.iloc[-2, 0] = new_data1

new_data2 = 766.40
target.iloc[-1, 0] = new_data2
target.tail(5)
# Out:
#              SBI
# 3748  740.049988
# 3749  733.299988
# 3750  752.349976
# 3751  758.300000
# 3752  766.400000

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_features = scaler.fit_transform(features)
scaled_target = scaler.fit_transform(target.values.reshape(-1, 1))
target=target.dropna()

n_steps = 5 # Number of timesteps to look back
X, y = [], []

for i in range(n_steps, len(scaled_features)):
    X.append(scaled_features[i-n_steps:i])
    y.append(scaled_target[i])

X = np.array(X)
y = np.array(y)

split=int(0.8*len(X))
X_train, y_train= X[:split], y[:split]
X_test, y_test= X[split:], y[split:]

# %%
model_lstm = load_model('model_lstm_sbi2_0.9681.keras')
model_lstm.predict(X_test)

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae_n=mean_absolute_error(y_test, predictions_lstm)
print(f"MAE_normalizeddata: {mae_n:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# R2: 0.9681
# MAPE: 0.0226
# RMSE: 15.5169
# RMSE_normalizeddata: 0.0222
# MAE_normalizeddata: 0.0171
# MAE: 11.9423

# %%
plt.figure(figsize=(9, 6))
plt.plot(y_test_actual_LSTM, color='green', label=['Actual Price'])
plt.plot(predictions_LSTM, color='red', label=['Predicted Price'])
plt.legend(['Actual Price', 'Predicted Price'], loc='upper left')

plt.text(0.75, 0.1, f'R2: {r2:.4f}\nMAPE: {mape:.4f}%\nRMSE: {rmse:.4f}\nMAE: {mae:.4f}', 
         fontsize=12, 
         bbox=dict(facecolor='white', alpha=0.5),
         transform=plt.gca().transAxes)

plt.grid(True)
plt.title('SBI single model (2 step ahead) ')
plt.xlabel('Time Step')
plt.ylabel('Actual vs Predicted Price')
plt.savefig('sbi_2sa-1l.png', dpi=600)  # Saves the plot as a PNG file
plt.show()

# %%
model_lstm.predict(X_train)

predictions_train_lstm = model_lstm.predict(X_train)
predictions_train_LSTM = scaler.inverse_transform(predictions_train_lstm)
y_train_actual_LSTM = scaler.inverse_transform(y_train.reshape(-1, 1))

r2=r2_score(y_train_actual_LSTM, predictions_train_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_train_actual_LSTM, predictions_train_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_train_actual_LSTM, predictions_train_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_train, predictions_train_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae_n=mean_absolute_error(y_train, predictions_train_lstm)
print(f"MAE_normalizeddata: {mae_n:.4f}")

mae=mean_absolute_error(y_train_actual_LSTM, predictions_train_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# R2: 0.9677
# MAPE: 0.0303
# RMSE: 9.7521
# RMSE_normalizeddata: 0.0140
# MAE_normalizeddata: 0.0102
# MAE: 7.1437

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(412, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.001), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=39, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])
predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")

# %%
model_lstm.save('model_lstm_bajajfin2h_1.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(412, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.001), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=39, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])
predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - loss: 0.0068 - val_loss: 0.0073
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.1011e-04 - val_loss: 0.0023
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 1.6848e-04 - val_loss: 0.0020
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.8559e-04 - val_loss: 0.0029
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.9586e-04 - val_loss: 0.0017
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.5856e-04 - val_loss: 0.0012
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.7443e-04 - val_loss: 0.0017
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.4324e-04 - val_loss: 0.0031
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.4801e-04 - val_loss: 0.0016
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.3249e-04 - val_loss: 0.0016
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.3200e-04 - val_loss: 0.0019
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.5803e-04 - val_loss: 9.0445e-04
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 1.4826e-04 - val_loss: 8.7023e-04
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.1386e-04 - val_loss: 7.9648e-04
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.3446e-04 - val_loss: 0.0016
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.1567e-04 - val_loss: 9.9054e-04
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.1029e-04 - val_loss: 9.6932e-04
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 1.2302e-04 - val_loss: 0.0012
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.1947e-04 - val_loss: 8.1531e-04
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.2428e-04 - val_loss: 7.0495e-04
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 1.2521e-04 - val_loss: 8.8674e-04
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.1018e-04 - val_loss: 9.4012e-04
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.1909e-04 - val_loss: 9.1889e-04
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 1.0010e-04 - val_loss: 7.7411e-04
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 1.0891e-04 - val_loss: 7.5708e-04
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 1.2838e-04 - val_loss: 8.5391e-04
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.1182e-04 - val_loss: 0.0011
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.0643e-04 - val_loss: 7.2322e-04
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 1.2235e-04 - val_loss: 9.1522e-04
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.0813e-04 - val_loss: 0.0012
# Epoch 31/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0322e-04 - val_loss: 7.8339e-04
# Epoch 32/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.3351e-04 - val_loss: 0.0020
# Epoch 33/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.1992e-04 - val_loss: 0.0020
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# R2: 0.7606
# MAPE: 0.0455
# RMSE: 364.3873
# RMSE_normalizeddata: 0.0446
# MAE: 310.1878

# %%
model_lstm.save('model_lstm_bajajfin2h_2.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(412, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.001), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=39, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])
predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - loss: 0.0059 - val_loss: 0.0081
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.9647e-04 - val_loss: 0.0013
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.5705e-04 - val_loss: 0.0014
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.9806e-04 - val_loss: 0.0013
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 1.9901e-04 - val_loss: 0.0012
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.4362e-04 - val_loss: 0.0011
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.8924e-04 - val_loss: 0.0014
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.6514e-04 - val_loss: 9.6822e-04
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 1.5832e-04 - val_loss: 0.0018
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.7714e-04 - val_loss: 8.9281e-04
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 1.3725e-04 - val_loss: 0.0014
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 1.3361e-04 - val_loss: 9.0463e-04
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.1405e-04 - val_loss: 8.5785e-04
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 1.2464e-04 - val_loss: 0.0012
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.4029e-04 - val_loss: 0.0012
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.3805e-04 - val_loss: 8.7880e-04
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.2740e-04 - val_loss: 0.0011
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.4154e-04 - val_loss: 8.2880e-04
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# R2: 0.9004
# MAPE: 0.0268
# RMSE: 235.0305
# RMSE_normalizeddata: 0.0288
# MAE: 179.8153

# %%
model_lstm.save('model_lstm_bajajfin2h_3.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(412, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.001), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=39, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])
predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - loss: 0.0049 - val_loss: 0.0055
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 1.6949e-04 - val_loss: 0.0044
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.6450e-04 - val_loss: 0.0044
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 1.9370e-04 - val_loss: 0.0015
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 2.1431e-04 - val_loss: 0.0021
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 1.5766e-04 - val_loss: 0.0020
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 2.3700e-04 - val_loss: 0.0012
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 1.7126e-04 - val_loss: 0.0015
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 1.5899e-04 - val_loss: 0.0012
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 1.3109e-04 - val_loss: 0.0018
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.1950e-04 - val_loss: 0.0010
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 1.3151e-04 - val_loss: 0.0028
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 1.5148e-04 - val_loss: 9.0882e-04
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 1.5767e-04 - val_loss: 0.0011
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.3200e-04 - val_loss: 7.5218e-04
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 1.3925e-04 - val_loss: 8.6559e-04
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6463e-04 - val_loss: 0.0010
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.0498e-04 - val_loss: 8.7459e-04
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.3584e-04 - val_loss: 7.5076e-04
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 1.2741e-04 - val_loss: 7.8480e-04
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 1.1077e-04 - val_loss: 0.0010
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 1.0508e-04 - val_loss: 0.0035
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.1122e-04 - val_loss: 7.0769e-04
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.1537e-04 - val_loss: 8.6000e-04
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 9.8612e-05 - val_loss: 8.5929e-04
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.1844e-04 - val_loss: 0.0015
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step
# R2: 0.8236
# MAPE: 0.0375
# RMSE: 312.7939
# RMSE_normalizeddata: 0.0383
# MAE: 255.1291

# %%
model_lstm.save('model_lstm_bajajfin2h_4.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(412, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.001), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=39, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])
predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 54s 71ms/step - loss: 0.0056 - val_loss: 0.0048
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.9874e-04 - val_loss: 0.0021
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 1.8646e-04 - val_loss: 0.0023
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.6835e-04 - val_loss: 0.0023
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 1.5831e-04 - val_loss: 0.0026
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.5223e-04 - val_loss: 0.0012
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.7303e-04 - val_loss: 0.0015
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.6914e-04 - val_loss: 0.0019
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 1.2754e-04 - val_loss: 0.0013
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.6101e-04 - val_loss: 8.9802e-04
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.5319e-04 - val_loss: 0.0015
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 1.5291e-04 - val_loss: 0.0016
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 1.5983e-04 - val_loss: 8.6743e-04
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 1.5056e-04 - val_loss: 0.0012
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 1.3004e-04 - val_loss: 8.0361e-04
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 1.2407e-04 - val_loss: 0.0010
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 1.2190e-04 - val_loss: 8.0735e-04
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.3137e-04 - val_loss: 0.0019
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 1.0942e-04 - val_loss: 0.0012
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 1.2072e-04 - val_loss: 0.0015
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.3684e-04 - val_loss: 9.6737e-04
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.5368e-04 - val_loss: 0.0011
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.3256e-04 - val_loss: 8.9628e-04
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step
# R2: 0.8923
# MAPE: 0.0278
# RMSE: 244.4113
# RMSE_normalizeddata: 0.0299
# MAE: 188.9391

# %%
model_lstm.save('model_lstm_bajajfin2h_5.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(412, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.001), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=39, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])
predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 57s 73ms/step - loss: 0.0058 - val_loss: 0.0087
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 1.7150e-04 - val_loss: 0.0037
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 1.8219e-04 - val_loss: 0.0022
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 1.8907e-04 - val_loss: 0.0025
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 1.9638e-04 - val_loss: 0.0017
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 1.4185e-04 - val_loss: 0.0052
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 1.8360e-04 - val_loss: 0.0011
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 1.4489e-04 - val_loss: 0.0012
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 1.5777e-04 - val_loss: 0.0011
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.3337e-04 - val_loss: 0.0025
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 1.7354e-04 - val_loss: 0.0015
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.4323e-04 - val_loss: 0.0012
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.2216e-04 - val_loss: 9.6486e-04
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 1.1561e-04 - val_loss: 0.0030
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.2566e-04 - val_loss: 7.9622e-04
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.1585e-04 - val_loss: 0.0010
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.3094e-04 - val_loss: 0.0015
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 1.5030e-04 - val_loss: 7.2841e-04
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 1.3246e-04 - val_loss: 8.3225e-04
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.1485e-04 - val_loss: 8.3241e-04
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.2820e-04 - val_loss: 8.7496e-04
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 1.0067e-04 - val_loss: 0.0020
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 1.1601e-04 - val_loss: 8.7368e-04
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.5656e-04 - val_loss: 8.0719e-04
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.4599e-04 - val_loss: 7.8475e-04
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 1.1388e-04 - val_loss: 0.0023
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.1694e-04 - val_loss: 7.2907e-04
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0338e-04 - val_loss: 7.9403e-04
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 1.2000e-04 - val_loss: 8.1826e-04
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 9.8281e-05 - val_loss: 8.2139e-04
# Epoch 31/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.1409e-04 - val_loss: 7.4550e-04
# Epoch 32/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.0218e-04 - val_loss: 0.0012
# Epoch 33/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.2448e-04 - val_loss: 7.6031e-04
# Epoch 34/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.1198e-04 - val_loss: 0.0011
# Epoch 35/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 9.7346e-05 - val_loss: 0.0021
# Epoch 36/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.5498e-04 - val_loss: 7.1290e-04
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 224ms/step
# R2: 0.9143
# MAPE: 0.0243
# RMSE: 217.9776
# RMSE_normalizeddata: 0.0267
# MAE: 163.1211

# %%
model_lstm.save('model_lstm_bajajfin2h_6.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(412, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.001), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=39, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])
predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 48s 75ms/step - loss: 0.0058 - val_loss: 0.0039
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.8759e-04 - val_loss: 0.0023
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - loss: 1.5465e-04 - val_loss: 0.0020
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.9302e-04 - val_loss: 0.0061
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 1.7620e-04 - val_loss: 0.0014
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.6078e-04 - val_loss: 0.0074
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.5918e-04 - val_loss: 0.0012
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 1.8138e-04 - val_loss: 0.0054
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.1995e-04 - val_loss: 0.0040
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.6561e-04 - val_loss: 0.0012
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 1.2959e-04 - val_loss: 9.9033e-04
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.5280e-04 - val_loss: 0.0018
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 1.1579e-04 - val_loss: 0.0016
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.3969e-04 - val_loss: 8.9506e-04
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 1.3145e-04 - val_loss: 0.0018
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 1.3078e-04 - val_loss: 0.0018
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.7707e-04 - val_loss: 9.0712e-04
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.2292e-04 - val_loss: 9.8680e-04
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step
# R2: 0.8814
# MAPE: 0.0302
# RMSE: 256.4556
# RMSE_normalizeddata: 0.0314
# MAE: 201.4484

# %%
model_lstm.save('model_lstm_bajajfin2h_7.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(412, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.001), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=39, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])
predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 59s 72ms/step - loss: 0.0060 - val_loss: 0.0073
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 2.0311e-04 - val_loss: 0.0045
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - loss: 1.3363e-04 - val_loss: 0.0030
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - loss: 1.5373e-04 - val_loss: 0.0018
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.3883e-04 - val_loss: 0.0015
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 1.4909e-04 - val_loss: 0.0019
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 1.5447e-04 - val_loss: 0.0017
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3702e-04 - val_loss: 0.0013
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6459e-04 - val_loss: 0.0015
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 1.6922e-04 - val_loss: 0.0012
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 1.5775e-04 - val_loss: 9.5811e-04
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 1.2733e-04 - val_loss: 9.5669e-04
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 1.3965e-04 - val_loss: 8.2374e-04
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.6018e-04 - val_loss: 9.0861e-04
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.4908e-04 - val_loss: 0.0010
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 1.1839e-04 - val_loss: 8.7105e-04
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 1.7851e-04 - val_loss: 0.0013
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 1.7717e-04 - val_loss: 0.0022
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 1.1616e-04 - val_loss: 7.3369e-04
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 1.4465e-04 - val_loss: 7.4561e-04
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 1.2655e-04 - val_loss: 0.0013
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 1.4797e-04 - val_loss: 9.4448e-04
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 1.4994e-04 - val_loss: 7.7905e-04
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 1.0621e-04 - val_loss: 7.1694e-04
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 1.4010e-04 - val_loss: 7.7267e-04
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 9.9271e-05 - val_loss: 0.0040
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 1.3970e-04 - val_loss: 7.6645e-04
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.2895e-04 - val_loss: 7.0641e-04
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.1886e-04 - val_loss: 6.8908e-04
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 9.5136e-05 - val_loss: 9.5931e-04
# Epoch 31/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.0646e-04 - val_loss: 7.4862e-04
# Epoch 32/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 1.1274e-04 - val_loss: 0.0014
# Epoch 33/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 1.2051e-04 - val_loss: 9.2741e-04
# Epoch 34/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.0868e-04 - val_loss: 0.0025
# Epoch 35/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.1778e-04 - val_loss: 6.8711e-04
# Epoch 36/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 1.0783e-04 - val_loss: 7.2590e-04
# Epoch 37/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 1.1997e-04 - val_loss: 8.6218e-04
# Epoch 38/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.0920e-04 - val_loss: 7.0047e-04
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step
# R2: 0.9158
# MAPE: 0.0241
# RMSE: 216.0691
# RMSE_normalizeddata: 0.0265
# MAE: 161.3975

# %%
model_lstm.save('model_lstm_bajajfin2h_8.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(412, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.001), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=39, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])
predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 30s 31ms/step - loss: 0.0052 - val_loss: 0.0047
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.8670e-04 - val_loss: 0.0078
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 1.7701e-04 - val_loss: 0.0041
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.7920e-04 - val_loss: 0.0013
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.1128e-04 - val_loss: 0.0014
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 1.6571e-04 - val_loss: 0.0012
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.5552e-04 - val_loss: 0.0026
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.5080e-04 - val_loss: 0.0031
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.9652e-04 - val_loss: 0.0015
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6289e-04 - val_loss: 0.0015
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 1.5666e-04 - val_loss: 9.3969e-04
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 1.5600e-04 - val_loss: 0.0024
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 1.2338e-04 - val_loss: 0.0010
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.4831e-04 - val_loss: 0.0017
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 1.4374e-04 - val_loss: 8.5899e-04
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 1.2472e-04 - val_loss: 7.5695e-04
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.1428e-04 - val_loss: 0.0026
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.2611e-04 - val_loss: 8.7101e-04
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 1.1836e-04 - val_loss: 0.0011
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.3047e-04 - val_loss: 0.0012
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.3114e-04 - val_loss: 8.6795e-04
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 1.3687e-04 - val_loss: 7.2640e-04
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - loss: 1.2049e-04 - val_loss: 8.3327e-04
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.2487e-04 - val_loss: 0.0010
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.3372e-04 - val_loss: 0.0010
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 1.1316e-04 - val_loss: 0.0012
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 1.1425e-04 - val_loss: 7.5316e-04
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.3514e-04 - val_loss: 8.4032e-04
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.1301e-04 - val_loss: 8.0413e-04
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.0934e-04 - val_loss: 7.5955e-04
# Epoch 31/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.0833e-04 - val_loss: 6.8551e-04
# Epoch 32/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 1.0502e-04 - val_loss: 8.7733e-04
# Epoch 33/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 1.4137e-04 - val_loss: 6.7554e-04
# Epoch 34/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.1663e-04 - val_loss: 0.0013
# Epoch 35/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.0062e-04 - val_loss: 9.9491e-04
# Epoch 36/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 1.1190e-04 - val_loss: 7.8647e-04
# Epoch 37/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.2036e-04 - val_loss: 8.0425e-04
# Epoch 38/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 1.1161e-04 - val_loss: 7.5814e-04
# Epoch 39/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 1.1057e-04 - val_loss: 9.3166e-04
# Epoch 40/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.1948e-04 - val_loss: 8.0614e-04
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step
# R2: 0.9031
# MAPE: 0.0260
# RMSE: 231.7941
# RMSE_normalizeddata: 0.0284
# MAE: 176.2103

# %%
model_lstm.save('model_lstm_bajajfin2h_9.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(412, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.001), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=39, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])
predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 35ms/step - loss: 0.0055 - val_loss: 0.0082
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 2.0876e-04 - val_loss: 0.0029
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 2.2741e-04 - val_loss: 0.0127
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 1.7689e-04 - val_loss: 0.0019
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 1.5753e-04 - val_loss: 0.0018
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 1.5905e-04 - val_loss: 0.0030
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 1.7103e-04 - val_loss: 0.0019
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 1.4177e-04 - val_loss: 0.0011
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 1.5627e-04 - val_loss: 0.0021
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 1.6738e-04 - val_loss: 0.0011
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.4330e-04 - val_loss: 0.0015
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 1.5255e-04 - val_loss: 9.8977e-04
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.5243e-04 - val_loss: 8.7550e-04
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 1.3007e-04 - val_loss: 8.6140e-04
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.4668e-04 - val_loss: 8.0745e-04
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.4089e-04 - val_loss: 0.0012
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 1.2097e-04 - val_loss: 0.0016
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.5453e-04 - val_loss: 8.2711e-04
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.4029e-04 - val_loss: 7.4386e-04
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 1.1987e-04 - val_loss: 0.0012
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.2327e-04 - val_loss: 8.5552e-04
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.2091e-04 - val_loss: 0.0010
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step
# R2: 0.8778
# MAPE: 0.0299
# RMSE: 260.3470
# RMSE_normalizeddata: 0.0319
# MAE: 202.9514

# %%
predictions_train_lstm = model_lstm.predict(X_train)
predictions_train_LSTM = scaler.inverse_transform(predictions_train_lstm)
y_train_actual_LSTM = scaler.inverse_transform(y_train.reshape(-1, 1))

r2=r2_score(y_train_actual_LSTM, predictions_train_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_train_actual_LSTM, predictions_train_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_train_actual_LSTM, predictions_train_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_train, predictions_train_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae_n=mean_absolute_error(y_train, predictions_train_lstm)
print(f"MAE_normalizeddata: {mae_n:.4f}")

mae=mean_absolute_error(y_train_actual_LSTM, predictions_train_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# R2: 0.9967
# MAPE: 0.0664
# RMSE: 80.3846
# RMSE_normalizeddata: 0.0098
# MAE_normalizeddata: 0.0046
# MAE: 37.2633

# %%
model_lstm.save('model_lstm_bajajfin2h_10.keras')
