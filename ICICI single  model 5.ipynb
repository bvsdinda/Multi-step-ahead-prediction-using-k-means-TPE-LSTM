# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import statsmodels.api as smi
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from statistics import mean
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, SimpleRNN, GRU, Dropout, Conv1D, MaxPooling1D, Flatten, RepeatVector
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_percentage_error, mean_absolute_error
from tensorflow.keras.optimizers import Adam, Nadam, RMSprop
from statsmodels.tsa.seasonal import seasonal_decompose
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from hyperopt import hp, Trials, fmin, tpe
import joblib
import warnings
warnings.simplefilter('ignore')

# %%
df=pd.read_csv(r'E:\A aPython Programms\Data1\Bank.csv')
df.tail(5)
# Out:
#             Date     AXISBANK   AXISVOL     BAJAJFIN  BAJAJFINVOL         BOB  \
# 3748  21-03-2024  1035.599976   9903738  6715.750000      1806092  255.699997
# 3749  22-03-2024  1033.300049   9891194  6760.899902      1125238  259.799988
# 3750  26-03-2024  1040.550049   9656767  6910.100098      1850321  261.549988
# 3751  27-03-2024  1052.849976  17027308  7022.750000      1551275  258.750000
# 3752  28-03-2024  1047.199951  10235318  7245.250000      3574518  264.049988
#
#         BOBVOL     FEDBANK    FEDVOL         HDFC  ...        KOTAK  KOTAKVOL  \
# 3748  10121220  149.949997   6212045  1445.750000  ...  1772.150024   3783681
# 3749  11402546  149.600006   8409218  1442.849976  ...  1776.400024   7061283
# 3750   8259347  149.800003   7742995  1425.400024  ...  1753.699951   5303630
# 3751  19196992  149.800003  20853016  1440.699951  ...  1775.599976   8231130
# 3752  11966752  150.199997   7208707  1447.900024  ...  1785.500000   6630072
#
#              PNB    PNBVOL         SBI    SBIVOL         REC    RECVOL  \
# 3748  121.050003  38099730  744.299988  15161161  450.250000  18429233
# 3749  122.750000  35001868  746.700012  15535921  460.100006  12531582
# 3750  123.949997  30860596  740.049988  14678342  461.399994  10475524
# 3751  122.750000  42673023  733.299988  30088789  445.600006  28138339
# 3752  124.400002  29453142  752.349976  21705116  451.000000  12637899
#
#          PIRAMAL  PIRAMALVOL
# 3748  841.599976      987716
# 3749  861.500000     1618543
# 3750  858.250000     1391794
# 3751  840.200012     1344329
# 3752  849.349976     5261416
#
# [5 rows x 25 columns]

# %%
feature_columns = ['ICICI', 'ICICIVOL']
target_column = ['ICICI']
features = df[feature_columns]
target = df[target_column].shift(-5)

new_data1 = 1099.65
target.iloc[-5, 0] = new_data1

new_data2 = 1081.20
target.iloc[-4, 0] = new_data2

new_data3 = 1077.20
target.iloc[-3, 0] = new_data3

new_data4 = 1078.85
target.iloc[-2, 0] = new_data4

new_data5 = 1083.40
target.iloc[-1, 0] = new_data5

target.tail(7)
# Out:
#             ICICI
# 3746  1083.750000
# 3747  1093.300049
# 3748  1099.650000
# 3749  1081.200000
# 3750  1077.200000
# 3751  1078.850000
# 3752  1083.400000

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_features = scaler.fit_transform(features)
scaled_target = scaler.fit_transform(target.values.reshape(-1, 1))

n_steps = 5  # Number of timesteps to look back
X, y = [], []

for i in range(n_steps, len(scaled_features)):
    X.append(scaled_features[i-n_steps:i])
    y.append(scaled_target[i])

X = np.array(X)
y = np.array(y)

split=int(0.8*len(X))
X_train, y_train= X[:split], y[:split]
X_test, y_test= X[split:], y[split:]

# %%
model_lstm = load_model('model_lstm_icici5_0.9579.keras')
model_lstm.predict(X_test)

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae_n=mean_absolute_error(y_test, predictions_lstm)
print(f"MAE_normalizeddata: {mae_n:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# R2: 0.9579
# MAPE: 0.0256
# RMSE: 26.6418
# RMSE_normalizeddata: 0.0253
# MAE_normalizeddata: 0.0198
# MAE: 20.7928

# %%
plt.figure(figsize=(9, 6))
plt.plot(y_test_actual_LSTM, color='green', label=['Actual Price'])
plt.plot(predictions_LSTM, color='red', label=['Predicted Price'])
plt.legend(['Actual Price', 'Predicted Price'], loc='upper left')

plt.text(0.75, 0.1, f'R2: {r2:.4f}\nMAPE: {mape:.4f}%\nRMSE: {rmse:.4f}\nMAE: {mae:.4f}', 
         fontsize=12, 
         bbox=dict(facecolor='white', alpha=0.5),
         transform=plt.gca().transAxes)

plt.grid(True)
plt.title('ICICI single model (5 step ahead)')
plt.xlabel('Time Step')
plt.ylabel('Actual vs Predicted Price')
plt.savefig('icici_5sa-1l.png', dpi=600)  # Saves the plot as a PNG file
plt.show()

# %%
model_lstm.predict(X_train)

predictions_train_lstm = model_lstm.predict(X_train)
predictions_train_LSTM = scaler.inverse_transform(predictions_train_lstm)
y_train_actual_LSTM = scaler.inverse_transform(y_train.reshape(-1, 1))

r2=r2_score(y_train_actual_LSTM, predictions_train_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_train_actual_LSTM, predictions_train_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_train_actual_LSTM, predictions_train_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_train, predictions_train_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae_n=mean_absolute_error(y_train, predictions_train_lstm)
print(f"MAE_normalizeddata: {mae_n:.4f}")

mae=mean_absolute_error(y_train_actual_LSTM, predictions_train_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# R2: 0.9784
# MAPE: 0.0455
# RMSE: 15.8133
# RMSE_normalizeddata: 0.0150
# MAE_normalizeddata: 0.0105
# MAE: 11.0384

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(412, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.001), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=39, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 73s 127ms/step - loss: 0.0114 - val_loss: 0.0022
# Epoch 2/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - loss: 3.4519e-04 - val_loss: 0.0022
# Epoch 3/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - loss: 2.7172e-04 - val_loss: 0.0021
# Epoch 4/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - loss: 2.9447e-04 - val_loss: 0.0022
# Epoch 5/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - loss: 2.6533e-04 - val_loss: 0.0026
# Epoch 6/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - loss: 2.6523e-04 - val_loss: 0.0023
# Epoch 7/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 7s 83ms/step - loss: 2.8576e-04 - val_loss: 0.0020
# Epoch 8/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 2.8535e-04 - val_loss: 0.0023
# Epoch 9/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 2.9486e-04 - val_loss: 0.0020
# Epoch 10/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 2.4334e-04 - val_loss: 0.0028
# Epoch 11/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 2.6559e-04 - val_loss: 0.0019
# Epoch 12/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 2.5072e-04 - val_loss: 0.0021
# Epoch 13/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 2.9419e-04 - val_loss: 0.0019
# Epoch 14/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 3.0666e-04 - val_loss: 0.0029
# Epoch 15/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 3.1858e-04 - val_loss: 0.0019
# Epoch 16/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 2.9331e-04 - val_loss: 0.0020
# Epoch 17/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - loss: 2.6954e-04 - val_loss: 0.0019
# Epoch 18/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 2.7119e-04 - val_loss: 0.0025
# Epoch 19/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 2.7653e-04 - val_loss: 0.0018
# Epoch 20/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 2.1570e-04 - val_loss: 0.0024
# Epoch 21/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - loss: 2.6560e-04 - val_loss: 0.0027
# Epoch 22/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - loss: 2.7730e-04 - val_loss: 0.0023
# Epoch 23/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 8s 89ms/step - loss: 2.6007e-04 - val_loss: 0.0018
# Epoch 24/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 77ms/step - loss: 2.1217e-04 - val_loss: 0.0022
# Epoch 25/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - loss: 2.9171e-04 - val_loss: 0.0020
# Epoch 26/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - loss: 2.6219e-04 - val_loss: 0.0020
# Epoch 27/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - loss: 2.6860e-04 - val_loss: 0.0027
# Epoch 28/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - loss: 2.5025e-04 - val_loss: 0.0017
# Epoch 29/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 78ms/step - loss: 2.3156e-04 - val_loss: 0.0032
# Epoch 30/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: 2.4410e-04 - val_loss: 0.0035
# Epoch 31/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 79ms/step - loss: 2.4389e-04 - val_loss: 0.0029
# Epoch 32/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 2.3390e-04 - val_loss: 0.0053
# Epoch 33/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - loss: 3.0239e-04 - val_loss: 0.0018
# Epoch 34/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 1.7594e-04 - val_loss: 0.0046
# Epoch 35/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 2.7565e-04 - val_loss: 0.0030
# Epoch 36/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: 2.3590e-04 - val_loss: 0.0043
# Epoch 37/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - loss: 2.4657e-04 - val_loss: 0.0028
# Epoch 38/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: 2.1559e-04 - val_loss: 0.0025
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step
# R2: 0.7177
# MAPE: 0.0462
# RMSE: 393.4978
# RMSE_normalizeddata: 0.0482
# MAE: 315.1779

# %%
model_lstm.save('model_lstm_bajajfin5_1.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(412, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.001), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=39, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 42s 161ms/step - loss: 0.0100 - val_loss: 0.0023
# Epoch 2/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step - loss: 2.9441e-04 - val_loss: 0.0035
# Epoch 3/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 2.9311e-04 - val_loss: 0.0021
# Epoch 4/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: 2.5583e-04 - val_loss: 0.0027
# Epoch 5/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: 3.2347e-04 - val_loss: 0.0021
# Epoch 6/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 2.6500e-04 - val_loss: 0.0032
# Epoch 7/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - loss: 3.0905e-04 - val_loss: 0.0026
# Epoch 8/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 3.0193e-04 - val_loss: 0.0027
# Epoch 9/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 2.7375e-04 - val_loss: 0.0033
# Epoch 10/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - loss: 2.6483e-04 - val_loss: 0.0021
# Epoch 11/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - loss: 3.3897e-04 - val_loss: 0.0020
# Epoch 12/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 2.2559e-04 - val_loss: 0.0020
# Epoch 13/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 2.5573e-04 - val_loss: 0.0028
# Epoch 14/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 3.3421e-04 - val_loss: 0.0020
# Epoch 15/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 2.3714e-04 - val_loss: 0.0019
# Epoch 16/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: 2.9690e-04 - val_loss: 0.0029
# Epoch 17/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 3.0890e-04 - val_loss: 0.0025
# Epoch 18/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - loss: 2.7714e-04 - val_loss: 0.0021
# Epoch 19/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - loss: 2.6103e-04 - val_loss: 0.0019
# Epoch 20/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - loss: 2.7143e-04 - val_loss: 0.0018
# Epoch 21/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - loss: 2.5863e-04 - val_loss: 0.0019
# Epoch 22/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 2.7166e-04 - val_loss: 0.0020
# Epoch 23/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - loss: 2.1647e-04 - val_loss: 0.0069
# Epoch 24/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - loss: 2.7650e-04 - val_loss: 0.0018
# Epoch 25/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - loss: 2.2914e-04 - val_loss: 0.0020
# Epoch 26/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - loss: 2.6714e-04 - val_loss: 0.0020
# Epoch 27/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 2.7125e-04 - val_loss: 0.0022
# Epoch 28/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 79ms/step - loss: 2.2891e-04 - val_loss: 0.0028
# Epoch 29/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - loss: 2.3751e-04 - val_loss: 0.0021
# Epoch 30/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 76ms/step - loss: 2.6452e-04 - val_loss: 0.0018
# Epoch 31/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - loss: 2.4324e-04 - val_loss: 0.0016
# Epoch 32/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 2.6015e-04 - val_loss: 0.0021
# Epoch 33/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - loss: 2.7348e-04 - val_loss: 0.0016
# Epoch 34/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - loss: 2.6366e-04 - val_loss: 0.0038
# Epoch 35/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - loss: 2.2762e-04 - val_loss: 0.0019
# Epoch 36/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 2.5322e-04 - val_loss: 0.0017
# Epoch 37/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 2.2091e-04 - val_loss: 0.0058
# Epoch 38/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 2.3158e-04 - val_loss: 0.0040
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step
# R2: 0.5446
# MAPE: 0.0620
# RMSE: 499.7807
# RMSE_normalizeddata: 0.0612
# MAE: 425.7119

# %%
model_lstm.save('model_lstm_bajajfin5_2.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(412, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.001), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=39, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 32s 110ms/step - loss: 0.0116 - val_loss: 0.0021
# Epoch 2/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - loss: 3.3059e-04 - val_loss: 0.0021
# Epoch 3/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: 3.6522e-04 - val_loss: 0.0024
# Epoch 4/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 3.3927e-04 - val_loss: 0.0021
# Epoch 5/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 3.6330e-04 - val_loss: 0.0031
# Epoch 6/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 2.6160e-04 - val_loss: 0.0030
# Epoch 7/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: 3.0779e-04 - val_loss: 0.0026
# Epoch 8/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 3.3128e-04 - val_loss: 0.0024
# Epoch 9/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 2.7149e-04 - val_loss: 0.0027
# Epoch 10/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 2.6236e-04 - val_loss: 0.0026
# Epoch 11/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 2.6448e-04 - val_loss: 0.0023
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step
# R2: 0.7468
# MAPE: 0.0429
# RMSE: 372.6259
# RMSE_normalizeddata: 0.0456
# MAE: 287.1585

# %%
model_lstm.save('model_lstm_bajajfin5_3.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(412, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.001), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=39, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 17s 59ms/step - loss: 0.0127 - val_loss: 0.0024
# Epoch 2/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 3.4247e-04 - val_loss: 0.0022
# Epoch 3/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 2.4406e-04 - val_loss: 0.0020
# Epoch 4/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 2.7677e-04 - val_loss: 0.0021
# Epoch 5/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 2.8219e-04 - val_loss: 0.0020
# Epoch 6/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 2.5735e-04 - val_loss: 0.0022
# Epoch 7/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 3.2100e-04 - val_loss: 0.0028
# Epoch 8/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: 2.7290e-04 - val_loss: 0.0026
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step
# R2: 0.7168
# MAPE: 0.0459
# RMSE: 394.0922
# RMSE_normalizeddata: 0.0483
# MAE: 308.4610

# %%
model_lstm.save('model_lstm_bajajfin5_4.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(412, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.001), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=39, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 26s 55ms/step - loss: 0.0118 - val_loss: 0.0023
# Epoch 2/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - loss: 2.9307e-04 - val_loss: 0.0020
# Epoch 3/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 3.1297e-04 - val_loss: 0.0020
# Epoch 4/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 2.6098e-04 - val_loss: 0.0023
# Epoch 5/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 2.5823e-04 - val_loss: 0.0038
# Epoch 6/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 2.7659e-04 - val_loss: 0.0020
# Epoch 7/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - loss: 3.0089e-04 - val_loss: 0.0020
# Epoch 8/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 2.8664e-04 - val_loss: 0.0026
# Epoch 9/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 2.8382e-04 - val_loss: 0.0040
# Epoch 10/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 2.5720e-04 - val_loss: 0.0020
# Epoch 11/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - loss: 2.8139e-04 - val_loss: 0.0021
# Epoch 12/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 9s 56ms/step - loss: 2.8882e-04 - val_loss: 0.0022
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step
# R2: 0.7600
# MAPE: 0.0416
# RMSE: 362.8089
# RMSE_normalizeddata: 0.0444
# MAE: 278.0300

# %%
model_lstm.save('model_lstm_bajajfin5_5.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(412, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.001), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=39, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 36s 96ms/step - loss: 0.0126 - val_loss: 0.0021
# Epoch 2/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 8s 59ms/step - loss: 3.3704e-04 - val_loss: 0.0037
# Epoch 3/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 2.9611e-04 - val_loss: 0.0020
# Epoch 4/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 2.8248e-04 - val_loss: 0.0029
# Epoch 5/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 65ms/step - loss: 3.1423e-04 - val_loss: 0.0021
# Epoch 6/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 3.2749e-04 - val_loss: 0.0022
# Epoch 7/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - loss: 3.2032e-04 - val_loss: 0.0021
# Epoch 8/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 2.9060e-04 - val_loss: 0.0020
# Epoch 9/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 2.7377e-04 - val_loss: 0.0026
# Epoch 10/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 2.5023e-04 - val_loss: 0.0032
# Epoch 11/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - loss: 2.8298e-04 - val_loss: 0.0021
# Epoch 12/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 2.4965e-04 - val_loss: 0.0024
# Epoch 13/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 3.1656e-04 - val_loss: 0.0024
# Epoch 14/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 3.1311e-04 - val_loss: 0.0021
# Epoch 15/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 2.7679e-04 - val_loss: 0.0019
# Epoch 16/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 2.9239e-04 - val_loss: 0.0019
# Epoch 17/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 2.7336e-04 - val_loss: 0.0020
# Epoch 18/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 3.1800e-04 - val_loss: 0.0019
# Epoch 19/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 2.6132e-04 - val_loss: 0.0019
# Epoch 20/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 1.9966e-04 - val_loss: 0.0019
# Epoch 21/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - loss: 2.7160e-04 - val_loss: 0.0018
# Epoch 22/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 2.6140e-04 - val_loss: 0.0022
# Epoch 23/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 2.0986e-04 - val_loss: 0.0023
# Epoch 24/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 2.1019e-04 - val_loss: 0.0029
# Epoch 25/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 1.8845e-04 - val_loss: 0.0018
# Epoch 26/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 2.7577e-04 - val_loss: 0.0022
# Epoch 27/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - loss: 2.4415e-04 - val_loss: 0.0017
# Epoch 28/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 2.2362e-04 - val_loss: 0.0017
# Epoch 29/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 2.0469e-04 - val_loss: 0.0017
# Epoch 30/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 2.1692e-04 - val_loss: 0.0036
# Epoch 31/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 2.3152e-04 - val_loss: 0.0025
# Epoch 32/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 2.3755e-04 - val_loss: 0.0016
# Epoch 33/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 2.2859e-04 - val_loss: 0.0029
# Epoch 34/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 2.2247e-04 - val_loss: 0.0017
# Epoch 35/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 2.3556e-04 - val_loss: 0.0078
# Epoch 36/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 2.3466e-04 - val_loss: 0.0051
# Epoch 37/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 2.4546e-04 - val_loss: 0.0030
# Epoch 38/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 2.4013e-04 - val_loss: 0.0029
# Epoch 39/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 1.9491e-04 - val_loss: 0.0016
# Epoch 40/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 2.1889e-04 - val_loss: 0.0018
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step
# R2: 0.7951
# MAPE: 0.0384
# RMSE: 335.2394
# RMSE_normalizeddata: 0.0411
# MAE: 258.8891

# %%
model_lstm.save('model_lstm_bajajfin5_6.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(412, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.001), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=39, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))


r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 12s 58ms/step - loss: 0.0101 - val_loss: 0.0020
# Epoch 2/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 2.9290e-04 - val_loss: 0.0022
# Epoch 3/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 2.8685e-04 - val_loss: 0.0020
# Epoch 4/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 3.1166e-04 - val_loss: 0.0023
# Epoch 5/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 3.9086e-04 - val_loss: 0.0045
# Epoch 6/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 3.3743e-04 - val_loss: 0.0020
# Epoch 7/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 3.2530e-04 - val_loss: 0.0021
# Epoch 8/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 2.3379e-04 - val_loss: 0.0034
# Epoch 9/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 2.9714e-04 - val_loss: 0.0024
# Epoch 10/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 2.9936e-04 - val_loss: 0.0021
# Epoch 11/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 2.9467e-04 - val_loss: 0.0022
# Epoch 12/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.7285e-04 - val_loss: 0.0020
# Epoch 13/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 2.2785e-04 - val_loss: 0.0020
# Epoch 14/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 2.8926e-04 - val_loss: 0.0019
# Epoch 15/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 2.4792e-04 - val_loss: 0.0025
# Epoch 16/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 3.2273e-04 - val_loss: 0.0019
# Epoch 17/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 2.8997e-04 - val_loss: 0.0022
# Epoch 18/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.2175e-04 - val_loss: 0.0021
# Epoch 19/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 3.3989e-04 - val_loss: 0.0026
# Epoch 20/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 2.1353e-04 - val_loss: 0.0020
# Epoch 21/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 2.0584e-04 - val_loss: 0.0020
# Epoch 22/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 2.0234e-04 - val_loss: 0.0025
# Epoch 23/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 2.6254e-04 - val_loss: 0.0021
# Epoch 24/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 2.5615e-04 - val_loss: 0.0021
# Epoch 25/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.3855e-04 - val_loss: 0.0053
# Epoch 26/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 2.5335e-04 - val_loss: 0.0030
# Epoch 27/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 2.9371e-04 - val_loss: 0.0018
# Epoch 28/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 2.6218e-04 - val_loss: 0.0021
# Epoch 29/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 2.7908e-04 - val_loss: 0.0026
# Epoch 30/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 2.0989e-04 - val_loss: 0.0041
# Epoch 31/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 2.6786e-04 - val_loss: 0.0019
# Epoch 32/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 3.0101e-04 - val_loss: 0.0017
# Epoch 33/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 2.4511e-04 - val_loss: 0.0019
# Epoch 34/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.7750e-04 - val_loss: 0.0016
# Epoch 35/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 2.5160e-04 - val_loss: 0.0016
# Epoch 36/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.7735e-04 - val_loss: 0.0017
# Epoch 37/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 2.0649e-04 - val_loss: 0.0033
# Epoch 38/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.4535e-04 - val_loss: 0.0019
# Epoch 39/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.1256e-04 - val_loss: 0.0018
# Epoch 40/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 2.1292e-04 - val_loss: 0.0022
# Epoch 41/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 2.7125e-04 - val_loss: 0.0092
# Epoch 42/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 2.4098e-04 - val_loss: 0.0019
# Epoch 43/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.6186e-04 - val_loss: 0.0044
# Epoch 44/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 2.1973e-04 - val_loss: 0.0032
# Epoch 45/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 2.0575e-04 - val_loss: 0.0017
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# R2: 0.8046
# MAPE: 0.0376
# RMSE: 327.3784
# RMSE_normalizeddata: 0.0401
# MAE: 252.3933

# %%
model_lstm.save('model_lstm_bajajfin5_7.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(412, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.001), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=39, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 0.0119 - val_loss: 0.0021
# Epoch 2/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 2.8920e-04 - val_loss: 0.0043
# Epoch 3/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.5293e-04 - val_loss: 0.0091
# Epoch 4/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 4.0384e-04 - val_loss: 0.0028
# Epoch 5/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 2.5246e-04 - val_loss: 0.0021
# Epoch 6/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 3.3234e-04 - val_loss: 0.0036
# Epoch 7/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 2.8271e-04 - val_loss: 0.0021
# Epoch 8/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 2.4322e-04 - val_loss: 0.0025
# Epoch 9/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 2.7526e-04 - val_loss: 0.0021
# Epoch 10/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 2.7310e-04 - val_loss: 0.0020
# Epoch 11/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 2.8798e-04 - val_loss: 0.0020
# Epoch 12/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 3.2035e-04 - val_loss: 0.0023
# Epoch 13/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 2.7391e-04 - val_loss: 0.0021
# Epoch 14/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.7541e-04 - val_loss: 0.0022
# Epoch 15/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 3.3670e-04 - val_loss: 0.0023
# Epoch 16/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 2.2888e-04 - val_loss: 0.0020
# Epoch 17/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.5051e-04 - val_loss: 0.0034
# Epoch 18/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 2.3711e-04 - val_loss: 0.0020
# Epoch 19/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 2.7340e-04 - val_loss: 0.0019
# Epoch 20/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 2.5325e-04 - val_loss: 0.0019
# Epoch 21/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 2.1115e-04 - val_loss: 0.0020
# Epoch 22/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 2.6177e-04 - val_loss: 0.0018
# Epoch 23/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 2.6603e-04 - val_loss: 0.0018
# Epoch 24/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 2.8412e-04 - val_loss: 0.0018
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# R2: 0.7933
# MAPE: 0.0387
# RMSE: 336.7112
# RMSE_normalizeddata: 0.0412
# MAE: 257.4226

# %%
model_lstm.save('model_lstm_bajajfin5_8.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(412, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.001), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=39, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 0.0126 - val_loss: 0.0020
# Epoch 2/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 2.7948e-04 - val_loss: 0.0020
# Epoch 3/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 2.8137e-04 - val_loss: 0.0021
# Epoch 4/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 3.0274e-04 - val_loss: 0.0020
# Epoch 5/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 2.8368e-04 - val_loss: 0.0025
# Epoch 6/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 2.5918e-04 - val_loss: 0.0023
# Epoch 7/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 2.3141e-04 - val_loss: 0.0020
# Epoch 8/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.9081e-04 - val_loss: 0.0034
# Epoch 9/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 2.8282e-04 - val_loss: 0.0023
# Epoch 10/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 2.4376e-04 - val_loss: 0.0021
# Epoch 11/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 2.4138e-04 - val_loss: 0.0021
# Epoch 12/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 3.3292e-04 - val_loss: 0.0020
# Epoch 13/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 2.8505e-04 - val_loss: 0.0022
# Epoch 14/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 2.9780e-04 - val_loss: 0.0020
# Epoch 15/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 2.6721e-04 - val_loss: 0.0031
# Epoch 16/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.6667e-04 - val_loss: 0.0021
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
# R2: 0.7674
# MAPE: 0.0409
# RMSE: 357.1937
# RMSE_normalizeddata: 0.0438
# MAE: 273.4104

# %%
model_lstm.save('model_lstm_bajajfin5_9.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(412, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.001), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=39, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 0.0138 - val_loss: 0.0023
# Epoch 2/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 3.0616e-04 - val_loss: 0.0021
# Epoch 3/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 2.5672e-04 - val_loss: 0.0024
# Epoch 4/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 2.4463e-04 - val_loss: 0.0022
# Epoch 5/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 3.6100e-04 - val_loss: 0.0021
# Epoch 6/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.9370e-04 - val_loss: 0.0021
# Epoch 7/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.8812e-04 - val_loss: 0.0021
# Epoch 8/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.4521e-04 - val_loss: 0.0021
# Epoch 9/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 3.0228e-04 - val_loss: 0.0024
# Epoch 10/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 2.8600e-04 - val_loss: 0.0022
# Epoch 11/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 2.9132e-04 - val_loss: 0.0024
# Epoch 12/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.6768e-04 - val_loss: 0.0020
# Epoch 13/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.8097e-04 - val_loss: 0.0020
# Epoch 14/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.5276e-04 - val_loss: 0.0019
# Epoch 15/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 2.3187e-04 - val_loss: 0.0020
# Epoch 16/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 3.4043e-04 - val_loss: 0.0019
# Epoch 17/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 2.8437e-04 - val_loss: 0.0025
# Epoch 18/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 2.8239e-04 - val_loss: 0.0020
# Epoch 19/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 2.6968e-04 - val_loss: 0.0019
# Epoch 20/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 2.2676e-04 - val_loss: 0.0022
# Epoch 21/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 3.3568e-04 - val_loss: 0.0019
# Epoch 22/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 2.6101e-04 - val_loss: 0.0020
# Epoch 23/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 2.2431e-04 - val_loss: 0.0021
# Epoch 24/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 2.4943e-04 - val_loss: 0.0032
# Epoch 25/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 2.5008e-04 - val_loss: 0.0022
# Epoch 26/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 2.4299e-04 - val_loss: 0.0017
# Epoch 27/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 2.3457e-04 - val_loss: 0.0017
# Epoch 28/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 2.3447e-04 - val_loss: 0.0017
# Epoch 29/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 2.8464e-04 - val_loss: 0.0019
# Epoch 30/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 2.1948e-04 - val_loss: 0.0027
# Epoch 31/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 2.2586e-04 - val_loss: 0.0022
# Epoch 32/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 2.2542e-04 - val_loss: 0.0048
# Epoch 33/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 2.3184e-04 - val_loss: 0.0019
# Epoch 34/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.7009e-04 - val_loss: 0.0031
# Epoch 35/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 2.5268e-04 - val_loss: 0.0016
# Epoch 36/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 2.5234e-04 - val_loss: 0.0016
# Epoch 37/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 2.4218e-04 - val_loss: 0.0024
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
# R2: 0.7292
# MAPE: 0.0451
# RMSE: 385.4038
# RMSE_normalizeddata: 0.0472
# MAE: 306.8200

# %%
model_lstm.save('model_lstm_bajajfin5_10.keras')
