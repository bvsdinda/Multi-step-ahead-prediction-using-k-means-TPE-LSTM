# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as smi
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from statistics import mean
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, SimpleRNN, GRU, Dropout, Conv1D, MaxPooling1D, Flatten, RepeatVector
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_percentage_error, mean_absolute_error
from tensorflow.keras.optimizers import Adam, Nadam, RMSprop
from statsmodels.tsa.seasonal import seasonal_decompose
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from hyperopt import hp, Trials, fmin, tpe
import joblib
import warnings
warnings.simplefilter('ignore')

# %%
df=pd.read_csv(r'E:\A aPython Programms\Data1\Bank.csv')
df.head(5)
# Out:
#          Date    AXISBANK   AXISVOL  BAJAJFIN  BAJAJFINVOL        BOB  \
# 0  02-01-2009  108.379997  14261265  6.310420       141738  57.340000
# 1  05-01-2009  112.019997   9165605  6.504736      1120575  58.860001
# 2  06-01-2009  113.949997  12893855  6.660189       312830  57.750000
# 3  07-01-2009  104.419998  10571555  6.150109       166223  54.939999
# 4  09-01-2009   97.320000  25173105  6.048093        95905  54.689999
#
#     BOBVOL    FEDBANK   FEDVOL        HDFC  ...      KOTAK  KOTAKVOL  \
# 0  1700495  16.889999  1359910  101.565002  ...  97.900002   6258884
# 1  2687100  17.129999  4379460  104.410004  ...  99.637497   5956956
# 2  3162520  16.760000  1930260  110.040001  ...  96.712502   9015300
# 3  5602350  16.459999  2251090  100.925003  ...  90.762497   6482408
# 4  1806325  16.004999  4046570  101.750000  ...  86.125000   5076276
#
#           PNB   PNBVOL         SBI    SBIVOL        REC   RECVOL     PIRAMAL  \
# 0  106.430000  2973855  133.184998  24161650  29.587500  9574565  134.700485
# 1  107.160004  3037185  136.080002  26931910  30.562500  8844514  136.025497
# 2  106.089996  4110100  132.285004  35970960  29.831249  1078005  133.516418
# 3   97.660004  6538860  124.004997  37268580  28.424999  5624090  131.853104
# 4   97.129997  3834090  122.110001  24996510  28.818750  6157634  129.654144
#
#    PIRAMALVOL
# 0      222908
# 1       14449
# 2      102783
# 3       24863
# 4      301873
#
# [5 rows x 25 columns]

# %%
feature_columns = ['FEDBANK', 'FEDVOL']
target_column = ['FEDBANK']
features = df[feature_columns]
target = df[target_column].shift(-2)

new_data1 = 152.35
target.iloc[-2, 0] = new_data1

new_data2 = 154.05
target.iloc[-1, 0] = new_data2
target.tail(5)
# Out:
#          FEDBANK
# 3748  149.800003
# 3749  149.800003
# 3750  150.199997
# 3751  152.350000
# 3752  154.050000

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_features = scaler.fit_transform(features)
scaled_target = scaler.fit_transform(target.values.reshape(-1, 1))
target=target.dropna()

n_steps = 5 # Number of timesteps to look back
X, y = [], []

for i in range(n_steps, len(scaled_features)):
    X.append(scaled_features[i-n_steps:i])
    y.append(scaled_target[i])

X = np.array(X)
y = np.array(y)

split=int(0.8*len(X))
X_train, y_train= X[:split], y[:split]
X_test, y_test= X[split:], y[split:]

# %%
model_lstm = load_model('model_lstm_fed2_0.9804.keras')
model_lstm.predict(X_test)

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae_n=mean_absolute_error(y_test, predictions_lstm)
print(f"MAE_normalizeddata: {mae_n:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# R2: 0.9804
# MAPE: 0.0237
# RMSE: 3.5285
# RMSE_normalizeddata: 0.0231
# MAE_normalizeddata: 0.0173
# MAE: 2.6442

# %%
plt.figure(figsize=(9, 6))
plt.plot(y_test_actual_LSTM, color='green', label=['Actual Price'])
plt.plot(predictions_LSTM, color='red', label=['Predicted Price'])
plt.legend(['Actual Price', 'Predicted Price'], loc='upper left')

plt.text(0.75, 0.1, f'R2: {r2:.4f}\nMAPE: {mape:.4f}%\nRMSE: {rmse:.4f}\nMAE: {mae:.4f}', 
         fontsize=12, 
         bbox=dict(facecolor='white', alpha=0.5),
         transform=plt.gca().transAxes)

plt.grid(True)
plt.title('FEDBANK single model (2 step ahead)')
plt.xlabel('Time Step')
plt.ylabel('Actual vs Predicted Price')
plt.savefig('fed_2sa1l.png', dpi=600)  # Saves the plot as a PNG file
plt.show()

# %%
model_lstm.predict(X_train)

predictions_train_lstm = model_lstm.predict(X_train)
predictions_train_LSTM = scaler.inverse_transform(predictions_train_lstm)
y_train_actual_LSTM = scaler.inverse_transform(y_train.reshape(-1, 1))

r2=r2_score(y_train_actual_LSTM, predictions_train_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_train_actual_LSTM, predictions_train_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_train_actual_LSTM, predictions_train_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_train, predictions_train_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae_n=mean_absolute_error(y_train, predictions_train_lstm)
print(f"MAE_normalizeddata: {mae_n:.4f}")

mae=mean_absolute_error(y_train_actual_LSTM, predictions_train_LSTM)
print(f"MAE: {mae:.4f}")

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(169, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.00398), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=30, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.0134 - val_loss: 0.0013
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.7861e-04 - val_loss: 7.5530e-04
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 4.1904e-04 - val_loss: 0.0039
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 4.0136e-04 - val_loss: 0.0043
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.4388e-04 - val_loss: 8.7851e-04
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.0193e-04 - val_loss: 8.0717e-04
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.2609e-04 - val_loss: 0.0013
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.0884e-04 - val_loss: 0.0010
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.6917e-04 - val_loss: 6.8520e-04
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.7657e-04 - val_loss: 8.4990e-04
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.9873e-04 - val_loss: 6.6761e-04
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.0584e-04 - val_loss: 7.3221e-04
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.2021e-04 - val_loss: 7.2506e-04
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.3380e-04 - val_loss: 0.0014
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.4319e-04 - val_loss: 0.0012
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.1326e-04 - val_loss: 0.0017
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.9458e-04 - val_loss: 7.6602e-04
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.1782e-04 - val_loss: 8.7370e-04
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.0132e-04 - val_loss: 0.0046
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.0930e-04 - val_loss: 7.7341e-04
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.9805e-04 - val_loss: 9.4334e-04
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.9182e-04 - val_loss: 0.0019
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.7656e-04 - val_loss: 8.6656e-04
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.8172e-04 - val_loss: 8.7422e-04
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.9537e-04 - val_loss: 0.0012
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.1575e-04 - val_loss: 0.0011
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.7955e-04 - val_loss: 0.0012
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.8212e-04 - val_loss: 9.6902e-04
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.0797e-04 - val_loss: 0.0012
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.0915e-04 - val_loss: 0.0016
# Epoch 31/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.2326e-04 - val_loss: 0.0013
# Epoch 32/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.1665e-04 - val_loss: 0.0016
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
# R2: 0.9406
# MAPE: 0.0407
# RMSE: 6.1486
# RMSE_normalizeddata: 0.0402
# MAE: 4.9617

# %%
model_lstm.save(f"model_lstm_fedbk2h_{r2:.4f}.keras")

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(169, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.00398), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=30, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - loss: 0.0210 - val_loss: 0.0014
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.4304e-04 - val_loss: 0.0013
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.5386e-04 - val_loss: 7.0760e-04
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.4833e-04 - val_loss: 7.1988e-04
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.5621e-04 - val_loss: 8.9177e-04
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.2271e-04 - val_loss: 0.0034
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.2628e-04 - val_loss: 0.0011
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.0423e-04 - val_loss: 6.9463e-04
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.7881e-04 - val_loss: 7.0690e-04
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.2703e-04 - val_loss: 9.6804e-04
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.5689e-04 - val_loss: 0.0011
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.6941e-04 - val_loss: 0.0012
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.5691e-04 - val_loss: 7.9973e-04
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.5511e-04 - val_loss: 0.0011
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.1079e-04 - val_loss: 7.4754e-04
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.4927e-04 - val_loss: 0.0011
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.4630e-04 - val_loss: 7.3553e-04
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.7224e-04 - val_loss: 8.2397e-04
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.4192e-04 - val_loss: 7.5798e-04
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.0477e-04 - val_loss: 0.0011
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.4422e-04 - val_loss: 7.5904e-04
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.1052e-04 - val_loss: 7.8519e-04
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.1237e-04 - val_loss: 0.0022
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.9738e-04 - val_loss: 7.2725e-04
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.3602e-04 - val_loss: 7.9663e-04
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.8026e-04 - val_loss: 0.0011
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.2431e-04 - val_loss: 6.3881e-04
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.3159e-04 - val_loss: 8.7632e-04
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# R2: 0.9678
# MAPE: 0.0301
# RMSE: 4.5262
# RMSE_normalizeddata: 0.0296
# MAE: 3.5451

# %%
model_lstm.save(f"model_lstm_fedbk2h_{r2:.4f}.keras")

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(169, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.00398), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=30, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 0.0138 - val_loss: 0.0039
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 4.6255e-04 - val_loss: 7.3697e-04
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 4.8743e-04 - val_loss: 0.0021
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 4.2178e-04 - val_loss: 0.0016
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.6981e-04 - val_loss: 8.6423e-04
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.1800e-04 - val_loss: 6.5483e-04
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.2078e-04 - val_loss: 0.0012
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 3.9644e-04 - val_loss: 9.4097e-04
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.0365e-04 - val_loss: 7.2406e-04
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.0707e-04 - val_loss: 9.4011e-04
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 3.4354e-04 - val_loss: 0.0011
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 3.3535e-04 - val_loss: 7.5066e-04
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 3.4471e-04 - val_loss: 9.2123e-04
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 3.4061e-04 - val_loss: 0.0016
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 3.4624e-04 - val_loss: 8.8775e-04
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.2066e-04 - val_loss: 0.0016
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.2185e-04 - val_loss: 0.0020
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 3.5545e-04 - val_loss: 8.2732e-04
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.2174e-04 - val_loss: 0.0014
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 3.2381e-04 - val_loss: 0.0018
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 3.0016e-04 - val_loss: 0.0013
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 2.9184e-04 - val_loss: 7.3715e-04
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 3.1486e-04 - val_loss: 9.3872e-04
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 3.1760e-04 - val_loss: 0.0010
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.9713e-04 - val_loss: 0.0015
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.1216e-04 - val_loss: 8.7665e-04
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.0129e-04 - val_loss: 0.0013
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.8957e-04 - val_loss: 7.2046e-04
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.0887e-04 - val_loss: 0.0013
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.0208e-04 - val_loss: 0.0013
# Epoch 31/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.0906e-04 - val_loss: 0.0019
# Epoch 32/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.0013e-04 - val_loss: 0.0010
# Epoch 33/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.8796e-04 - val_loss: 0.0012
# Epoch 34/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.8634e-04 - val_loss: 0.0015
# Epoch 35/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.9730e-04 - val_loss: 0.0011
# Epoch 36/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.9260e-04 - val_loss: 0.0012
# Epoch 37/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.8546e-04 - val_loss: 0.0022
# Epoch 38/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.7638e-04 - val_loss: 0.0022
# Epoch 39/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.7639e-04 - val_loss: 9.9814e-04
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step
# R2: 0.9633
# MAPE: 0.0348
# RMSE: 4.8306
# RMSE_normalizeddata: 0.0316
# MAE: 3.8674

# %%
model_lstm.save(f"model_lstm_fedbk2h_{r2:.4f}.keras")

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(169, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.00398), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=30, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - loss: 0.0104 - val_loss: 0.0090
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.1425e-04 - val_loss: 9.8653e-04
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.5370e-04 - val_loss: 0.0014
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.8062e-04 - val_loss: 6.8244e-04
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.0831e-04 - val_loss: 8.9933e-04
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.0203e-04 - val_loss: 0.0014
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.0791e-04 - val_loss: 0.0012
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 4.1048e-04 - val_loss: 9.2713e-04
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 3.7444e-04 - val_loss: 0.0010
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 3.3646e-04 - val_loss: 0.0011
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.4843e-04 - val_loss: 0.0012
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.6578e-04 - val_loss: 0.0012
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 3.9089e-04 - val_loss: 0.0015
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.5541e-04 - val_loss: 0.0010
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 3.3682e-04 - val_loss: 0.0018
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.2890e-04 - val_loss: 0.0010
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 3.4989e-04 - val_loss: 0.0013
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.5484e-04 - val_loss: 0.0013
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.9873e-04 - val_loss: 0.0024
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 3.1836e-04 - val_loss: 0.0016
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 3.1701e-04 - val_loss: 0.0017
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 2.7772e-04 - val_loss: 0.0022
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 3.2779e-04 - val_loss: 9.0706e-04
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 3.0808e-04 - val_loss: 0.0011
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 3.1205e-04 - val_loss: 8.6932e-04
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.9100e-04 - val_loss: 0.0018
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.1115e-04 - val_loss: 9.9287e-04
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.2054e-04 - val_loss: 0.0011
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.8545e-04 - val_loss: 7.3644e-04
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.0482e-04 - val_loss: 0.0010
# Epoch 31/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.8948e-04 - val_loss: 0.0013
# Epoch 32/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.8910e-04 - val_loss: 9.5786e-04
# Epoch 33/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.9708e-04 - val_loss: 0.0010
# Epoch 34/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.9220e-04 - val_loss: 0.0011
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step
# R2: 0.9591
# MAPE: 0.0352
# RMSE: 5.1021
# RMSE_normalizeddata: 0.0334
# MAE: 4.1032

# %%
model_lstm.save(f"model_lstm_fedbk2h_{r2:.4f}.keras")

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(169, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.00398), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=30, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - loss: 0.0116 - val_loss: 0.0056
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.1065e-04 - val_loss: 0.0025
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.7197e-04 - val_loss: 0.0012
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.4685e-04 - val_loss: 0.0013
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.9436e-04 - val_loss: 0.0016
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.5548e-04 - val_loss: 8.4959e-04
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.2403e-04 - val_loss: 9.1390e-04
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.4207e-04 - val_loss: 9.9526e-04
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.6743e-04 - val_loss: 0.0010
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.4292e-04 - val_loss: 9.3662e-04
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.5620e-04 - val_loss: 8.6524e-04
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.6706e-04 - val_loss: 7.4686e-04
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.6719e-04 - val_loss: 0.0017
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.5707e-04 - val_loss: 0.0018
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.4905e-04 - val_loss: 0.0011
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.3207e-04 - val_loss: 0.0011
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.2317e-04 - val_loss: 0.0019
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.5091e-04 - val_loss: 0.0012
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 3.3377e-04 - val_loss: 0.0012
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.4266e-04 - val_loss: 0.0018
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 2.8884e-04 - val_loss: 0.0016
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 3.3547e-04 - val_loss: 0.0010
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 3.5534e-04 - val_loss: 0.0011
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.2370e-04 - val_loss: 7.6128e-04
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.8718e-04 - val_loss: 8.5198e-04
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.8504e-04 - val_loss: 0.0013
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.8998e-04 - val_loss: 8.3136e-04
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 3.1982e-04 - val_loss: 0.0012
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 3.1617e-04 - val_loss: 8.8523e-04
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 3.1718e-04 - val_loss: 0.0012
# Epoch 31/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.0130e-04 - val_loss: 8.6771e-04
# Epoch 32/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.9455e-04 - val_loss: 0.0011
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step
# R2: 0.9587
# MAPE: 0.0337
# RMSE: 5.1241
# RMSE_normalizeddata: 0.0335
# MAE: 4.0544

# %%
model_lstm.save(f"model_lstm_fedbk2h_{r2:.4f}.keras")

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(169, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.00398), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=30, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - loss: 0.0133 - val_loss: 9.4123e-04
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 4.3789e-04 - val_loss: 8.2923e-04
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 4.4583e-04 - val_loss: 7.9934e-04
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.0487e-04 - val_loss: 8.5700e-04
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.3493e-04 - val_loss: 7.4574e-04
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.3840e-04 - val_loss: 7.8992e-04
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.7999e-04 - val_loss: 0.0011
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.8575e-04 - val_loss: 0.0013
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.8786e-04 - val_loss: 8.8336e-04
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.9147e-04 - val_loss: 0.0011
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.1769e-04 - val_loss: 0.0010
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.5429e-04 - val_loss: 0.0016
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.5430e-04 - val_loss: 0.0011
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.7348e-04 - val_loss: 8.1125e-04
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.2358e-04 - val_loss: 0.0012
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.5987e-04 - val_loss: 0.0013
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.6464e-04 - val_loss: 0.0011
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.6329e-04 - val_loss: 0.0014
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.0148e-04 - val_loss: 0.0013
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.3078e-04 - val_loss: 9.9883e-04
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.0175e-04 - val_loss: 0.0012
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.7929e-04 - val_loss: 0.0021
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.1235e-04 - val_loss: 9.7683e-04
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.2392e-04 - val_loss: 0.0014
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.2614e-04 - val_loss: 9.7512e-04
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.5327e-04 - val_loss: 0.0027
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.8371e-04 - val_loss: 0.0010
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.9335e-04 - val_loss: 0.0014
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.8843e-04 - val_loss: 0.0010
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.6420e-04 - val_loss: 0.0017
# Epoch 31/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.0601e-04 - val_loss: 0.0031
# Epoch 32/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.2369e-04 - val_loss: 9.5365e-04
# Epoch 33/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 2.7889e-04 - val_loss: 0.0016
# Epoch 34/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.8296e-04 - val_loss: 8.2306e-04
# Epoch 35/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.8602e-04 - val_loss: 0.0017
# Epoch 36/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.8813e-04 - val_loss: 0.0012
# Epoch 37/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 2.7947e-04 - val_loss: 7.8285e-04
# Epoch 38/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.9427e-04 - val_loss: 0.0016
# Epoch 39/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 3.0324e-04 - val_loss: 7.6010e-04
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step
# R2: 0.9721
# MAPE: 0.0296
# RMSE: 4.2154
# RMSE_normalizeddata: 0.0276
# MAE: 3.2926

# %%
model_lstm.save(f"model_lstm_fedbk2h_{r2:.4f}.keras")

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(169, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.00398), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=30, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - loss: 0.0171 - val_loss: 0.0014
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 4.4094e-04 - val_loss: 8.9486e-04
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.9656e-04 - val_loss: 7.6606e-04
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 4.7234e-04 - val_loss: 0.0029
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 4.2224e-04 - val_loss: 8.0350e-04
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.3396e-04 - val_loss: 9.0709e-04
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.8754e-04 - val_loss: 0.0022
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.6479e-04 - val_loss: 0.0015
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.1931e-04 - val_loss: 7.7034e-04
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.6712e-04 - val_loss: 8.0804e-04
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.4358e-04 - val_loss: 0.0018
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.3067e-04 - val_loss: 0.0012
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.2774e-04 - val_loss: 0.0019
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.2435e-04 - val_loss: 7.8059e-04
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.2895e-04 - val_loss: 0.0010
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.4613e-04 - val_loss: 0.0013
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.3105e-04 - val_loss: 8.8475e-04
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.9578e-04 - val_loss: 7.9345e-04
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.3410e-04 - val_loss: 0.0011
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.2930e-04 - val_loss: 0.0017
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.9948e-04 - val_loss: 9.6924e-04
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.9892e-04 - val_loss: 7.7683e-04
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.8813e-04 - val_loss: 7.6808e-04
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.1374e-04 - val_loss: 0.0020
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.1890e-04 - val_loss: 6.2991e-04
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.8314e-04 - val_loss: 0.0013
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.9091e-04 - val_loss: 7.9307e-04
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 3.1569e-04 - val_loss: 0.0013
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.1312e-04 - val_loss: 8.9835e-04
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 2.9044e-04 - val_loss: 6.9568e-04
# Epoch 31/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.0459e-04 - val_loss: 0.0013
# Epoch 32/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 3.0112e-04 - val_loss: 0.0016
# Epoch 33/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.0677e-04 - val_loss: 0.0017
# Epoch 34/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.9863e-04 - val_loss: 8.4778e-04
# Epoch 35/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 2.9071e-04 - val_loss: 7.1704e-04
# Epoch 36/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.9929e-04 - val_loss: 8.0069e-04
# Epoch 37/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.0317e-04 - val_loss: 0.0011
# Epoch 38/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.0508e-04 - val_loss: 0.0015
# Epoch 39/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 2.9706e-04 - val_loss: 7.7840e-04
# Epoch 40/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 2.7261e-04 - val_loss: 0.0011
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step
# R2: 0.9596
# MAPE: 0.0338
# RMSE: 5.0680
# RMSE_normalizeddata: 0.0331
# MAE: 4.0455

# %%
model_lstm.save(f"model_lstm_fedbk2h_{r2:.4f}.keras")

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(169, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.00398), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=30, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - loss: 0.0120 - val_loss: 0.0015
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.2198e-04 - val_loss: 9.0736e-04
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.4324e-04 - val_loss: 7.3097e-04
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.4203e-04 - val_loss: 0.0013
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 4.3461e-04 - val_loss: 9.9644e-04
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 4.2328e-04 - val_loss: 9.7221e-04
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 4.4869e-04 - val_loss: 0.0013
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 3.9883e-04 - val_loss: 0.0010
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.9105e-04 - val_loss: 0.0011
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 3.5869e-04 - val_loss: 0.0013
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 3.7854e-04 - val_loss: 0.0010
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.4726e-04 - val_loss: 0.0013
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.6538e-04 - val_loss: 0.0011
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.2007e-04 - val_loss: 9.4691e-04
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.1946e-04 - val_loss: 0.0010
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.4649e-04 - val_loss: 9.8974e-04
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.4240e-04 - val_loss: 0.0021
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.4578e-04 - val_loss: 9.2041e-04
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.8466e-04 - val_loss: 0.0014
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
# R2: 0.9479
# MAPE: 0.0388
# RMSE: 5.7566
# RMSE_normalizeddata: 0.0376
# MAE: 4.6605

# %%
model_lstm.save(f"model_lstm_fedbk2h_{r2:.4f}.keras")

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(169, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.00398), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=30, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 22ms/step - loss: 0.0125 - val_loss: 0.0011
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.3871e-04 - val_loss: 9.0957e-04
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.2110e-04 - val_loss: 0.0012
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.3196e-04 - val_loss: 8.8508e-04
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.0365e-04 - val_loss: 7.7541e-04
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 4.3011e-04 - val_loss: 0.0023
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.0110e-04 - val_loss: 0.0011
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.5805e-04 - val_loss: 9.4238e-04
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.6077e-04 - val_loss: 0.0014
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.4875e-04 - val_loss: 9.5649e-04
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.4240e-04 - val_loss: 9.5590e-04
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.7396e-04 - val_loss: 7.1755e-04
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.2668e-04 - val_loss: 7.5798e-04
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.3769e-04 - val_loss: 7.3031e-04
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.1642e-04 - val_loss: 0.0011
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.3940e-04 - val_loss: 6.7083e-04
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.1041e-04 - val_loss: 7.1284e-04
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.1284e-04 - val_loss: 0.0011
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.3458e-04 - val_loss: 9.1355e-04
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.0221e-04 - val_loss: 8.2097e-04
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.9524e-04 - val_loss: 9.0352e-04
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.1314e-04 - val_loss: 0.0014
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.9812e-04 - val_loss: 9.9099e-04
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.1692e-04 - val_loss: 0.0011
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.7461e-04 - val_loss: 7.3217e-04
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 3.1499e-04 - val_loss: 8.2006e-04
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.0206e-04 - val_loss: 0.0012
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.2065e-04 - val_loss: 0.0012
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 2.9765e-04 - val_loss: 7.2516e-04
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 3.1532e-04 - val_loss: 9.5149e-04
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step
# R2: 0.9650
# MAPE: 0.0330
# RMSE: 4.7164
# RMSE_normalizeddata: 0.0308
# MAE: 3.7692

# %%
model_lstm.save(f"model_lstm_fedbk2h_{r2:.4f}.keras")

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(169, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.00398), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=30, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - loss: 0.0110 - val_loss: 9.2296e-04
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 4.1548e-04 - val_loss: 6.8966e-04
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.4113e-04 - val_loss: 6.7714e-04
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.6769e-04 - val_loss: 7.5523e-04
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.2363e-04 - val_loss: 7.7667e-04
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.0771e-04 - val_loss: 0.0010
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.0476e-04 - val_loss: 0.0029
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.7779e-04 - val_loss: 8.1261e-04
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 3.7988e-04 - val_loss: 9.5913e-04
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.0073e-04 - val_loss: 0.0016
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.0805e-04 - val_loss: 0.0012
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.6017e-04 - val_loss: 0.0017
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.0574e-04 - val_loss: 0.0010
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.3843e-04 - val_loss: 0.0019
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.2758e-04 - val_loss: 0.0013
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.4870e-04 - val_loss: 8.7993e-04
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.4362e-04 - val_loss: 0.0013
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.0557e-04 - val_loss: 0.0028
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.4270e-04 - val_loss: 0.0018
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.1944e-04 - val_loss: 0.0010
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.2149e-04 - val_loss: 0.0022
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.8682e-04 - val_loss: 0.0016
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.4492e-04 - val_loss: 0.0020
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.8976e-04 - val_loss: 8.4796e-04
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.0388e-04 - val_loss: 0.0010
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 3.0353e-04 - val_loss: 0.0013
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.7566e-04 - val_loss: 0.0022
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 2.9470e-04 - val_loss: 0.0012
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.3556e-04 - val_loss: 0.0012
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 2.9117e-04 - val_loss: 0.0014
# Epoch 31/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.4700e-04 - val_loss: 9.2273e-04
# Epoch 32/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 2.9519e-04 - val_loss: 8.2697e-04
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step
# R2: 0.9696
# MAPE: 0.0326
# RMSE: 4.3970
# RMSE_normalizeddata: 0.0288
# MAE: 3.4474

# %%
model_lstm.save(f"model_lstm_fedbk2h_{r2:.4f}.keras")
