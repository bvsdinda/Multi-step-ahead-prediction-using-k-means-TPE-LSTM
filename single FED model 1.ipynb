# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import statsmodels.api as smi
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from statistics import mean
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, SimpleRNN, GRU, Dropout, Conv1D, MaxPooling1D, Flatten, RepeatVector
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_percentage_error, mean_absolute_error
from tensorflow.keras.optimizers import Adam, Nadam, RMSprop
from statsmodels.tsa.seasonal import seasonal_decompose
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from hyperopt import hp, Trials, fmin, tpe
import joblib
import warnings
warnings.simplefilter('ignore')

# %%
df=pd.read_csv(r'E:\A aPython Programms\Data1\Bank.csv')
df.tail(5)
# Out:
#             Date     AXISBANK   AXISVOL     BAJAJFIN  BAJAJFINVOL         BOB  \
# 3748  21-03-2024  1035.599976   9903738  6715.750000      1806092  255.699997
# 3749  22-03-2024  1033.300049   9891194  6760.899902      1125238  259.799988
# 3750  26-03-2024  1040.550049   9656767  6910.100098      1850321  261.549988
# 3751  27-03-2024  1052.849976  17027308  7022.750000      1551275  258.750000
# 3752  28-03-2024  1047.199951  10235318  7245.250000      3574518  264.049988
#
#         BOBVOL     FEDBANK    FEDVOL         HDFC  ...        KOTAK  KOTAKVOL  \
# 3748  10121220  149.949997   6212045  1445.750000  ...  1772.150024   3783681
# 3749  11402546  149.600006   8409218  1442.849976  ...  1776.400024   7061283
# 3750   8259347  149.800003   7742995  1425.400024  ...  1753.699951   5303630
# 3751  19196992  149.800003  20853016  1440.699951  ...  1775.599976   8231130
# 3752  11966752  150.199997   7208707  1447.900024  ...  1785.500000   6630072
#
#              PNB    PNBVOL         SBI    SBIVOL         REC    RECVOL  \
# 3748  121.050003  38099730  744.299988  15161161  450.250000  18429233
# 3749  122.750000  35001868  746.700012  15535921  460.100006  12531582
# 3750  123.949997  30860596  740.049988  14678342  461.399994  10475524
# 3751  122.750000  42673023  733.299988  30088789  445.600006  28138339
# 3752  124.400002  29453142  752.349976  21705116  451.000000  12637899
#
#          PIRAMAL  PIRAMALVOL
# 3748  841.599976      987716
# 3749  861.500000     1618543
# 3750  858.250000     1391794
# 3751  840.200012     1344329
# 3752  849.349976     5261416
#
# [5 rows x 25 columns]

# %%
feature_columns = ['FEDBANK', 'FEDVOL']
target_column = ['FEDBANK']
features = df[feature_columns]
target = df[target_column].shift(-1)

new_data1 = 152.35
target.iloc[-1, 0] = new_data1

target.tail(5)
# Out:
#          FEDBANK
# 3748  149.600006
# 3749  149.800003
# 3750  149.800003
# 3751  150.199997
# 3752  152.350000

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_features = scaler.fit_transform(features)
scaled_target = scaler.fit_transform(target.values.reshape(-1, 1))

n_steps = 5  # Number of timesteps to look back
X, y = [], []

for i in range(n_steps, len(scaled_features)):
    X.append(scaled_features[i-n_steps:i])
    y.append(scaled_target[i])

X = np.array(X)
y = np.array(y)

split=int(0.8*len(X))
X_train, y_train= X[:split], y[:split]
X_test, y_test= X[split:], y[split:]

# %%
model_lstm = load_model('model_lstm_fed1_0.9861.keras')
model_lstm.predict(X_test)

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae_n=mean_absolute_error(y_test, predictions_lstm)
print(f"MAE_normalizeddata: {mae_n:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# R2: 0.9861
# MAPE: 0.0197
# RMSE: 2.9711
# RMSE_normalizeddata: 0.0194
# MAE_normalizeddata: 0.0143
# MAE: 2.1893

# %%
plt.figure(figsize=(9, 6))
plt.plot(y_test_actual_LSTM, color='green', label=['Actual Price'])
plt.plot(predictions_LSTM, color='red', label=['Predicted Price'])
plt.legend(['Actual Price', 'Predicted Price'], loc='upper left')

plt.text(0.75, 0.1, f'R2: {r2:.4f}\nMAPE: {mape:.4f}%\nRMSE: {rmse:.4f}\nMAE: {mae:.4f}', 
         fontsize=12, 
         bbox=dict(facecolor='white', alpha=0.5),
         transform=plt.gca().transAxes)

plt.grid(True)
plt.title('FEDBANK single model (1 step ahead)')
plt.xlabel('Time Step')
plt.ylabel('Actual vs Predicted Price')
plt.savefig('fed_1da1l.png', dpi=600)  # Saves the plot as a PNG file
plt.show()

# %%
model_lstm.predict(X_train)

predictions_train_lstm = model_lstm.predict(X_train)
predictions_train_LSTM = scaler.inverse_transform(predictions_train_lstm)
y_train_actual_LSTM = scaler.inverse_transform(y_train.reshape(-1, 1))

r2=r2_score(y_train_actual_LSTM, predictions_train_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_train_actual_LSTM, predictions_train_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_train_actual_LSTM, predictions_train_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_train, predictions_train_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae_n=mean_absolute_error(y_train, predictions_train_lstm)
print(f"MAE_normalizeddata: {mae_n:.4f}")

mae=mean_absolute_error(y_train_actual_LSTM, predictions_train_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# R2: 0.9928
# MAPE: 0.0281
# RMSE: 2.1981
# RMSE_normalizeddata: 0.0144
# MAE_normalizeddata: 0.0101
# MAE: 1.5476

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(169, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.00398), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=30, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0111 - val_loss: 6.6811e-04
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.6157e-04 - val_loss: 5.6051e-04
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.7285e-04 - val_loss: 0.0017
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.4597e-04 - val_loss: 5.5651e-04
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.3577e-04 - val_loss: 5.8314e-04
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.5748e-04 - val_loss: 0.0010
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.9450e-04 - val_loss: 5.4157e-04
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.8691e-04 - val_loss: 8.1954e-04
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.4501e-04 - val_loss: 7.2090e-04
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.7587e-04 - val_loss: 5.6724e-04
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.9171e-04 - val_loss: 6.3995e-04
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.7066e-04 - val_loss: 0.0010
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.3512e-04 - val_loss: 5.1016e-04
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.6550e-04 - val_loss: 0.0011
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.5909e-04 - val_loss: 6.9220e-04
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.3193e-04 - val_loss: 9.1496e-04
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.3111e-04 - val_loss: 9.8335e-04
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.3093e-04 - val_loss: 9.1901e-04
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.4875e-04 - val_loss: 6.1862e-04
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.3527e-04 - val_loss: 5.7207e-04
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.2281e-04 - val_loss: 9.6175e-04
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.1327e-04 - val_loss: 6.4301e-04
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.9072e-04 - val_loss: 6.8576e-04
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.0163e-04 - val_loss: 5.8338e-04
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.8297e-04 - val_loss: 6.0420e-04
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.0953e-04 - val_loss: 7.9967e-04
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.8880e-04 - val_loss: 6.1908e-04
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.9564e-04 - val_loss: 6.8797e-04
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.0309e-04 - val_loss: 8.6392e-04
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.3362e-04 - val_loss: 5.4495e-04
# Epoch 31/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.8186e-04 - val_loss: 0.0010
# Epoch 32/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.9901e-04 - val_loss: 6.2091e-04
# Epoch 33/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.1267e-04 - val_loss: 0.0010
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# R2: 0.9624
# MAPE: 0.0326
# RMSE: 4.8872
# RMSE_normalizeddata: 0.0320
# MAE: 3.9251

# %%
model_lstm.save(f"model_lstm_fedbk1h_{r2:.4f}.keras")

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(169, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.00398), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=30, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.0144 - val_loss: 8.0247e-04
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.4279e-04 - val_loss: 6.1998e-04
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.6142e-04 - val_loss: 7.5068e-04
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.7222e-04 - val_loss: 5.4513e-04
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.2575e-04 - val_loss: 0.0012
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.4248e-04 - val_loss: 8.2093e-04
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.9106e-04 - val_loss: 5.9055e-04
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.1862e-04 - val_loss: 5.4531e-04
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.1653e-04 - val_loss: 5.0087e-04
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.0949e-04 - val_loss: 6.1967e-04
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.7469e-04 - val_loss: 6.0430e-04
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.8061e-04 - val_loss: 0.0012
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.8847e-04 - val_loss: 8.2222e-04
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.4041e-04 - val_loss: 6.1371e-04
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.4618e-04 - val_loss: 0.0010
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.4100e-04 - val_loss: 6.8730e-04
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.4931e-04 - val_loss: 5.7960e-04
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.5398e-04 - val_loss: 7.0519e-04
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.4461e-04 - val_loss: 8.7607e-04
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.4385e-04 - val_loss: 0.0018
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.5158e-04 - val_loss: 0.0010
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.2408e-04 - val_loss: 7.5827e-04
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.1092e-04 - val_loss: 7.6381e-04
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.1425e-04 - val_loss: 7.1812e-04
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.2299e-04 - val_loss: 6.8222e-04
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.1868e-04 - val_loss: 6.5010e-04
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.2813e-04 - val_loss: 0.0012
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.9797e-04 - val_loss: 9.2681e-04
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.1109e-04 - val_loss: 0.0015
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.0237e-04 - val_loss: 7.9778e-04
# Epoch 31/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.1175e-04 - val_loss: 6.3345e-04
# Epoch 32/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.0114e-04 - val_loss: 6.4532e-04
# Epoch 33/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.0363e-04 - val_loss: 0.0013
# Epoch 34/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.0470e-04 - val_loss: 0.0019
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# R2: 0.9289
# MAPE: 0.0452
# RMSE: 6.7219
# RMSE_normalizeddata: 0.0440
# MAE: 5.5857

# %%
model_lstm.save(f"model_lstm_fedbk1h_{r2:.4f}.keras")

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(169, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.00398), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=30, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - loss: 0.0154 - val_loss: 5.6699e-04
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 3.4122e-04 - val_loss: 0.0017
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.8158e-04 - val_loss: 6.8301e-04
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.3785e-04 - val_loss: 6.2543e-04
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.9391e-04 - val_loss: 0.0010
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.9931e-04 - val_loss: 0.0014
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.9308e-04 - val_loss: 5.9576e-04
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.7420e-04 - val_loss: 0.0034
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.4845e-04 - val_loss: 6.4385e-04
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.7507e-04 - val_loss: 5.6415e-04
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.8493e-04 - val_loss: 5.9909e-04
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.3932e-04 - val_loss: 5.9183e-04
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.3608e-04 - val_loss: 5.8296e-04
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.6885e-04 - val_loss: 8.0894e-04
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.1687e-04 - val_loss: 5.1059e-04
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.2418e-04 - val_loss: 0.0014
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.2448e-04 - val_loss: 5.0991e-04
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 2.3250e-04 - val_loss: 6.9606e-04
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.4596e-04 - val_loss: 6.6087e-04
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 2.1878e-04 - val_loss: 4.6220e-04
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 2.0516e-04 - val_loss: 0.0010
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 2.1548e-04 - val_loss: 5.7135e-04
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.9776e-04 - val_loss: 4.9632e-04
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.9453e-04 - val_loss: 5.3322e-04
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.0852e-04 - val_loss: 3.8554e-04
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.0350e-04 - val_loss: 7.0699e-04
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 2.2447e-04 - val_loss: 7.5944e-04
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 2.0063e-04 - val_loss: 5.9354e-04
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 2.0848e-04 - val_loss: 4.9668e-04
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 2.0937e-04 - val_loss: 7.2404e-04
# Epoch 31/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.1674e-04 - val_loss: 0.0012
# Epoch 32/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.9768e-04 - val_loss: 4.5750e-04
# Epoch 33/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 2.1461e-04 - val_loss: 6.0357e-04
# Epoch 34/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 2.0631e-04 - val_loss: 4.7761e-04
# Epoch 35/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.9426e-04 - val_loss: 8.2586e-04
# Epoch 36/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 2.1235e-04 - val_loss: 6.2701e-04
# Epoch 37/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 2.1971e-04 - val_loss: 4.7246e-04
# Epoch 38/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 2.1628e-04 - val_loss: 5.7693e-04
# Epoch 39/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.0223e-04 - val_loss: 6.4690e-04
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step
# R2: 0.9762
# MAPE: 0.0296
# RMSE: 3.8889
# RMSE_normalizeddata: 0.0254
# MAE: 3.0745

# %%
model_lstm.save(f"model_lstm_fedbk1h_{r2:.4f}.keras")

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(169, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.00398), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=30, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - loss: 0.0126 - val_loss: 7.1617e-04
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.6836e-04 - val_loss: 6.0196e-04
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.9661e-04 - val_loss: 6.5076e-04
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.2909e-04 - val_loss: 0.0013
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.1258e-04 - val_loss: 8.1177e-04
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.5660e-04 - val_loss: 7.0211e-04
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.1177e-04 - val_loss: 0.0018
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.4885e-04 - val_loss: 7.6043e-04
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.8049e-04 - val_loss: 0.0013
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.6386e-04 - val_loss: 5.5746e-04
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.6197e-04 - val_loss: 4.9460e-04
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.4958e-04 - val_loss: 0.0014
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.8525e-04 - val_loss: 9.5748e-04
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.3964e-04 - val_loss: 0.0016
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.4898e-04 - val_loss: 8.2795e-04
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.5659e-04 - val_loss: 5.6896e-04
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.2628e-04 - val_loss: 0.0010
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.4799e-04 - val_loss: 7.1917e-04
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.2138e-04 - val_loss: 8.7817e-04
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 2.3429e-04 - val_loss: 5.0168e-04
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 2.2584e-04 - val_loss: 5.9071e-04
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.2862e-04 - val_loss: 0.0017
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.0428e-04 - val_loss: 0.0012
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.9165e-04 - val_loss: 7.2413e-04
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.2066e-04 - val_loss: 0.0015
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 2.0220e-04 - val_loss: 7.6086e-04
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.9535e-04 - val_loss: 7.9313e-04
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.9622e-04 - val_loss: 8.0950e-04
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 1.8682e-04 - val_loss: 9.1163e-04
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.2320e-04 - val_loss: 6.7189e-04
# Epoch 31/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 2.0935e-04 - val_loss: 8.2755e-04
# Epoch 32/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 2.2254e-04 - val_loss: 7.1242e-04
# Epoch 33/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 2.2310e-04 - val_loss: 8.7554e-04
# Epoch 34/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.8429e-04 - val_loss: 0.0016
# Epoch 35/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.9265e-04 - val_loss: 0.0015
# Epoch 36/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 1.8684e-04 - val_loss: 0.0018
# Epoch 37/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 2.1929e-04 - val_loss: 0.0010
# Epoch 38/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 1.9673e-04 - val_loss: 0.0012
# Epoch 39/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.0254e-04 - val_loss: 7.5019e-04
# Epoch 40/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.0947e-04 - val_loss: 8.7849e-04
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step
# R2: 0.9677
# MAPE: 0.0311
# RMSE: 4.5319
# RMSE_normalizeddata: 0.0296
# MAE: 3.6446

# %%
model_lstm.save(f"model_lstm_fedbk1h_{r2:.4f}.keras")

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(169, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.00398), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=30, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - loss: 0.0131 - val_loss: 0.0011
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.5496e-04 - val_loss: 0.0021
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.9968e-04 - val_loss: 8.8021e-04
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.6276e-04 - val_loss: 0.0011
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.2852e-04 - val_loss: 6.3676e-04
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.5685e-04 - val_loss: 5.6526e-04
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.9661e-04 - val_loss: 7.3811e-04
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.8328e-04 - val_loss: 6.5190e-04
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.8799e-04 - val_loss: 5.4586e-04
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.8421e-04 - val_loss: 6.9005e-04
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.6038e-04 - val_loss: 5.9589e-04
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.2776e-04 - val_loss: 0.0013
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.6650e-04 - val_loss: 5.5802e-04
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.7930e-04 - val_loss: 6.4606e-04
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.4574e-04 - val_loss: 0.0010
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.0653e-04 - val_loss: 6.4441e-04
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.1389e-04 - val_loss: 4.9072e-04
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.1200e-04 - val_loss: 8.9570e-04
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.1537e-04 - val_loss: 5.6375e-04
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 2.2324e-04 - val_loss: 5.2080e-04
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 2.0783e-04 - val_loss: 0.0013
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.3579e-04 - val_loss: 6.3901e-04
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 2.1251e-04 - val_loss: 4.9777e-04
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 2.3113e-04 - val_loss: 5.0954e-04
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 2.0590e-04 - val_loss: 4.7317e-04
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.8042e-04 - val_loss: 7.8655e-04
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.0927e-04 - val_loss: 5.7731e-04
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.9450e-04 - val_loss: 7.0587e-04
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 2.2624e-04 - val_loss: 6.9219e-04
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 2.0207e-04 - val_loss: 6.4072e-04
# Epoch 31/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.9676e-04 - val_loss: 7.8132e-04
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step
# R2: 0.9713
# MAPE: 0.0334
# RMSE: 4.2739
# RMSE_normalizeddata: 0.0280
# MAE: 3.4033

# %%
model_lstm.save(f"model_lstm_fedbk1h_{r2:.4f}.keras")

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(169, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.00398), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=30, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - loss: 0.0097 - val_loss: 0.0018
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.9354e-04 - val_loss: 0.0012
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.4499e-04 - val_loss: 6.4077e-04
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.6901e-04 - val_loss: 7.1140e-04
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.5559e-04 - val_loss: 6.2850e-04
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.2323e-04 - val_loss: 6.6581e-04
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.0492e-04 - val_loss: 0.0014
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.1721e-04 - val_loss: 6.0862e-04
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.0808e-04 - val_loss: 9.9875e-04
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.8585e-04 - val_loss: 6.9861e-04
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.7108e-04 - val_loss: 9.4364e-04
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.9721e-04 - val_loss: 7.7884e-04
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.5959e-04 - val_loss: 7.3172e-04
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.5035e-04 - val_loss: 8.9983e-04
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.5087e-04 - val_loss: 7.3969e-04
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.3891e-04 - val_loss: 7.2518e-04
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.3349e-04 - val_loss: 6.3587e-04
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.1493e-04 - val_loss: 5.4484e-04
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.4446e-04 - val_loss: 7.5537e-04
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.2209e-04 - val_loss: 9.0618e-04
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.2273e-04 - val_loss: 7.1541e-04
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.1915e-04 - val_loss: 0.0014
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.2342e-04 - val_loss: 5.3209e-04
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.0942e-04 - val_loss: 5.4550e-04
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.1487e-04 - val_loss: 7.2973e-04
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.0774e-04 - val_loss: 0.0014
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.3357e-04 - val_loss: 8.0079e-04
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.2120e-04 - val_loss: 0.0013
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.0810e-04 - val_loss: 0.0011
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.1714e-04 - val_loss: 6.4019e-04
# Epoch 31/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.3491e-04 - val_loss: 0.0011
# Epoch 32/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.1539e-04 - val_loss: 5.9193e-04
# Epoch 33/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.8822e-04 - val_loss: 5.9004e-04
# Epoch 34/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.9597e-04 - val_loss: 0.0017
# Epoch 35/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.1808e-04 - val_loss: 6.2910e-04
# Epoch 36/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.1317e-04 - val_loss: 5.8386e-04
# Epoch 37/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.9309e-04 - val_loss: 0.0013
# Epoch 38/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.9796e-04 - val_loss: 6.7596e-04
# Epoch 39/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 2.1137e-04 - val_loss: 6.4181e-04
# Epoch 40/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 2.1369e-04 - val_loss: 9.0262e-04
# Epoch 41/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.9405e-04 - val_loss: 0.0011
# Epoch 42/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.9540e-04 - val_loss: 6.2096e-04
# Epoch 43/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 2.0820e-04 - val_loss: 0.0012
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step
# R2: 0.9569
# MAPE: 0.0350
# RMSE: 5.2348
# RMSE_normalizeddata: 0.0342
# MAE: 4.2293

# %%
model_lstm.save(f"model_lstm_fedbk1h_{r2:.4f}.keras")

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(169, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.00398), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=30, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - loss: 0.0149 - val_loss: 0.0010
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.4597e-04 - val_loss: 0.0015
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.0730e-04 - val_loss: 7.2388e-04
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.2706e-04 - val_loss: 0.0013
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.3331e-04 - val_loss: 0.0012
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.6312e-04 - val_loss: 4.9603e-04
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.7968e-04 - val_loss: 4.8165e-04
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.3500e-04 - val_loss: 4.8399e-04
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 2.5436e-04 - val_loss: 5.1432e-04
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 2.7198e-04 - val_loss: 7.2178e-04
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.6866e-04 - val_loss: 7.3953e-04
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.8019e-04 - val_loss: 5.5416e-04
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.6365e-04 - val_loss: 7.9514e-04
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.4743e-04 - val_loss: 5.4367e-04
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.4092e-04 - val_loss: 0.0011
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.5539e-04 - val_loss: 0.0013
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.3661e-04 - val_loss: 5.7119e-04
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.1308e-04 - val_loss: 9.1542e-04
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.3058e-04 - val_loss: 4.4194e-04
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.2922e-04 - val_loss: 4.5610e-04
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.5403e-04 - val_loss: 5.9207e-04
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.9525e-04 - val_loss: 8.8831e-04
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.2362e-04 - val_loss: 9.3277e-04
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.2370e-04 - val_loss: 6.4578e-04
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.0874e-04 - val_loss: 0.0014
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.4568e-04 - val_loss: 6.5091e-04
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.0558e-04 - val_loss: 4.8279e-04
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 2.0977e-04 - val_loss: 4.8709e-04
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.9528e-04 - val_loss: 6.1231e-04
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.9160e-04 - val_loss: 6.6868e-04
# Epoch 31/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.9881e-04 - val_loss: 5.2364e-04
# Epoch 32/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.9700e-04 - val_loss: 0.0016
# Epoch 33/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.4077e-04 - val_loss: 9.2056e-04
# Epoch 34/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 2.0634e-04 - val_loss: 5.2570e-04
# Epoch 35/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.0218e-04 - val_loss: 5.4462e-04
# Epoch 36/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.1706e-04 - val_loss: 6.3996e-04
# Epoch 37/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.8896e-04 - val_loss: 8.2388e-04
# Epoch 38/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.0559e-04 - val_loss: 6.0617e-04
# Epoch 39/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.2623e-04 - val_loss: 0.0012
# Epoch 40/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 2.0530e-04 - val_loss: 7.6465e-04
# Epoch 41/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.9320e-04 - val_loss: 8.4784e-04
# Epoch 42/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.1654e-04 - val_loss: 5.3002e-04
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# R2: 0.9805
# MAPE: 0.0241
# RMSE: 3.5201
# RMSE_normalizeddata: 0.0230
# MAE: 2.7268

# %%
model_lstm.save(f"model_lstm_fedbk1h_{r2:.4f}.keras")

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(169, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.00398), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=30, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - loss: 0.0135 - val_loss: 8.8919e-04
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 3.2779e-04 - val_loss: 0.0014
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 3.5593e-04 - val_loss: 7.4181e-04
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 3.8977e-04 - val_loss: 7.1948e-04
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 2.9662e-04 - val_loss: 0.0012
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 3.2598e-04 - val_loss: 6.1731e-04
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 3.5649e-04 - val_loss: 6.4758e-04
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 3.1758e-04 - val_loss: 5.8147e-04
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.5608e-04 - val_loss: 5.5116e-04
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 2.4249e-04 - val_loss: 6.2057e-04
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.7040e-04 - val_loss: 5.3689e-04
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.0050e-04 - val_loss: 7.8311e-04
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.2675e-04 - val_loss: 5.3428e-04
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.3938e-04 - val_loss: 0.0014
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.7361e-04 - val_loss: 6.2491e-04
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.8868e-04 - val_loss: 8.5487e-04
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.4410e-04 - val_loss: 5.5444e-04
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.2661e-04 - val_loss: 5.7201e-04
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.2129e-04 - val_loss: 9.5248e-04
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.1181e-04 - val_loss: 8.0425e-04
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.2725e-04 - val_loss: 5.0652e-04
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.4629e-04 - val_loss: 0.0014
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.0950e-04 - val_loss: 5.7618e-04
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 1.9388e-04 - val_loss: 5.9254e-04
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.0427e-04 - val_loss: 5.9390e-04
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step
# R2: 0.9782
# MAPE: 0.0257
# RMSE: 3.7262
# RMSE_normalizeddata: 0.0244
# MAE: 2.9222

# %%
model_lstm.save(f"model_lstm_fedbk1h_{r2:.4f}.keras")

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(169, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.00398), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=30, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - loss: 0.0130 - val_loss: 7.9250e-04
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.6846e-04 - val_loss: 6.0132e-04
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.4141e-04 - val_loss: 0.0017
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.3944e-04 - val_loss: 5.5122e-04
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.1212e-04 - val_loss: 5.0392e-04
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.1568e-04 - val_loss: 8.6475e-04
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.1395e-04 - val_loss: 5.1389e-04
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 2.9500e-04 - val_loss: 4.8641e-04
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 2.9906e-04 - val_loss: 4.5704e-04
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.6415e-04 - val_loss: 4.3398e-04
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.7956e-04 - val_loss: 4.5765e-04
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.7005e-04 - val_loss: 5.8252e-04
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.8537e-04 - val_loss: 0.0016
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.8391e-04 - val_loss: 6.1594e-04
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.6051e-04 - val_loss: 0.0014
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 2.4938e-04 - val_loss: 5.5092e-04
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 2.4310e-04 - val_loss: 6.3682e-04
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.3270e-04 - val_loss: 6.7472e-04
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.3606e-04 - val_loss: 5.8104e-04
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.1283e-04 - val_loss: 0.0013
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 2.6117e-04 - val_loss: 6.0686e-04
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.0516e-04 - val_loss: 5.6923e-04
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.3858e-04 - val_loss: 5.7264e-04
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.2585e-04 - val_loss: 0.0011
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.2578e-04 - val_loss: 0.0014
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.0989e-04 - val_loss: 0.0013
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.2129e-04 - val_loss: 0.0016
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.1355e-04 - val_loss: 7.8425e-04
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.0638e-04 - val_loss: 9.2284e-04
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.1823e-04 - val_loss: 5.8906e-04
# Epoch 31/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.0309e-04 - val_loss: 4.8738e-04
# Epoch 32/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.9250e-04 - val_loss: 5.0766e-04
# Epoch 33/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.0436e-04 - val_loss: 4.6896e-04
# Epoch 34/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.2155e-04 - val_loss: 8.3317e-04
# Epoch 35/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.8396e-04 - val_loss: 7.8313e-04
# Epoch 36/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.9334e-04 - val_loss: 6.3191e-04
# Epoch 37/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.8627e-04 - val_loss: 0.0010
# Epoch 38/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.9912e-04 - val_loss: 6.9037e-04
# Epoch 39/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.0602e-04 - val_loss: 5.3860e-04
# Epoch 40/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.8653e-04 - val_loss: 4.7400e-04
# Epoch 41/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 2.1256e-04 - val_loss: 6.7608e-04
# Epoch 42/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.1660e-04 - val_loss: 8.0480e-04
# Epoch 43/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.1907e-04 - val_loss: 5.8870e-04
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step
# R2: 0.9784
# MAPE: 0.0269
# RMSE: 3.7098
# RMSE_normalizeddata: 0.0243
# MAE: 2.9411

# %%
model_lstm.save(f"model_lstm_fedbk1h_{r2:.4f}.keras")

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(169, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.00398), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=30, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - loss: 0.0134 - val_loss: 7.5143e-04
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.7107e-04 - val_loss: 7.3314e-04
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.3855e-04 - val_loss: 9.8944e-04
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.5123e-04 - val_loss: 0.0022
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.1501e-04 - val_loss: 6.8066e-04
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 3.3197e-04 - val_loss: 0.0030
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 3.3121e-04 - val_loss: 6.3924e-04
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 2.9634e-04 - val_loss: 5.1334e-04
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 2.9751e-04 - val_loss: 4.9562e-04
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.8960e-04 - val_loss: 4.9839e-04
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.9971e-04 - val_loss: 6.6392e-04
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.9209e-04 - val_loss: 6.8091e-04
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 2.8148e-04 - val_loss: 8.4194e-04
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.6451e-04 - val_loss: 0.0011
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.4063e-04 - val_loss: 5.4150e-04
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.5238e-04 - val_loss: 7.3170e-04
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.4130e-04 - val_loss: 0.0034
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.8307e-04 - val_loss: 0.0013
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.3933e-04 - val_loss: 8.1773e-04
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.2876e-04 - val_loss: 6.4373e-04
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.1536e-04 - val_loss: 5.5257e-04
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.2834e-04 - val_loss: 4.6869e-04
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.2586e-04 - val_loss: 6.3022e-04
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.0808e-04 - val_loss: 6.1218e-04
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.0971e-04 - val_loss: 5.6444e-04
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.1957e-04 - val_loss: 0.0013
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.9266e-04 - val_loss: 8.6383e-04
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.3035e-04 - val_loss: 5.2231e-04
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.2336e-04 - val_loss: 5.0836e-04
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.1093e-04 - val_loss: 9.5817e-04
# Epoch 31/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.0423e-04 - val_loss: 5.6962e-04
# Epoch 32/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.1017e-04 - val_loss: 0.0011
# Epoch 33/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.1147e-04 - val_loss: 5.7560e-04
# Epoch 34/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.0717e-04 - val_loss: 4.4374e-04
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# R2: 0.9837
# MAPE: 0.0220
# RMSE: 3.2208
# RMSE_normalizeddata: 0.0211
# MAE: 2.4598

# %%
model_lstm.save(f"model_lstm_fedbk1h_{r2:.4f}.keras")
