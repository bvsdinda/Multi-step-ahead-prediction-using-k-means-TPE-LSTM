# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import statsmodels.api as smi
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from statistics import mean
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, SimpleRNN, GRU, Dropout, Conv1D, MaxPooling1D, Flatten, RepeatVector
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_percentage_error, mean_absolute_error
from tensorflow.keras.optimizers import Adam, Nadam, RMSprop
from statsmodels.tsa.seasonal import seasonal_decompose
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from hyperopt import hp, Trials, fmin, tpe
import joblib
import warnings
warnings.simplefilter('ignore')

# %%
df=pd.read_csv(r'E:\A aPython Programms\Data1\Bank.csv')
df.tail(5)
# Out:
#             Date     AXISBANK   AXISVOL     BAJAJFIN  BAJAJFINVOL         BOB  \
# 3748  21-03-2024  1035.599976   9903738  6715.750000      1806092  255.699997
# 3749  22-03-2024  1033.300049   9891194  6760.899902      1125238  259.799988
# 3750  26-03-2024  1040.550049   9656767  6910.100098      1850321  261.549988
# 3751  27-03-2024  1052.849976  17027308  7022.750000      1551275  258.750000
# 3752  28-03-2024  1047.199951  10235318  7245.250000      3574518  264.049988
#
#         BOBVOL     FEDBANK    FEDVOL         HDFC  ...        KOTAK  KOTAKVOL  \
# 3748  10121220  149.949997   6212045  1445.750000  ...  1772.150024   3783681
# 3749  11402546  149.600006   8409218  1442.849976  ...  1776.400024   7061283
# 3750   8259347  149.800003   7742995  1425.400024  ...  1753.699951   5303630
# 3751  19196992  149.800003  20853016  1440.699951  ...  1775.599976   8231130
# 3752  11966752  150.199997   7208707  1447.900024  ...  1785.500000   6630072
#
#              PNB    PNBVOL         SBI    SBIVOL         REC    RECVOL  \
# 3748  121.050003  38099730  744.299988  15161161  450.250000  18429233
# 3749  122.750000  35001868  746.700012  15535921  460.100006  12531582
# 3750  123.949997  30860596  740.049988  14678342  461.399994  10475524
# 3751  122.750000  42673023  733.299988  30088789  445.600006  28138339
# 3752  124.400002  29453142  752.349976  21705116  451.000000  12637899
#
#          PIRAMAL  PIRAMALVOL
# 3748  841.599976      987716
# 3749  861.500000     1618543
# 3750  858.250000     1391794
# 3751  840.200012     1344329
# 3752  849.349976     5261416
#
# [5 rows x 25 columns]

# %%
feature_columns = [ 'SBI', 'SBIVOL', 'BAJAJFIN', 'FEDBANK', 'ICICI']
target_column = ['SBI']
features = df[feature_columns]
target = df[target_column].shift(-5)

new_data1 = 758.30
target.iloc[-5, 0] = new_data1

new_data2 = 766.40
target.iloc[-4, 0] = new_data2

new_data3 = 771.05
target.iloc[-3, 0] = new_data3

new_data4 = 759.30
target.iloc[-2, 0] = new_data4

new_data5 = 764.75
target.iloc[-1, 0] = new_data5

target.tail(5)
# Out:
#          SBI
# 3748  758.30
# 3749  766.40
# 3750  771.05
# 3751  759.30
# 3752  764.75

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_features = scaler.fit_transform(features)
scaled_target = scaler.fit_transform(target.values.reshape(-1, 1))

n_steps = 5  # Number of timesteps to look back
X, y = [], []

for i in range(n_steps, len(scaled_features)):
    X.append(scaled_features[i-n_steps:i])
    y.append(scaled_target[i])

X = np.array(X)
y = np.array(y)

split=int(0.8*len(X))
X_train, y_train= X[:split], y[:split]
X_test, y_test= X[split:], y[split:]

# %%
model_lstm = load_model('model_lstm_sbi5h_0.9324.keras')
model_lstm.predict(X_test)

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae_n=mean_absolute_error(y_test, predictions_lstm)
print(f"MAE_normalizeddata: {mae_n:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# R2: 0.9324
# MAPE: 0.0330
# RMSE: 22.7755
# RMSE_normalizeddata: 0.0326
# MAE_normalizeddata: 0.0254
# MAE: 17.7737

# %%
plt.figure(figsize=(9, 6))
plt.plot(y_test_actual_LSTM, color='green', label=['Actual Price'])
plt.plot(predictions_LSTM, color='red', label=['Predicted Price'])
plt.legend(['Actual Price', 'Predicted Price'], loc='upper left')

plt.text(0.75, 0.1, f'R2: {r2:.4f}\nMAPE: {mape:.4f}%\nRMSE: {rmse:.4f}\nMAE: {mae:.4f}', 
         fontsize=12, 
         bbox=dict(facecolor='white', alpha=0.5),
         transform=plt.gca().transAxes)

plt.grid(True)
plt.title('SBI cluster model (5 step ahead)')
plt.xlabel('Time Step')
plt.ylabel('Actual vs Predicted Price')
plt.savefig('sbicluster_5sa-1l.jpg', dpi=600)  # Saves the plot as a PNG file
plt.show()

# %%
model_lstm.predict(X_train)

predictions_train_lstm = model_lstm.predict(X_train)
predictions_train_LSTM = scaler.inverse_transform(predictions_train_lstm)
y_train_actual_LSTM = scaler.inverse_transform(y_train.reshape(-1, 1))

r2=r2_score(y_train_actual_LSTM, predictions_train_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_train_actual_LSTM, predictions_train_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_train_actual_LSTM, predictions_train_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_train, predictions_train_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae_n=mean_absolute_error(y_train, predictions_train_lstm)
print(f"MAE_normalizeddata: {mae_n:.4f}")

mae=mean_absolute_error(y_train_actual_LSTM, predictions_train_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# R2: 0.9387
# MAPE: 0.0436
# RMSE: 13.4291
# RMSE_normalizeddata: 0.0192
# MAE_normalizeddata: 0.0145
# MAE: 10.1144

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(169, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.00398), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=30, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - loss: 0.0054 - val_loss: 0.0027
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.4628e-04 - val_loss: 0.0012
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.6894e-04 - val_loss: 0.0039
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.2091e-04 - val_loss: 0.0051
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 4.6256e-04 - val_loss: 0.0012
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.6645e-04 - val_loss: 0.0044
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 4.1866e-04 - val_loss: 0.0048
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.0914e-04 - val_loss: 0.0014
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.7173e-04 - val_loss: 0.0038
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.1135e-04 - val_loss: 0.0034
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.5235e-04 - val_loss: 0.0022
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.0142e-04 - val_loss: 0.0048
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.1053e-04 - val_loss: 0.0028
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.0578e-04 - val_loss: 0.0015
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.1344e-04 - val_loss: 0.0030
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.6657e-04 - val_loss: 0.0044
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.3806e-04 - val_loss: 0.0031
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.7778e-04 - val_loss: 0.0078
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.9121e-04 - val_loss: 0.0029
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.9148e-04 - val_loss: 0.0021
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.0325e-04 - val_loss: 0.0013
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.1333e-04 - val_loss: 0.0059
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.6766e-04 - val_loss: 0.0039
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.7901e-04 - val_loss: 0.0033
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.1708e-04 - val_loss: 0.0053
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.9451e-04 - val_loss: 0.0036
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.7957e-04 - val_loss: 0.0037
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.0326e-04 - val_loss: 0.0026
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.8389e-04 - val_loss: 0.0053
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.8447e-04 - val_loss: 0.0042
# Epoch 31/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.0980e-04 - val_loss: 0.0044
# Epoch 32/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.8869e-04 - val_loss: 0.0088
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# R2: 0.4399
# MAPE: 0.1089
# RMSE: 65.5550
# RMSE_normalizeddata: 0.0938
# MAE: 59.8111

# %%
model_lstm.save('model_lstm_SBI5H_1.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(169, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.00398), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=30, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0063 - val_loss: 0.0014
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.0362e-04 - val_loss: 0.0013
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.6151e-04 - val_loss: 0.0055
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.9972e-04 - val_loss: 0.0016
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.8498e-04 - val_loss: 0.0022
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.5331e-04 - val_loss: 0.0015
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.7436e-04 - val_loss: 0.0012
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.5429e-04 - val_loss: 0.0060
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 4.6752e-04 - val_loss: 0.0021
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.6214e-04 - val_loss: 0.0015
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.1303e-04 - val_loss: 0.0014
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.6684e-04 - val_loss: 0.0029
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.1069e-04 - val_loss: 0.0031
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.1943e-04 - val_loss: 0.0014
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.0953e-04 - val_loss: 0.0019
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.0225e-04 - val_loss: 0.0026
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.1053e-04 - val_loss: 0.0024
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.8564e-04 - val_loss: 0.0021
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.2932e-04 - val_loss: 0.0027
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.0056e-04 - val_loss: 0.0030
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.6105e-04 - val_loss: 0.0019
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.7113e-04 - val_loss: 0.0020
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 4.1609e-04 - val_loss: 0.0037
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.7858e-04 - val_loss: 0.0032
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.8566e-04 - val_loss: 0.0017
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.7816e-04 - val_loss: 0.0023
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.6950e-04 - val_loss: 0.0029
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.7171e-04 - val_loss: 0.0024
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.7919e-04 - val_loss: 0.0035
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.0133e-04 - val_loss: 0.0049
# Epoch 31/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.8430e-04 - val_loss: 0.0020
# Epoch 32/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.6203e-04 - val_loss: 0.0021
# Epoch 33/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.6414e-04 - val_loss: 0.0028
# Epoch 34/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.3318e-04 - val_loss: 0.0034
# Epoch 35/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.4617e-04 - val_loss: 0.0018
# Epoch 36/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.7530e-04 - val_loss: 0.0038
# Epoch 37/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.0958e-04 - val_loss: 0.0045
# Epoch 38/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.7698e-04 - val_loss: 0.0032
# Epoch 39/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.8085e-04 - val_loss: 0.0050
# Epoch 40/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.5511e-04 - val_loss: 0.0033
# Epoch 41/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.7530e-04 - val_loss: 0.0026
# Epoch 42/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.5676e-04 - val_loss: 0.0060
# Epoch 43/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.5046e-04 - val_loss: 0.0039
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
# R2: 0.7499
# MAPE: 0.0692
# RMSE: 43.8057
# RMSE_normalizeddata: 0.0627
# MAE: 38.0289

# %%
model_lstm.save('model_lstm_SBI5H_2.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(169, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.00398), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=30, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - loss: 0.0037 - val_loss: 0.0014
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.4942e-04 - val_loss: 0.0029
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.2592e-04 - val_loss: 0.0011
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.8111e-04 - val_loss: 0.0027
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.3485e-04 - val_loss: 0.0018
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.5338e-04 - val_loss: 0.0016
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.4216e-04 - val_loss: 0.0011
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.5191e-04 - val_loss: 0.0010
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.2014e-04 - val_loss: 0.0017
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.3220e-04 - val_loss: 0.0011
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.3791e-04 - val_loss: 0.0013
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.4646e-04 - val_loss: 0.0049
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.3552e-04 - val_loss: 0.0039
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 3.7957e-04 - val_loss: 0.0037
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.4582e-04 - val_loss: 0.0020
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.2387e-04 - val_loss: 0.0040
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.9197e-04 - val_loss: 0.0015
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.9174e-04 - val_loss: 0.0057
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.9615e-04 - val_loss: 0.0020
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.9721e-04 - val_loss: 8.8094e-04
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.8711e-04 - val_loss: 0.0032
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.9319e-04 - val_loss: 0.0035
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.1113e-04 - val_loss: 0.0018
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.6809e-04 - val_loss: 0.0027
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.7186e-04 - val_loss: 0.0021
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.9913e-04 - val_loss: 0.0058
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.8625e-04 - val_loss: 0.0033
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 3.9161e-04 - val_loss: 0.0035
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.8273e-04 - val_loss: 0.0059
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.6897e-04 - val_loss: 0.0050
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step
# R2: 0.6819
# MAPE: 0.0758
# RMSE: 49.4002
# RMSE_normalizeddata: 0.0707
# MAE: 42.2832

# %%
model_lstm.save('model_lstm_SBI5h_3.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(169, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.00398), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=30, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - loss: 0.0050 - val_loss: 0.0018
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.0058e-04 - val_loss: 0.0018
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.6247e-04 - val_loss: 0.0011
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.5086e-04 - val_loss: 0.0030
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.0679e-04 - val_loss: 0.0029
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.2212e-04 - val_loss: 0.0011
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 4.4978e-04 - val_loss: 0.0067
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 4.5993e-04 - val_loss: 0.0021
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 4.4692e-04 - val_loss: 0.0026
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.9089e-04 - val_loss: 0.0030
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.9919e-04 - val_loss: 0.0039
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.0527e-04 - val_loss: 0.0011
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 4.0567e-04 - val_loss: 0.0041
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.9936e-04 - val_loss: 0.0028
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.8122e-04 - val_loss: 0.0028
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 4.1463e-04 - val_loss: 0.0032
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.7490e-04 - val_loss: 0.0037
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 4.2296e-04 - val_loss: 0.0020
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.9947e-04 - val_loss: 0.0032
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.6813e-04 - val_loss: 0.0049
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.9306e-04 - val_loss: 0.0032
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.6450e-04 - val_loss: 0.0032
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.2823e-04 - val_loss: 0.0040
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.8832e-04 - val_loss: 0.0042
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.7291e-04 - val_loss: 0.0054
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.8073e-04 - val_loss: 0.0045
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.8841e-04 - val_loss: 0.0031
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.8379e-04 - val_loss: 0.0019
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.6453e-04 - val_loss: 0.0034
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.4362e-04 - val_loss: 0.0070
# Epoch 31/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.6206e-04 - val_loss: 0.0038
# Epoch 32/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.8114e-04 - val_loss: 0.0063
# Epoch 33/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.5150e-04 - val_loss: 0.0059
# Epoch 34/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 3.5848e-04 - val_loss: 0.0026
# Epoch 35/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.6728e-04 - val_loss: 0.0036
# Epoch 36/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.5459e-04 - val_loss: 0.0039
# Epoch 37/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.6379e-04 - val_loss: 0.0015
# Epoch 38/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.6068e-04 - val_loss: 0.0046
# Epoch 39/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.6378e-04 - val_loss: 0.0099
# Epoch 40/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 3.5070e-04 - val_loss: 0.0073
# Epoch 41/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.0655e-04 - val_loss: 0.0148
# Epoch 42/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.3875e-04 - val_loss: 0.0039
# Epoch 43/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.3405e-04 - val_loss: 0.0050
# Epoch 44/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.7265e-04 - val_loss: 0.0046
# Epoch 45/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.6733e-04 - val_loss: 0.0059
# Epoch 46/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.5462e-04 - val_loss: 0.0046
# Epoch 47/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.6606e-04 - val_loss: 0.0065
# Epoch 48/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.3849e-04 - val_loss: 0.0050
# Epoch 49/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.2655e-04 - val_loss: 0.0064
# Epoch 50/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.4929e-04 - val_loss: 0.0043
# Epoch 51/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.5636e-04 - val_loss: 0.0038
# Epoch 52/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.5938e-04 - val_loss: 0.0067
# Epoch 53/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.4803e-04 - val_loss: 0.0079
# Epoch 54/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.4103e-04 - val_loss: 0.0027
# Epoch 55/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.3050e-04 - val_loss: 0.0065
# Epoch 56/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.1632e-04 - val_loss: 0.0061
# Epoch 57/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.1476e-04 - val_loss: 0.0064
# Epoch 58/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.3476e-04 - val_loss: 0.0065
# Epoch 59/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.3840e-04 - val_loss: 0.0101
# Epoch 60/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.3045e-04 - val_loss: 0.0078
# Epoch 61/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.5432e-04 - val_loss: 0.0072
# Epoch 62/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.5044e-04 - val_loss: 0.0041
# Epoch 63/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.4490e-04 - val_loss: 0.0090
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# R2: 0.4273
# MAPE: 0.1030
# RMSE: 66.2878
# RMSE_normalizeddata: 0.0949
# MAE: 57.9023

# %%
model_lstm.save('model_lstm_SBI5h_4.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(169, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.00398), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=30, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - loss: 0.0064 - val_loss: 0.0023
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.4195e-04 - val_loss: 0.0018
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 5.0308e-04 - val_loss: 0.0014
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.7388e-04 - val_loss: 0.0017
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.4943e-04 - val_loss: 0.0018
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.0926e-04 - val_loss: 0.0010
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.8863e-04 - val_loss: 0.0013
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.7695e-04 - val_loss: 0.0055
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.5483e-04 - val_loss: 0.0013
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.0621e-04 - val_loss: 0.0031
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.5823e-04 - val_loss: 0.0052
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.1612e-04 - val_loss: 0.0011
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.9367e-04 - val_loss: 0.0031
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.0416e-04 - val_loss: 0.0019
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.2076e-04 - val_loss: 0.0043
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.6378e-04 - val_loss: 0.0028
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.0943e-04 - val_loss: 0.0018
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.1118e-04 - val_loss: 0.0022
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.0481e-04 - val_loss: 0.0032
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.1257e-04 - val_loss: 0.0025
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.8186e-04 - val_loss: 0.0023
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.0938e-04 - val_loss: 0.0024
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.8484e-04 - val_loss: 0.0021
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.8296e-04 - val_loss: 0.0059
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.8222e-04 - val_loss: 0.0043
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.9387e-04 - val_loss: 0.0024
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.9384e-04 - val_loss: 0.0038
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.7174e-04 - val_loss: 0.0013
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.6999e-04 - val_loss: 0.0064
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# R2: 0.5909
# MAPE: 0.0928
# RMSE: 56.0231
# RMSE_normalizeddata: 0.0802
# MAE: 50.7794

# %%
model_lstm.save('model_lstm_SBI5h_5.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(169, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.00398), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=30, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0049 - val_loss: 0.0012
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.1213e-04 - val_loss: 0.0028
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.0448e-04 - val_loss: 0.0033
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.4554e-04 - val_loss: 0.0025
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.0594e-04 - val_loss: 0.0010
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.8313e-04 - val_loss: 0.0031
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.7180e-04 - val_loss: 0.0032
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.6583e-04 - val_loss: 0.0032
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.1960e-04 - val_loss: 9.6741e-04
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.2492e-04 - val_loss: 0.0034
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.1917e-04 - val_loss: 0.0036
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.0311e-04 - val_loss: 0.0034
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.4533e-04 - val_loss: 0.0029
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.0621e-04 - val_loss: 0.0024
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.0499e-04 - val_loss: 0.0047
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.0031e-04 - val_loss: 0.0018
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.3284e-04 - val_loss: 0.0047
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.1838e-04 - val_loss: 0.0046
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.8555e-04 - val_loss: 0.0062
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.9343e-04 - val_loss: 0.0055
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.9261e-04 - val_loss: 0.0026
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.8056e-04 - val_loss: 0.0029
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.7925e-04 - val_loss: 0.0049
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.9093e-04 - val_loss: 0.0045
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.6900e-04 - val_loss: 0.0036
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.9526e-04 - val_loss: 0.0018
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.0323e-04 - val_loss: 0.0014
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.8461e-04 - val_loss: 0.0022
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.7608e-04 - val_loss: 0.0032
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.7764e-04 - val_loss: 0.0046
# Epoch 31/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.8772e-04 - val_loss: 0.0045
# Epoch 32/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.7317e-04 - val_loss: 0.0030
# Epoch 33/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.7093e-04 - val_loss: 0.0037
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# R2: 0.7645
# MAPE: 0.0663
# RMSE: 42.5091
# RMSE_normalizeddata: 0.0609
# MAE: 36.6115

# %%
model_lstm.save('model_lstm_SBI5h_6.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(169, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.00398), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=30, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - loss: 0.0049 - val_loss: 0.0015
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.3349e-04 - val_loss: 0.0034
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 4.9673e-04 - val_loss: 0.0019
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.0638e-04 - val_loss: 0.0020
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.2607e-04 - val_loss: 0.0028
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 4.4414e-04 - val_loss: 0.0047
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 4.6443e-04 - val_loss: 0.0013
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 4.3571e-04 - val_loss: 0.0015
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.5509e-04 - val_loss: 0.0020
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.2099e-04 - val_loss: 0.0016
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.1857e-04 - val_loss: 0.0028
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.1575e-04 - val_loss: 0.0020
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.2836e-04 - val_loss: 0.0019
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.1866e-04 - val_loss: 0.0014
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.3699e-04 - val_loss: 0.0050
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.8967e-04 - val_loss: 0.0012
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.1348e-04 - val_loss: 0.0044
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.9836e-04 - val_loss: 0.0050
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.0922e-04 - val_loss: 0.0036
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.8209e-04 - val_loss: 0.0049
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.8281e-04 - val_loss: 0.0083
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.6977e-04 - val_loss: 0.0053
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.9470e-04 - val_loss: 0.0035
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.8971e-04 - val_loss: 0.0029
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
# R2: 0.8133
# MAPE: 0.0560
# RMSE: 37.8479
# RMSE_normalizeddata: 0.0542
# MAE: 31.2617

# %%
model_lstm.save('model_lstm_SBI5h_7.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(169, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.00398), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=30, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 0.0044 - val_loss: 0.0019
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.8651e-04 - val_loss: 0.0012
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.8547e-04 - val_loss: 0.0024
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.8255e-04 - val_loss: 0.0014
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.4731e-04 - val_loss: 0.0016
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.1098e-04 - val_loss: 0.0019
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.7159e-04 - val_loss: 0.0025
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.8292e-04 - val_loss: 0.0033
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.3324e-04 - val_loss: 0.0013
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.3821e-04 - val_loss: 0.0013
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.2356e-04 - val_loss: 0.0021
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.6020e-04 - val_loss: 0.0025
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.2431e-04 - val_loss: 0.0036
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.5175e-04 - val_loss: 0.0024
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.0315e-04 - val_loss: 0.0013
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 4.2236e-04 - val_loss: 0.0041
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.9974e-04 - val_loss: 0.0028
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.9186e-04 - val_loss: 0.0032
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 4.0587e-04 - val_loss: 0.0022
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.7528e-04 - val_loss: 0.0013
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.9973e-04 - val_loss: 0.0043
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.5375e-04 - val_loss: 0.0033
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.7678e-04 - val_loss: 0.0024
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.6922e-04 - val_loss: 0.0029
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.5473e-04 - val_loss: 0.0053
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.7694e-04 - val_loss: 0.0038
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.8305e-04 - val_loss: 0.0026
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.7299e-04 - val_loss: 0.0035
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.7934e-04 - val_loss: 0.0038
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.6367e-04 - val_loss: 0.0038
# Epoch 31/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.6024e-04 - val_loss: 0.0034
# Epoch 32/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.7442e-04 - val_loss: 0.0029
# Epoch 33/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.6149e-04 - val_loss: 0.0044
# Epoch 34/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.6505e-04 - val_loss: 0.0032
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
# R2: 0.7965
# MAPE: 0.0569
# RMSE: 39.5117
# RMSE_normalizeddata: 0.0566
# MAE: 32.0601

# %%
model_lstm.save('model_lstm_SBI5h_8.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(169, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.00398), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=30, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.0056 - val_loss: 0.0020
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.2766e-04 - val_loss: 0.0032
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 4.9878e-04 - val_loss: 0.0015
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 4.8050e-04 - val_loss: 0.0013
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 4.5564e-04 - val_loss: 0.0027
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 4.8729e-04 - val_loss: 0.0011
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 4.5299e-04 - val_loss: 0.0011
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 4.4652e-04 - val_loss: 0.0010
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 4.2443e-04 - val_loss: 0.0016
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 4.2351e-04 - val_loss: 0.0016
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 4.2825e-04 - val_loss: 0.0021
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.9509e-04 - val_loss: 0.0015
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.4498e-04 - val_loss: 0.0021
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.4592e-04 - val_loss: 0.0025
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.9262e-04 - val_loss: 0.0020
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.0458e-04 - val_loss: 0.0022
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.4178e-04 - val_loss: 0.0023
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.8925e-04 - val_loss: 0.0025
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.4921e-04 - val_loss: 0.0017
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.6092e-04 - val_loss: 0.0051
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.1033e-04 - val_loss: 0.0045
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.7724e-04 - val_loss: 0.0049
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.8891e-04 - val_loss: 0.0028
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.6987e-04 - val_loss: 0.0026
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.6062e-04 - val_loss: 0.0048
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.9905e-04 - val_loss: 0.0052
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.6343e-04 - val_loss: 0.0060
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.9332e-04 - val_loss: 0.0020
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.9806e-04 - val_loss: 0.0060
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.6075e-04 - val_loss: 0.0036
# Epoch 31/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.1024e-04 - val_loss: 0.0046
# Epoch 32/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.8354e-04 - val_loss: 0.0053
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# R2: 0.6640
# MAPE: 0.0819
# RMSE: 50.7732
# RMSE_normalizeddata: 0.0727
# MAE: 44.9736

# %%
model_lstm.save('model_lstm_SBI5h_9.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(169, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.00398), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=30, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0049 - val_loss: 0.0012
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.0885e-04 - val_loss: 0.0015
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.9385e-04 - val_loss: 0.0015
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.2650e-04 - val_loss: 0.0024
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.8914e-04 - val_loss: 0.0020
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.8253e-04 - val_loss: 0.0026
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.2023e-04 - val_loss: 0.0018
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.9626e-04 - val_loss: 0.0026
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.3646e-04 - val_loss: 0.0030
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.4113e-04 - val_loss: 0.0024
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.1753e-04 - val_loss: 0.0048
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.0397e-04 - val_loss: 0.0011
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.0596e-04 - val_loss: 0.0021
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.9744e-04 - val_loss: 0.0018
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.9351e-04 - val_loss: 0.0041
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.8551e-04 - val_loss: 0.0032
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.8352e-04 - val_loss: 0.0021
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.8235e-04 - val_loss: 0.0011
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.1499e-04 - val_loss: 0.0021
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.1791e-04 - val_loss: 0.0018
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.8390e-04 - val_loss: 0.0016
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.7119e-04 - val_loss: 0.0018
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 4.0157e-04 - val_loss: 0.0025
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.9038e-04 - val_loss: 0.0028
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.8977e-04 - val_loss: 0.0018
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.9187e-04 - val_loss: 0.0055
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.6728e-04 - val_loss: 0.0035
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.7423e-04 - val_loss: 0.0017
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.7665e-04 - val_loss: 0.0052
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.8041e-04 - val_loss: 0.0028
# Epoch 31/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.6068e-04 - val_loss: 0.0021
# Epoch 32/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.0538e-04 - val_loss: 0.0034
# Epoch 33/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.6700e-04 - val_loss: 0.0013
# Epoch 34/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.5606e-04 - val_loss: 0.0067
# Epoch 35/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.9779e-04 - val_loss: 0.0011
# Epoch 36/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.9521e-04 - val_loss: 0.0029
# Epoch 37/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.5371e-04 - val_loss: 0.0036
# Epoch 38/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.6507e-04 - val_loss: 0.0034
# Epoch 39/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.2026e-04 - val_loss: 0.0024
# Epoch 40/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.7556e-04 - val_loss: 0.0012
# Epoch 41/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.1441e-04 - val_loss: 0.0020
# Epoch 42/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.7332e-04 - val_loss: 0.0033
# Epoch 43/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.9048e-04 - val_loss: 0.0024
# Epoch 44/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.2683e-04 - val_loss: 0.0018
# Epoch 45/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.2411e-04 - val_loss: 0.0022
# Epoch 46/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.3521e-04 - val_loss: 0.0040
# Epoch 47/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.5235e-04 - val_loss: 0.0018
# Epoch 48/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.3526e-04 - val_loss: 0.0016
# Epoch 49/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.9105e-04 - val_loss: 0.0017
# Epoch 50/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.8222e-04 - val_loss: 0.0050
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# R2: 0.6846
# MAPE: 0.0762
# RMSE: 49.1970
# RMSE_normalizeddata: 0.0704
# MAE: 42.2953

# %%
model_lstm.save('model_lstm_SBI5h_10.keras')
