# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import statsmodels.api as smi
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from statistics import mean
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, SimpleRNN, GRU, Dropout, Conv1D, MaxPooling1D, Flatten, RepeatVector
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_percentage_error, mean_absolute_error
from tensorflow.keras.optimizers import Adam, Nadam, RMSprop
from statsmodels.tsa.seasonal import seasonal_decompose
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from hyperopt import hp, Trials, fmin, tpe
import joblib
import warnings
warnings.simplefilter('ignore')

# %%
df=pd.read_csv(r'E:\A aPython Programms\Data1\Bank.csv')
df.tail(5)
# Out:
#             Date     AXISBANK   AXISVOL     BAJAJFIN  BAJAJFINVOL         BOB  \
# 3748  21-03-2024  1035.599976   9903738  6715.750000      1806092  255.699997
# 3749  22-03-2024  1033.300049   9891194  6760.899902      1125238  259.799988
# 3750  26-03-2024  1040.550049   9656767  6910.100098      1850321  261.549988
# 3751  27-03-2024  1052.849976  17027308  7022.750000      1551275  258.750000
# 3752  28-03-2024  1047.199951  10235318  7245.250000      3574518  264.049988
#
#         BOBVOL     FEDBANK    FEDVOL         HDFC  ...        KOTAK  KOTAKVOL  \
# 3748  10121220  149.949997   6212045  1445.750000  ...  1772.150024   3783681
# 3749  11402546  149.600006   8409218  1442.849976  ...  1776.400024   7061283
# 3750   8259347  149.800003   7742995  1425.400024  ...  1753.699951   5303630
# 3751  19196992  149.800003  20853016  1440.699951  ...  1775.599976   8231130
# 3752  11966752  150.199997   7208707  1447.900024  ...  1785.500000   6630072
#
#              PNB    PNBVOL         SBI    SBIVOL         REC    RECVOL  \
# 3748  121.050003  38099730  744.299988  15161161  450.250000  18429233
# 3749  122.750000  35001868  746.700012  15535921  460.100006  12531582
# 3750  123.949997  30860596  740.049988  14678342  461.399994  10475524
# 3751  122.750000  42673023  733.299988  30088789  445.600006  28138339
# 3752  124.400002  29453142  752.349976  21705116  451.000000  12637899
#
#          PIRAMAL  PIRAMALVOL
# 3748  841.599976      987716
# 3749  861.500000     1618543
# 3750  858.250000     1391794
# 3751  840.200012     1344329
# 3752  849.349976     5261416
#
# [5 rows x 25 columns]

# %%
feature_columns = ['ICICI', 'ICICIVOL']
target_column = ['ICICI']
features = df[feature_columns]
target = df[target_column].shift(-1)

new_data1 = 1099.65
target.iloc[-1, 0] = new_data1

target.tail(5)
# Out:
#             ICICI
# 3748  1090.300049
# 3749  1083.699951
# 3750  1083.750000
# 3751  1093.300049
# 3752  1099.650000

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_features = scaler.fit_transform(features)
scaled_target = scaler.fit_transform(target.values.reshape(-1, 1))

n_steps = 5  # Number of timesteps to look back
X, y = [], []

for i in range(n_steps, len(scaled_features)):
    X.append(scaled_features[i-n_steps:i])
    y.append(scaled_target[i])

X = np.array(X)
y = np.array(y)

split=int(0.8*len(X))
X_train, y_train= X[:split], y[:split]
X_test, y_test= X[split:], y[split:]

# %%
model_lstm = load_model('model_lstm_icici1_0.9857.keras')
model_lstm.predict(X_test)

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae_n=mean_absolute_error(y_test, predictions_lstm)
print(f"MAE_normalizeddata: {mae_n:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# R2: 0.9857
# MAPE: 0.0146
# RMSE: 15.5262
# RMSE_normalizeddata: 0.0148
# MAE_normalizeddata: 0.0111
# MAE: 11.6666

# %%
plt.figure(figsize=(9, 6))
plt.plot(y_test_actual_LSTM, color='green', label=['Actual Price'])
plt.plot(predictions_LSTM, color='red', label=['Predicted Price'])
plt.legend(['Actual Price', 'Predicted Price'], loc='upper left')

plt.text(0.75, 0.1, f'R2: {r2:.4f}\nMAPE: {mape:.4f}%\nRMSE: {rmse:.4f}\nMAE: {mae:.4f}', 
         fontsize=12, 
         bbox=dict(facecolor='white', alpha=0.5),
         transform=plt.gca().transAxes)

plt.grid(True)
plt.title('ICICI single model (1 step ahead)')
plt.xlabel('Time Step')
plt.ylabel('Actual vs Predicted Price')
plt.savefig('icici_1sa-1l.png', dpi=600)  # Saves the plot as a PNG file
plt.show()

# %%
model_lstm.predict(X_train)

predictions_train_lstm = model_lstm.predict(X_train)
predictions_train_LSTM = scaler.inverse_transform(predictions_train_lstm)
y_train_actual_LSTM = scaler.inverse_transform(y_train.reshape(-1, 1))

r2=r2_score(y_train_actual_LSTM, predictions_train_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_train_actual_LSTM, predictions_train_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_train_actual_LSTM, predictions_train_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_train, predictions_train_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae_n=mean_absolute_error(y_train, predictions_train_lstm)
print(f"MAE_normalizeddata: {mae_n:.4f}")

mae=mean_absolute_error(y_train_actual_LSTM, predictions_train_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# R2: 0.9929
# MAPE: 0.0260
# RMSE: 9.0129
# RMSE_normalizeddata: 0.0086
# MAE_normalizeddata: 0.0060
# MAE: 6.3085

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(412, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.001), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=39, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])
predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - loss: 0.0113 - val_loss: 0.0128
# Epoch 2/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.4922e-04 - val_loss: 0.0025
# Epoch 3/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 1.6072e-04 - val_loss: 0.0023
# Epoch 4/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 1.3042e-04 - val_loss: 0.0015
# Epoch 5/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 1.4516e-04 - val_loss: 0.0015
# Epoch 6/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 1.4931e-04 - val_loss: 0.0012
# Epoch 7/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 1.5331e-04 - val_loss: 0.0012
# Epoch 8/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 1.1481e-04 - val_loss: 0.0011
# Epoch 9/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 1.3023e-04 - val_loss: 0.0010
# Epoch 10/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 1.1674e-04 - val_loss: 0.0024
# Epoch 11/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 1.0648e-04 - val_loss: 0.0023
# Epoch 12/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 1.5333e-04 - val_loss: 9.3863e-04
# Epoch 13/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 1.4096e-04 - val_loss: 0.0040
# Epoch 14/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 1.0918e-04 - val_loss: 0.0012
# Epoch 15/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 1.0373e-04 - val_loss: 0.0018
# Epoch 16/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 9.2095e-05 - val_loss: 0.0019
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# R2: 0.7668
# MAPE: 0.0440
# RMSE: 360.3992
# RMSE_normalizeddata: 0.0441
# MAE: 297.3690

# %%
model_lstm.save('model_lstm_bajajfin1h_1.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(412, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.001), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=39, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])
predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 0.0079 - val_loss: 0.0028
# Epoch 2/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 1.6540e-04 - val_loss: 0.0015
# Epoch 3/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 1.5815e-04 - val_loss: 0.0023
# Epoch 4/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 1.1190e-04 - val_loss: 0.0013
# Epoch 5/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 1.3825e-04 - val_loss: 0.0021
# Epoch 6/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 1.4675e-04 - val_loss: 0.0030
# Epoch 7/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 1.2753e-04 - val_loss: 0.0016
# Epoch 8/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 1.1506e-04 - val_loss: 0.0011
# Epoch 9/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 1.7030e-04 - val_loss: 0.0011
# Epoch 10/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 1.0807e-04 - val_loss: 0.0010
# Epoch 11/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 1.0233e-04 - val_loss: 0.0024
# Epoch 12/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 1.2410e-04 - val_loss: 0.0013
# Epoch 13/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 1.1387e-04 - val_loss: 0.0019
# Epoch 14/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.1428e-04 - val_loss: 0.0010
# Epoch 15/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 9.8657e-05 - val_loss: 0.0021
# Epoch 16/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 9.4467e-05 - val_loss: 0.0013
# Epoch 17/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 9.7976e-05 - val_loss: 0.0011
# Epoch 18/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.0186e-04 - val_loss: 0.0014
# Epoch 19/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.0924e-04 - val_loss: 9.8529e-04
# Epoch 20/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 1.0799e-04 - val_loss: 0.0012
# Epoch 21/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.1260e-04 - val_loss: 9.5750e-04
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# R2: 0.8926
# MAPE: 0.0286
# RMSE: 244.5065
# RMSE_normalizeddata: 0.0299
# MAE: 191.4492

# %%
model_lstm.save('model_lstm_bajajfin1h_2.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(412, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.001), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=39, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])
predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 0.0085 - val_loss: 0.0073
# Epoch 2/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 1.3616e-04 - val_loss: 0.0015
# Epoch 3/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1.7585e-04 - val_loss: 0.0027
# Epoch 4/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.1471e-04 - val_loss: 0.0026
# Epoch 5/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.2183e-04 - val_loss: 0.0016
# Epoch 6/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.0143e-04 - val_loss: 0.0023
# Epoch 7/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.5071e-04 - val_loss: 0.0017
# Epoch 8/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 1.1220e-04 - val_loss: 0.0017
# Epoch 9/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 1.1241e-04 - val_loss: 0.0025
# Epoch 10/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 1.1301e-04 - val_loss: 0.0015
# Epoch 11/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 1.0787e-04 - val_loss: 0.0010
# Epoch 12/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.0932e-04 - val_loss: 0.0010
# Epoch 13/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 9.5006e-05 - val_loss: 0.0014
# Epoch 14/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 1.3559e-04 - val_loss: 0.0013
# Epoch 15/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 1.0169e-04 - val_loss: 0.0020
# Epoch 16/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 1.1820e-04 - val_loss: 0.0010
# Epoch 17/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 9.6931e-05 - val_loss: 0.0018
# Epoch 18/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 1.1906e-04 - val_loss: 0.0011
# Epoch 19/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 9.5563e-05 - val_loss: 8.5827e-04
# Epoch 20/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 9.0020e-05 - val_loss: 0.0011
# Epoch 21/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 9.2699e-05 - val_loss: 8.1854e-04
# Epoch 22/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 9.3927e-05 - val_loss: 8.8989e-04
# Epoch 23/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.0453e-04 - val_loss: 0.0015
# Epoch 24/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 8.2977e-05 - val_loss: 0.0013
# Epoch 25/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 9.0858e-05 - val_loss: 8.6724e-04
# Epoch 26/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 9.2672e-05 - val_loss: 8.1632e-04
# Epoch 27/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 8.6596e-05 - val_loss: 9.3133e-04
# Epoch 28/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1.1171e-04 - val_loss: 7.6540e-04
# Epoch 29/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 8.7177e-05 - val_loss: 7.4763e-04
# Epoch 30/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 8.3152e-05 - val_loss: 7.9726e-04
# Epoch 31/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 7.7336e-05 - val_loss: 8.0298e-04
# Epoch 32/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 8.3081e-05 - val_loss: 6.8235e-04
# Epoch 33/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 7.1109e-05 - val_loss: 7.8966e-04
# Epoch 34/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 9.1504e-05 - val_loss: 7.7204e-04
# Epoch 35/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 7.4997e-05 - val_loss: 6.4971e-04
# Epoch 36/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 8.2629e-05 - val_loss: 6.9409e-04
# Epoch 37/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 8.1465e-05 - val_loss: 0.0010
# Epoch 38/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 8.4775e-05 - val_loss: 7.1000e-04
# Epoch 39/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 7.2459e-05 - val_loss: 0.0013
# Epoch 40/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 8.5467e-05 - val_loss: 6.6400e-04
# Epoch 41/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 7.3058e-05 - val_loss: 6.3875e-04
# Epoch 42/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 6.6965e-05 - val_loss: 8.5792e-04
# Epoch 43/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 8.4884e-05 - val_loss: 8.7069e-04
# Epoch 44/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 7.0982e-05 - val_loss: 7.0352e-04
# Epoch 45/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 7.5211e-05 - val_loss: 6.1754e-04
# Epoch 46/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 8.9821e-05 - val_loss: 6.6976e-04
# Epoch 47/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 6.4040e-05 - val_loss: 7.7126e-04
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# R2: 0.9052
# MAPE: 0.0276
# RMSE: 229.7936
# RMSE_normalizeddata: 0.0281
# MAE: 184.4806

# %%
model_lstm.save('model_lstm_bajajfin1h_3.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(412, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.001), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=39, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])
predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 0.0098 - val_loss: 0.0054
# Epoch 2/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.3549e-04 - val_loss: 0.0019
# Epoch 3/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 1.1387e-04 - val_loss: 0.0014
# Epoch 4/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.2282e-04 - val_loss: 0.0014
# Epoch 5/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 1.2940e-04 - val_loss: 0.0020
# Epoch 6/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 1.4283e-04 - val_loss: 0.0012
# Epoch 7/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 1.1903e-04 - val_loss: 0.0017
# Epoch 8/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 1.0986e-04 - val_loss: 0.0011
# Epoch 9/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 1.0309e-04 - val_loss: 0.0018
# Epoch 10/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 1.3712e-04 - val_loss: 9.8886e-04
# Epoch 11/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 1.1549e-04 - val_loss: 0.0013
# Epoch 12/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1.4646e-04 - val_loss: 0.0012
# Epoch 13/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 1.0959e-04 - val_loss: 0.0030
# Epoch 14/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1.3038e-04 - val_loss: 0.0019
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# R2: 0.7685
# MAPE: 0.0442
# RMSE: 359.0833
# RMSE_normalizeddata: 0.0440
# MAE: 298.1334

# %%
model_lstm.save('model_lstm_bajajfin1h_4.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(412, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.001), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=39, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])
predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 0.0074 - val_loss: 0.0056
# Epoch 2/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 1.4233e-04 - val_loss: 0.0034
# Epoch 3/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 1.2015e-04 - val_loss: 0.0028
# Epoch 4/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.4480e-04 - val_loss: 0.0027
# Epoch 5/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 1.1402e-04 - val_loss: 0.0013
# Epoch 6/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.5351e-04 - val_loss: 0.0017
# Epoch 7/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1.5096e-04 - val_loss: 0.0016
# Epoch 8/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 1.1960e-04 - val_loss: 0.0021
# Epoch 9/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 1.1947e-04 - val_loss: 0.0019
# Epoch 10/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 1.1497e-04 - val_loss: 0.0018
# Epoch 11/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 1.2842e-04 - val_loss: 0.0011
# Epoch 12/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 1.2409e-04 - val_loss: 0.0014
# Epoch 13/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 1.0457e-04 - val_loss: 0.0016
# Epoch 14/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 1.5016e-04 - val_loss: 0.0011
# Epoch 15/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 1.2795e-04 - val_loss: 8.7547e-04
# Epoch 16/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 1.1016e-04 - val_loss: 9.1761e-04
# Epoch 17/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 9.3497e-05 - val_loss: 0.0023
# Epoch 18/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 1.1823e-04 - val_loss: 0.0011
# Epoch 19/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: 1.0881e-04 - val_loss: 9.5668e-04
# Epoch 20/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 1.0333e-04 - val_loss: 8.6329e-04
# Epoch 21/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 1.0664e-04 - val_loss: 8.2601e-04
# Epoch 22/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 1.0184e-04 - val_loss: 0.0013
# Epoch 23/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 1.0212e-04 - val_loss: 0.0016
# Epoch 24/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: 8.2768e-05 - val_loss: 0.0011
# Epoch 25/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 8.3291e-05 - val_loss: 7.4132e-04
# Epoch 26/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: 9.4098e-05 - val_loss: 9.9583e-04
# Epoch 27/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 9.4622e-05 - val_loss: 7.4607e-04
# Epoch 28/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 8.9065e-05 - val_loss: 0.0013
# Epoch 29/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 9.1462e-05 - val_loss: 0.0012
# Epoch 30/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 8.0157e-05 - val_loss: 0.0012
# Epoch 31/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 9.2372e-05 - val_loss: 8.9109e-04
# Epoch 32/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 7.5045e-05 - val_loss: 6.4919e-04
# Epoch 33/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: 9.2675e-05 - val_loss: 8.6644e-04
# Epoch 34/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 8.8085e-05 - val_loss: 7.4131e-04
# Epoch 35/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 8.8613e-05 - val_loss: 0.0012
# Epoch 36/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: 7.8128e-05 - val_loss: 6.9729e-04
# Epoch 37/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 6.8183e-05 - val_loss: 8.8485e-04
# Epoch 38/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 7.7381e-05 - val_loss: 6.9953e-04
# Epoch 39/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 7.7381e-05 - val_loss: 8.5361e-04
# Epoch 40/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 8.0260e-05 - val_loss: 0.0013
# Epoch 41/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - loss: 8.2019e-05 - val_loss: 6.4890e-04
# Epoch 42/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 9.7918e-05 - val_loss: 6.6679e-04
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 91ms/step
# R2: 0.9235
# MAPE: 0.0238
# RMSE: 206.4266
# RMSE_normalizeddata: 0.0253
# MAE: 158.8933

# %%
model_lstm.save('model_lstm_bajajfin1h_5.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(412, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.001), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=39, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])
predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 86ms/step - loss: 0.0099 - val_loss: 0.0060
# Epoch 2/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 1.3106e-04 - val_loss: 0.0019
# Epoch 3/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 1.2878e-04 - val_loss: 0.0020
# Epoch 4/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 1.0946e-04 - val_loss: 0.0015
# Epoch 5/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 1.1176e-04 - val_loss: 0.0026
# Epoch 6/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 1.1396e-04 - val_loss: 0.0014
# Epoch 7/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - loss: 1.1370e-04 - val_loss: 0.0034
# Epoch 8/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: 1.1539e-04 - val_loss: 0.0027
# Epoch 9/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 1.2076e-04 - val_loss: 0.0014
# Epoch 10/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 1.1591e-04 - val_loss: 0.0016
# Epoch 11/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 1.1021e-04 - val_loss: 0.0023
# Epoch 12/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: 1.2203e-04 - val_loss: 0.0013
# Epoch 13/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: 1.3802e-04 - val_loss: 0.0011
# Epoch 14/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - loss: 9.7283e-05 - val_loss: 0.0048
# Epoch 15/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 1.1266e-04 - val_loss: 9.7837e-04
# Epoch 16/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 1.3366e-04 - val_loss: 0.0011
# Epoch 17/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 8.7371e-05 - val_loss: 0.0016
# Epoch 18/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 1.2015e-04 - val_loss: 9.2766e-04
# Epoch 19/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 1.0303e-04 - val_loss: 0.0012
# Epoch 20/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 9.3285e-05 - val_loss: 9.3855e-04
# Epoch 21/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 8.5608e-05 - val_loss: 0.0018
# Epoch 22/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 1.2981e-04 - val_loss: 0.0010
# Epoch 23/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 8.5209e-05 - val_loss: 7.4508e-04
# Epoch 24/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 7.8486e-05 - val_loss: 0.0015
# Epoch 25/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 1.0396e-04 - val_loss: 0.0024
# Epoch 26/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 1.0757e-04 - val_loss: 0.0011
# Epoch 27/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 8.8736e-05 - val_loss: 0.0011
# Epoch 28/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 8.4664e-05 - val_loss: 9.4883e-04
# Epoch 29/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 1.0447e-04 - val_loss: 0.0010
# Epoch 30/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 8.9338e-05 - val_loss: 7.7037e-04
# Epoch 31/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 1.0520e-04 - val_loss: 7.1250e-04
# Epoch 32/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 8.2963e-05 - val_loss: 6.7685e-04
# Epoch 33/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - loss: 8.2183e-05 - val_loss: 7.3252e-04
# Epoch 34/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: 9.6159e-05 - val_loss: 7.3638e-04
# Epoch 35/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - loss: 8.3578e-05 - val_loss: 6.7708e-04
# Epoch 36/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 9.1405e-05 - val_loss: 9.3631e-04
# Epoch 37/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 7.7944e-05 - val_loss: 9.9280e-04
# Epoch 38/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - loss: 9.4567e-05 - val_loss: 6.8463e-04
# Epoch 39/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - loss: 8.6772e-05 - val_loss: 6.5578e-04
# Epoch 40/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 7.9082e-05 - val_loss: 0.0011
# Epoch 41/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 8.6105e-05 - val_loss: 7.9522e-04
# Epoch 42/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 8.4635e-05 - val_loss: 7.1552e-04
# Epoch 43/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 7.5046e-05 - val_loss: 6.7818e-04
# Epoch 44/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 7.6956e-05 - val_loss: 6.0153e-04
# Epoch 45/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 9.0249e-05 - val_loss: 9.5323e-04
# Epoch 46/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 6.0198e-05 - val_loss: 7.8568e-04
# Epoch 47/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - loss: 6.4491e-05 - val_loss: 5.8669e-04
# Epoch 48/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 7.2818e-05 - val_loss: 7.3596e-04
# Epoch 49/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 8.5004e-05 - val_loss: 5.7572e-04
# Epoch 50/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - loss: 7.3832e-05 - val_loss: 6.2869e-04
# Epoch 51/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 6.7300e-05 - val_loss: 6.8696e-04
# Epoch 52/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 6.7720e-05 - val_loss: 8.2762e-04
# Epoch 53/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - loss: 7.2383e-05 - val_loss: 5.6276e-04
# Epoch 54/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 6.9043e-05 - val_loss: 5.9383e-04
# Epoch 55/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 7.0496e-05 - val_loss: 6.4412e-04
# Epoch 56/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: 5.9565e-05 - val_loss: 5.8899e-04
# Epoch 57/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: 7.2189e-05 - val_loss: 9.9585e-04
# Epoch 58/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - loss: 7.9784e-05 - val_loss: 5.7861e-04
# Epoch 59/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 6.9744e-05 - val_loss: 6.7246e-04
# Epoch 60/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 7.4663e-05 - val_loss: 6.6233e-04
# Epoch 61/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - loss: 6.7044e-05 - val_loss: 9.5308e-04
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step
# R2: 0.8937
# MAPE: 0.0287
# RMSE: 243.2632
# RMSE_normalizeddata: 0.0298
# MAE: 194.3449

# %%
model_lstm.save('model_lstm_bajajfin1h_6.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(412, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.001), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=39, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])
predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 83ms/step - loss: 0.0099 - val_loss: 0.0061
# Epoch 2/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 1.5782e-04 - val_loss: 0.0020
# Epoch 3/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 1.3939e-04 - val_loss: 0.0027
# Epoch 4/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 1.1812e-04 - val_loss: 0.0014
# Epoch 5/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 1.2146e-04 - val_loss: 0.0015
# Epoch 6/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 1.1778e-04 - val_loss: 0.0012
# Epoch 7/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 1.1166e-04 - val_loss: 0.0011
# Epoch 8/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 1.4546e-04 - val_loss: 0.0013
# Epoch 9/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 1.0635e-04 - val_loss: 0.0035
# Epoch 10/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 1.0544e-04 - val_loss: 0.0035
# Epoch 11/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 1.1407e-04 - val_loss: 0.0014
# Epoch 12/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 1.2319e-04 - val_loss: 0.0019
# Epoch 13/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 1.4276e-04 - val_loss: 0.0011
# Epoch 14/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 9.6297e-05 - val_loss: 0.0031
# Epoch 15/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 9.4148e-05 - val_loss: 0.0014
# Epoch 16/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 1.0485e-04 - val_loss: 9.6772e-04
# Epoch 17/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 9.7286e-05 - val_loss: 0.0010
# Epoch 18/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 9.6488e-05 - val_loss: 0.0012
# Epoch 19/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: 1.0898e-04 - val_loss: 0.0017
# Epoch 20/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 1.1031e-04 - val_loss: 9.0072e-04
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step
# R2: 0.8926
# MAPE: 0.0286
# RMSE: 244.5897
# RMSE_normalizeddata: 0.0300
# MAE: 192.1837

# %%
model_lstm.save('model_lstm_bajajfin1h_7.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(412, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.001), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=39, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])
predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 32s 82ms/step - loss: 0.0096 - val_loss: 0.0125
# Epoch 2/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 8s 49ms/step - loss: 1.4556e-04 - val_loss: 0.0033
# Epoch 3/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: 1.3685e-04 - val_loss: 0.0026
# Epoch 4/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: 1.1382e-04 - val_loss: 0.0015
# Epoch 5/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 1.3676e-04 - val_loss: 0.0013
# Epoch 6/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 1.1494e-04 - val_loss: 0.0018
# Epoch 7/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: 1.2959e-04 - val_loss: 0.0014
# Epoch 8/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 1.4103e-04 - val_loss: 0.0015
# Epoch 9/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: 9.5814e-05 - val_loss: 0.0012
# Epoch 10/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 1.1676e-04 - val_loss: 0.0016
# Epoch 11/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 1.1111e-04 - val_loss: 0.0016
# Epoch 12/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 1.2358e-04 - val_loss: 0.0010
# Epoch 13/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 1.2358e-04 - val_loss: 0.0011
# Epoch 14/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 1.0592e-04 - val_loss: 9.5049e-04
# Epoch 15/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 1.1646e-04 - val_loss: 9.6919e-04
# Epoch 16/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 1.1480e-04 - val_loss: 0.0014
# Epoch 17/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 1.0896e-04 - val_loss: 0.0045
# Epoch 18/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 1.1839e-04 - val_loss: 0.0012
# Epoch 19/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 9.3299e-05 - val_loss: 9.6465e-04
# Epoch 20/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 9.3950e-05 - val_loss: 0.0020
# Epoch 21/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 9.3843e-05 - val_loss: 7.6553e-04
# Epoch 22/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 9.9024e-05 - val_loss: 0.0027
# Epoch 23/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 1.0405e-04 - val_loss: 0.0019
# Epoch 24/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 9.8740e-05 - val_loss: 0.0011
# Epoch 25/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 1.2281e-04 - val_loss: 0.0010
# Epoch 26/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - loss: 8.6991e-05 - val_loss: 7.4122e-04
# Epoch 27/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 8.4375e-05 - val_loss: 0.0016
# Epoch 28/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - loss: 1.0075e-04 - val_loss: 7.1981e-04
# Epoch 29/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - loss: 8.8961e-05 - val_loss: 6.8866e-04
# Epoch 30/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 9.7684e-05 - val_loss: 6.5903e-04
# Epoch 31/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 7.4253e-05 - val_loss: 6.9013e-04
# Epoch 32/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 8.4675e-05 - val_loss: 8.3472e-04
# Epoch 33/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 8.6817e-05 - val_loss: 0.0013
# Epoch 34/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 9.5505e-05 - val_loss: 5.9910e-04
# Epoch 35/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 7.5208e-05 - val_loss: 5.9213e-04
# Epoch 36/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: 8.8830e-05 - val_loss: 6.4144e-04
# Epoch 37/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 8.4227e-05 - val_loss: 0.0018
# Epoch 38/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: 7.2233e-05 - val_loss: 6.8621e-04
# Epoch 39/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 8.7201e-05 - val_loss: 8.5910e-04
# Epoch 40/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 8.4676e-05 - val_loss: 7.9294e-04
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step
# R2: 0.9145
# MAPE: 0.0253
# RMSE: 218.2056
# RMSE_normalizeddata: 0.0267
# MAE: 171.3922

# %%
model_lstm.save('model_lstm_bajajfin1h_8.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(412, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.001), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=39, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])
predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - loss: 0.0107 - val_loss: 0.0038
# Epoch 2/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 1.5762e-04 - val_loss: 0.0033
# Epoch 3/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 1.4781e-04 - val_loss: 0.0028
# Epoch 4/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 1.4757e-04 - val_loss: 0.0023
# Epoch 5/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 1.2376e-04 - val_loss: 0.0039
# Epoch 6/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 1.4788e-04 - val_loss: 0.0012
# Epoch 7/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 1.0393e-04 - val_loss: 0.0017
# Epoch 8/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1.2015e-04 - val_loss: 0.0020
# Epoch 9/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 1.5572e-04 - val_loss: 0.0014
# Epoch 10/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1.3506e-04 - val_loss: 0.0011
# Epoch 11/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 1.4694e-04 - val_loss: 0.0010
# Epoch 12/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1.2335e-04 - val_loss: 0.0011
# Epoch 13/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 1.0961e-04 - val_loss: 0.0010
# Epoch 14/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1.1812e-04 - val_loss: 0.0014
# Epoch 15/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 1.1262e-04 - val_loss: 9.6660e-04
# Epoch 16/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 9.9878e-05 - val_loss: 0.0026
# Epoch 17/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 1.0192e-04 - val_loss: 9.2707e-04
# Epoch 18/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: 1.1899e-04 - val_loss: 8.3269e-04
# Epoch 19/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 9.4987e-05 - val_loss: 0.0010
# Epoch 20/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 1.2162e-04 - val_loss: 8.4123e-04
# Epoch 21/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 8.7782e-05 - val_loss: 9.0401e-04
# Epoch 22/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 1.2104e-04 - val_loss: 0.0015
# Epoch 23/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 9.9302e-05 - val_loss: 0.0011
# Epoch 24/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 9.3958e-05 - val_loss: 7.8006e-04
# Epoch 25/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 9.6731e-05 - val_loss: 0.0015
# Epoch 26/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 9.7142e-05 - val_loss: 7.9833e-04
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step
# R2: 0.9039
# MAPE: 0.0269
# RMSE: 231.3418
# RMSE_normalizeddata: 0.0283
# MAE: 180.1519

# %%
model_lstm.save('model_lstm_bajajfin1h_9.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(412, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.001), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=39, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])
predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 68ms/step - loss: 0.0119 - val_loss: 0.0097
# Epoch 2/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 1.4661e-04 - val_loss: 0.0089
# Epoch 3/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 1.5139e-04 - val_loss: 0.0025
# Epoch 4/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 1.2675e-04 - val_loss: 0.0025
# Epoch 5/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 1.2710e-04 - val_loss: 0.0040
# Epoch 6/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 1.2152e-04 - val_loss: 0.0036
# Epoch 7/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 1.5028e-04 - val_loss: 0.0025
# Epoch 8/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 1.3884e-04 - val_loss: 0.0027
# Epoch 9/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 1.3061e-04 - val_loss: 0.0013
# Epoch 10/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 1.2055e-04 - val_loss: 0.0013
# Epoch 11/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 1.1244e-04 - val_loss: 0.0011
# Epoch 12/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 1.3116e-04 - val_loss: 0.0029
# Epoch 13/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 1.2460e-04 - val_loss: 0.0012
# Epoch 14/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 9.2054e-05 - val_loss: 0.0011
# Epoch 15/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: 1.0346e-04 - val_loss: 0.0013
# Epoch 16/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 1.2819e-04 - val_loss: 0.0012
# Epoch 17/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 8.9201e-05 - val_loss: 9.4261e-04
# Epoch 18/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 1.1777e-04 - val_loss: 9.5376e-04
# Epoch 19/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 1.0557e-04 - val_loss: 8.4734e-04
# Epoch 20/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 9.0409e-05 - val_loss: 0.0015
# Epoch 21/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 1.1041e-04 - val_loss: 8.8237e-04
# Epoch 22/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 1.1842e-04 - val_loss: 8.2780e-04
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# R2: 0.8996
# MAPE: 0.0277
# RMSE: 236.4303
# RMSE_normalizeddata: 0.0290
# MAE: 185.6707

# %%
model_lstm.save('model_lstm_bajajfin1h_10.keras')
