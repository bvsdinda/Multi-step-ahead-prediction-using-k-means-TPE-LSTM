# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as smi
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from statistics import mean
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, SimpleRNN, GRU, Dropout, Conv1D, MaxPooling1D, Flatten, RepeatVector
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_percentage_error, mean_absolute_error
from tensorflow.keras.optimizers import Adam, Nadam, RMSprop
from statsmodels.tsa.seasonal import seasonal_decompose
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from hyperopt import hp, Trials, fmin, tpe
import joblib
import warnings
warnings.simplefilter('ignore')

# %%
df=pd.read_csv(r'E:\A aPython Programms\Data1\Bank.csv')
df.head(5)
# Out:
#          Date    AXISBANK   AXISVOL  BAJAJFIN  BAJAJFINVOL        BOB  \
# 0  02-01-2009  108.379997  14261265  6.310420       141738  57.340000
# 1  05-01-2009  112.019997   9165605  6.504736      1120575  58.860001
# 2  06-01-2009  113.949997  12893855  6.660189       312830  57.750000
# 3  07-01-2009  104.419998  10571555  6.150109       166223  54.939999
# 4  09-01-2009   97.320000  25173105  6.048093        95905  54.689999
#
#     BOBVOL    FEDBANK   FEDVOL        HDFC  ...      KOTAK  KOTAKVOL  \
# 0  1700495  16.889999  1359910  101.565002  ...  97.900002   6258884
# 1  2687100  17.129999  4379460  104.410004  ...  99.637497   5956956
# 2  3162520  16.760000  1930260  110.040001  ...  96.712502   9015300
# 3  5602350  16.459999  2251090  100.925003  ...  90.762497   6482408
# 4  1806325  16.004999  4046570  101.750000  ...  86.125000   5076276
#
#           PNB   PNBVOL         SBI    SBIVOL        REC   RECVOL     PIRAMAL  \
# 0  106.430000  2973855  133.184998  24161650  29.587500  9574565  134.700485
# 1  107.160004  3037185  136.080002  26931910  30.562500  8844514  136.025497
# 2  106.089996  4110100  132.285004  35970960  29.831249  1078005  133.516418
# 3   97.660004  6538860  124.004997  37268580  28.424999  5624090  131.853104
# 4   97.129997  3834090  122.110001  24996510  28.818750  6157634  129.654144
#
#    PIRAMALVOL
# 0      222908
# 1       14449
# 2      102783
# 3       24863
# 4      301873
#
# [5 rows x 25 columns]

# %%
feature_columns = ['BAJAJFIN', 'BAJAJFINVOL']
target_column = ['BAJAJFIN']
features = df[feature_columns]
target = df[target_column].shift(-2)

new_data1 = 7250.95
target.iloc[-2, 0] = new_data1

new_data2 = 7207.40
target.iloc[-1, 0] = new_data2
target.tail(5)
# Out:
#          BAJAJFIN
# 3748  6910.100098
# 3749  7022.750000
# 3750  7245.250000
# 3751  7250.950000
# 3752  7207.400000

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_features = scaler.fit_transform(features)
scaled_target = scaler.fit_transform(target.values.reshape(-1, 1))
target=target.dropna()

n_steps = 5 # Number of timesteps to look back
X, y = [], []

for i in range(n_steps, len(scaled_features)):
    X.append(scaled_features[i-n_steps:i])
    y.append(scaled_target[i])

X = np.array(X)
y = np.array(y)

split=int(0.8*len(X))
X_train, y_train= X[:split], y[:split]
X_test, y_test= X[split:], y[split:]

# %%
model_lstm = load_model('model_lstm_bajajfin2_0.9139.keras')
model_lstm.predict(X_test) 

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae_n=mean_absolute_error(y_test, predictions_lstm)
print(f"MAE_normalizeddata: {mae_n:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# R2: 0.9139
# MAPE: 0.0243
# RMSE: 218.5376
# RMSE_normalizeddata: 0.0268
# MAE_normalizeddata: 0.0198
# MAE: 161.9998

# %%
plt.figure(figsize=(9, 6))
plt.plot(y_test_actual_LSTM, color='green', label=['Actual Price'])
plt.plot(predictions_LSTM, color='red', label=['Predicted Price'])
plt.legend(['Actual Price', 'Predicted Price'], loc='upper left')

plt.text(0.75, 0.1, f'R2: {r2:.4f}\nMAPE: {mape:.4f}%\nRMSE: {rmse:.4f}\nMAE: {mae:.4f}', 
         fontsize=12, 
         bbox=dict(facecolor='white', alpha=0.5),
         transform=plt.gca().transAxes)

plt.grid(True)
plt.title('BAJAJFIN single model (2 step ahead)')
plt.xlabel('Time Step')
plt.ylabel('Actual vs Predicted Price')
plt.savefig('bajajfin_2sa-1l.png', dpi=600)  # Saves the plot as a PNG file
plt.show()

# %%
model_lstm.predict(X_train)

predictions_train_lstm = model_lstm.predict(X_train)
predictions_train_LSTM = scaler.inverse_transform(predictions_train_lstm)
y_train_actual_LSTM = scaler.inverse_transform(y_train.reshape(-1, 1))

r2=r2_score(y_train_actual_LSTM, predictions_train_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_train_actual_LSTM, predictions_train_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_train_actual_LSTM, predictions_train_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_train, predictions_train_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae_n=mean_absolute_error(y_train, predictions_train_lstm)
print(f"MAE_normalizeddata: {mae_n:.4f}")

mae=mean_absolute_error(y_train_actual_LSTM, predictions_train_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# R2: 0.9964
# MAPE: 0.1149
# RMSE: 83.6693
# RMSE_normalizeddata: 0.0102
# MAE_normalizeddata: 0.0050
# MAE: 40.5207

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(412, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.001), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=39, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

               
predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 38s 103ms/step - loss: 0.0094 - val_loss: 0.0017
# Epoch 2/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 2.0441e-04 - val_loss: 0.0014
# Epoch 3/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 1.7613e-04 - val_loss: 0.0011
# Epoch 4/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 1.8276e-04 - val_loss: 0.0013
# Epoch 5/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 1.8284e-04 - val_loss: 0.0013
# Epoch 6/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - loss: 1.5844e-04 - val_loss: 0.0013
# Epoch 7/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: 1.9605e-04 - val_loss: 0.0013
# Epoch 8/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 1.5216e-04 - val_loss: 0.0011
# Epoch 9/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 1.3491e-04 - val_loss: 0.0012
# Epoch 10/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 1.9743e-04 - val_loss: 0.0011
# Epoch 11/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 1.6913e-04 - val_loss: 0.0011
# Epoch 12/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 1.7354e-04 - val_loss: 0.0011
# Epoch 13/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 2.0648e-04 - val_loss: 0.0011
# Epoch 14/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: 1.4946e-04 - val_loss: 0.0018
# Epoch 15/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.6494e-04 - val_loss: 0.0014
# Epoch 16/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 1.4959e-04 - val_loss: 0.0011
# Epoch 17/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 1.7984e-04 - val_loss: 0.0011
# Epoch 18/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.3701e-04 - val_loss: 0.0010
# Epoch 19/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 1.4328e-04 - val_loss: 0.0028
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step
# R2: 0.6495
# MAPE: 0.0561
# RMSE: 440.8986
# RMSE_normalizeddata: 0.0540
# MAE: 377.0880

# %%
model_lstm.save('model_lstm_bajajfin2_1.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(412, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.001), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=39, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 77s 171ms/step - loss: 0.0109 - val_loss: 0.0011
# Epoch 2/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 14s 77ms/step - loss: 1.8174e-04 - val_loss: 0.0012
# Epoch 3/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 1.6207e-04 - val_loss: 0.0013
# Epoch 4/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 1.5235e-04 - val_loss: 0.0019
# Epoch 5/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - loss: 1.6542e-04 - val_loss: 0.0011
# Epoch 6/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 80ms/step - loss: 1.7030e-04 - val_loss: 0.0017
# Epoch 7/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 76ms/step - loss: 1.7255e-04 - val_loss: 0.0012
# Epoch 8/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 1.5564e-04 - val_loss: 0.0012
# Epoch 9/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - loss: 1.3272e-04 - val_loss: 0.0013
# Epoch 10/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - loss: 1.5945e-04 - val_loss: 0.0011
# Epoch 11/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 77ms/step - loss: 1.7597e-04 - val_loss: 0.0011
# Epoch 12/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - loss: 1.6333e-04 - val_loss: 0.0012
# Epoch 13/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - loss: 1.2787e-04 - val_loss: 0.0017
# Epoch 14/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 1.6846e-04 - val_loss: 0.0012
# Epoch 15/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 77ms/step - loss: 1.3928e-04 - val_loss: 0.0012
# Epoch 16/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 1.4199e-04 - val_loss: 0.0014
# Epoch 17/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - loss: 1.4277e-04 - val_loss: 0.0010
# Epoch 18/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 10s 80ms/step - loss: 1.4547e-04 - val_loss: 0.0012
# Epoch 19/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 1.2472e-04 - val_loss: 0.0010
# Epoch 20/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 69ms/step - loss: 1.5337e-04 - val_loss: 0.0012
# Epoch 21/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 1.3503e-04 - val_loss: 9.9926e-04
# Epoch 22/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - loss: 1.4830e-04 - val_loss: 9.2702e-04
# Epoch 23/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - loss: 1.2924e-04 - val_loss: 0.0011
# Epoch 24/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 74ms/step - loss: 1.4806e-04 - val_loss: 8.7921e-04
# Epoch 25/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: 1.1658e-04 - val_loss: 8.4689e-04
# Epoch 26/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step - loss: 1.0738e-04 - val_loss: 0.0012
# Epoch 27/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 1.3226e-04 - val_loss: 8.2845e-04
# Epoch 28/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 1.5501e-04 - val_loss: 0.0010
# Epoch 29/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 64ms/step - loss: 1.2118e-04 - val_loss: 0.0015
# Epoch 30/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 1.3662e-04 - val_loss: 0.0013
# Epoch 31/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - loss: 1.7044e-04 - val_loss: 9.1158e-04
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step
# R2: 0.8965
# MAPE: 0.0273
# RMSE: 239.6258
# RMSE_normalizeddata: 0.0294
# MAE: 183.3151

# %%
model_lstm.save('model_lstm_bajajfin2_2.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(412, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.001), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=39, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - loss: 0.0121 - val_loss: 0.0012
# Epoch 2/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.8243e-04 - val_loss: 0.0013
# Epoch 3/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 2.2067e-04 - val_loss: 0.0014
# Epoch 4/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 1.9801e-04 - val_loss: 0.0013
# Epoch 5/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 1.8105e-04 - val_loss: 0.0012
# Epoch 6/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.5361e-04 - val_loss: 0.0013
# Epoch 7/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 1.4284e-04 - val_loss: 0.0013
# Epoch 8/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 1.4817e-04 - val_loss: 0.0014
# Epoch 9/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 1.4947e-04 - val_loss: 0.0011
# Epoch 10/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 1.4800e-04 - val_loss: 0.0013
# Epoch 11/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 1.8103e-04 - val_loss: 0.0011
# Epoch 12/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 1.4892e-04 - val_loss: 0.0015
# Epoch 13/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 1.5459e-04 - val_loss: 0.0013
# Epoch 14/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 1.3161e-04 - val_loss: 0.0011
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step
# R2: 0.8769
# MAPE: 0.0296
# RMSE: 261.2792
# RMSE_normalizeddata: 0.0320
# MAE: 197.1773

# %%
model_lstm.save('model_lstm_bajajfin2_3.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(412, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.001), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=39, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 30s 106ms/step - loss: 0.0122 - val_loss: 0.0014
# Epoch 2/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 1.8184e-04 - val_loss: 0.0011
# Epoch 3/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 1.5379e-04 - val_loss: 0.0016
# Epoch 4/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 1.9060e-04 - val_loss: 0.0013
# Epoch 5/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 1.5318e-04 - val_loss: 0.0028
# Epoch 6/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: 1.6071e-04 - val_loss: 0.0012
# Epoch 7/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 1.9051e-04 - val_loss: 0.0015
# Epoch 8/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 1.7584e-04 - val_loss: 0.0030
# Epoch 9/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: 1.6904e-04 - val_loss: 0.0012
# Epoch 10/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - loss: 1.3172e-04 - val_loss: 0.0015
# Epoch 11/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 1.6736e-04 - val_loss: 0.0011
# Epoch 12/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 1.4332e-04 - val_loss: 0.0011
# Epoch 13/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 1.5145e-04 - val_loss: 0.0011
# Epoch 14/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 1.4698e-04 - val_loss: 0.0011
# Epoch 15/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - loss: 1.4285e-04 - val_loss: 0.0012
# Epoch 16/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - loss: 1.8437e-04 - val_loss: 0.0013
# Epoch 17/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 1.7475e-04 - val_loss: 0.0017
# Epoch 18/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - loss: 1.3481e-04 - val_loss: 0.0010
# Epoch 19/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 1.4221e-04 - val_loss: 0.0011
# Epoch 20/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 1.5216e-04 - val_loss: 0.0015
# Epoch 21/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 1.4955e-04 - val_loss: 0.0010
# Epoch 22/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - loss: 1.2071e-04 - val_loss: 0.0010
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step
# R2: 0.8855
# MAPE: 0.0288
# RMSE: 252.0276
# RMSE_normalizeddata: 0.0309
# MAE: 192.0176

# %%
model_lstm.save('model_lstm_bajajfin2_4.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(412, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.001), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=39, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 89ms/step - loss: 0.0144 - val_loss: 0.0014
# Epoch 2/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 1.7750e-04 - val_loss: 0.0016
# Epoch 3/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 1.5761e-04 - val_loss: 0.0014
# Epoch 4/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: 1.3679e-04 - val_loss: 0.0017
# Epoch 5/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 1.5057e-04 - val_loss: 0.0014
# Epoch 6/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 1.6730e-04 - val_loss: 0.0013
# Epoch 7/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: 1.5089e-04 - val_loss: 0.0015
# Epoch 8/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 1.6824e-04 - val_loss: 0.0015
# Epoch 9/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - loss: 1.6492e-04 - val_loss: 0.0012
# Epoch 10/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 1.7594e-04 - val_loss: 0.0012
# Epoch 11/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: 1.6646e-04 - val_loss: 0.0011
# Epoch 12/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 1.3388e-04 - val_loss: 0.0011
# Epoch 13/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 1.6705e-04 - val_loss: 0.0013
# Epoch 14/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 1.5693e-04 - val_loss: 0.0011
# Epoch 15/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 1.3750e-04 - val_loss: 0.0011
# Epoch 16/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 1.5366e-04 - val_loss: 0.0011
# Epoch 17/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 1.5515e-04 - val_loss: 0.0011
# Epoch 18/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 1.4750e-04 - val_loss: 0.0013
# Epoch 19/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 1.4283e-04 - val_loss: 0.0012
# Epoch 20/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 1.7608e-04 - val_loss: 0.0015
# Epoch 21/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 1.5261e-04 - val_loss: 0.0011
# Epoch 22/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 1.5979e-04 - val_loss: 0.0010
# Epoch 23/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 1.3847e-04 - val_loss: 9.9777e-04
# Epoch 24/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 1.5698e-04 - val_loss: 0.0011
# Epoch 25/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 1.1378e-04 - val_loss: 0.0023
# Epoch 26/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 1.5921e-04 - val_loss: 9.4771e-04
# Epoch 27/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 1.1978e-04 - val_loss: 0.0012
# Epoch 28/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - loss: 1.4273e-04 - val_loss: 0.0012
# Epoch 29/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 1.3232e-04 - val_loss: 8.8247e-04
# Epoch 30/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 1.4694e-04 - val_loss: 0.0013
# Epoch 31/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 1.1580e-04 - val_loss: 9.3586e-04
# Epoch 32/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 10s 59ms/step - loss: 1.2000e-04 - val_loss: 0.0012
# Epoch 33/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - loss: 1.2029e-04 - val_loss: 8.3521e-04
# Epoch 34/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - loss: 1.1973e-04 - val_loss: 0.0013
# Epoch 35/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - loss: 1.2799e-04 - val_loss: 0.0011
# Epoch 36/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - loss: 1.2125e-04 - val_loss: 8.6248e-04
# Epoch 37/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 1.0654e-04 - val_loss: 8.9123e-04
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step
# R2: 0.8988
# MAPE: 0.0269
# RMSE: 236.9460
# RMSE_normalizeddata: 0.0290
# MAE: 180.6188

# %%
model_lstm.save('model_lstm_bajajfin2_5.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(412, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.001), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=39, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 32s 75ms/step - loss: 0.0112 - val_loss: 0.0014
# Epoch 2/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 1.5410e-04 - val_loss: 0.0016
# Epoch 3/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 1.7081e-04 - val_loss: 0.0012
# Epoch 4/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 1.5672e-04 - val_loss: 0.0011
# Epoch 5/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 10s 61ms/step - loss: 1.8772e-04 - val_loss: 0.0019
# Epoch 6/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - loss: 1.9114e-04 - val_loss: 0.0015
# Epoch 7/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 1.3008e-04 - val_loss: 0.0012
# Epoch 8/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: 1.5786e-04 - val_loss: 0.0011
# Epoch 9/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 1.5379e-04 - val_loss: 0.0012
# Epoch 10/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 1.3755e-04 - val_loss: 0.0013
# Epoch 11/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 1.3546e-04 - val_loss: 0.0012
# Epoch 12/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - loss: 1.4001e-04 - val_loss: 0.0012
# Epoch 13/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 1.3482e-04 - val_loss: 0.0015
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step
# R2: 0.8179
# MAPE: 0.0372
# RMSE: 317.7953
# RMSE_normalizeddata: 0.0389
# MAE: 248.5600

# %%
model_lstm.save('model_lstm_bajajfin2_6.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(412, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.001), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=39, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])
predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 30s 84ms/step - loss: 0.0107 - val_loss: 0.0012
# Epoch 2/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 1.7964e-04 - val_loss: 0.0012
# Epoch 3/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - loss: 1.6104e-04 - val_loss: 0.0012
# Epoch 4/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: 1.4525e-04 - val_loss: 0.0012
# Epoch 5/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 1.7929e-04 - val_loss: 0.0012
# Epoch 6/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 1.7602e-04 - val_loss: 0.0014
# Epoch 7/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 1.8290e-04 - val_loss: 0.0021
# Epoch 8/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - loss: 2.0245e-04 - val_loss: 0.0013
# Epoch 9/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.9409e-04 - val_loss: 0.0017
# Epoch 10/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 1.6948e-04 - val_loss: 0.0013
# Epoch 11/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 1.8011e-04 - val_loss: 0.0012
# Epoch 12/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 1.5823e-04 - val_loss: 0.0013
# Epoch 13/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 1.5036e-04 - val_loss: 0.0016
# Epoch 14/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 1.3580e-04 - val_loss: 0.0028
# Epoch 15/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 1.6510e-04 - val_loss: 0.0011
# Epoch 16/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 1.8323e-04 - val_loss: 0.0011
# Epoch 17/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 1.7431e-04 - val_loss: 0.0012
# Epoch 18/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 1.5373e-04 - val_loss: 0.0015
# Epoch 19/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 1.4370e-04 - val_loss: 0.0011
# Epoch 20/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 1.4863e-04 - val_loss: 0.0011
# Epoch 21/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 1.7403e-04 - val_loss: 0.0010
# Epoch 22/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 1.3734e-04 - val_loss: 0.0012
# Epoch 23/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 1.1392e-04 - val_loss: 0.0020
# Epoch 24/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 1.7005e-04 - val_loss: 9.7653e-04
# Epoch 25/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.3576e-04 - val_loss: 0.0010
# Epoch 26/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 1.4459e-04 - val_loss: 0.0011
# Epoch 27/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 1.2164e-04 - val_loss: 9.3815e-04
# Epoch 28/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 1.2817e-04 - val_loss: 0.0011
# Epoch 29/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 1.2641e-04 - val_loss: 0.0010
# Epoch 30/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 1.2649e-04 - val_loss: 0.0011
# Epoch 31/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 1.2225e-04 - val_loss: 9.0512e-04
# Epoch 32/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 1.2802e-04 - val_loss: 9.9568e-04
# Epoch 33/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 1.1453e-04 - val_loss: 0.0011
# Epoch 34/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 1.3336e-04 - val_loss: 0.0010
# Epoch 35/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 1.1020e-04 - val_loss: 8.2842e-04
# Epoch 36/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: 1.3645e-04 - val_loss: 0.0012
# Epoch 37/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 1.3621e-04 - val_loss: 8.1157e-04
# Epoch 38/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 1.4362e-04 - val_loss: 8.0439e-04
# Epoch 39/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 1.1762e-04 - val_loss: 0.0018
# Epoch 40/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 1.0132e-04 - val_loss: 0.0013
# Epoch 41/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 1.2272e-04 - val_loss: 0.0011
# Epoch 42/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 1.7722e-04 - val_loss: 8.0825e-04
# Epoch 43/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 1.3507e-04 - val_loss: 0.0015
# Epoch 44/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 1.4019e-04 - val_loss: 7.6361e-04
# Epoch 45/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 1.2666e-04 - val_loss: 8.3451e-04
# Epoch 46/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 1.1037e-04 - val_loss: 7.4065e-04
# Epoch 47/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 1.0988e-04 - val_loss: 8.7890e-04
# Epoch 48/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 1.2604e-04 - val_loss: 7.1517e-04
# Epoch 49/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 1.2067e-04 - val_loss: 8.4737e-04
# Epoch 50/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 1.1263e-04 - val_loss: 7.2976e-04
# Epoch 51/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 1.0674e-04 - val_loss: 0.0012
# Epoch 52/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 1.1247e-04 - val_loss: 8.7871e-04
# Epoch 53/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 1.2408e-04 - val_loss: 7.1330e-04
# Epoch 54/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 1.2852e-04 - val_loss: 0.0012
# Epoch 55/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 1.0216e-04 - val_loss: 0.0016
# Epoch 56/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 1.1457e-04 - val_loss: 0.0013
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step
# R2: 0.8547
# MAPE: 0.0336
# RMSE: 283.9189
# RMSE_normalizeddata: 0.0348
# MAE: 228.5701

# %%
model_lstm.save('model_lstm_bajajfin2_7.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(412, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.001), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=39, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])
predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 26s 109ms/step - loss: 0.0132 - val_loss: 0.0013
# Epoch 2/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 2.0837e-04 - val_loss: 0.0017
# Epoch 3/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 1.4795e-04 - val_loss: 0.0014
# Epoch 4/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 1.8982e-04 - val_loss: 0.0013
# Epoch 5/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 1.6624e-04 - val_loss: 0.0012
# Epoch 6/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 1.5331e-04 - val_loss: 0.0012
# Epoch 7/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 1.5382e-04 - val_loss: 0.0015
# Epoch 8/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 1.5773e-04 - val_loss: 0.0012
# Epoch 9/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 1.7551e-04 - val_loss: 0.0012
# Epoch 10/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 1.5863e-04 - val_loss: 0.0012
# Epoch 11/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 1.7061e-04 - val_loss: 0.0011
# Epoch 12/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 1.4446e-04 - val_loss: 0.0012
# Epoch 13/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 1.6462e-04 - val_loss: 0.0015
# Epoch 14/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 1.2713e-04 - val_loss: 0.0012
# Epoch 15/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - loss: 1.4670e-04 - val_loss: 0.0012
# Epoch 16/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - loss: 1.3273e-04 - val_loss: 0.0014
# Epoch 17/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 1.5545e-04 - val_loss: 0.0014
# Epoch 18/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 1.1443e-04 - val_loss: 0.0011
# Epoch 19/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 1.6891e-04 - val_loss: 0.0011
# Epoch 20/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - loss: 1.7324e-04 - val_loss: 0.0012
# Epoch 21/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - loss: 1.5107e-04 - val_loss: 0.0012
# Epoch 22/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - loss: 1.3357e-04 - val_loss: 0.0010
# Epoch 23/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - loss: 1.5656e-04 - val_loss: 9.3425e-04
# Epoch 24/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - loss: 1.3569e-04 - val_loss: 0.0022
# Epoch 25/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 1.5148e-04 - val_loss: 9.1185e-04
# Epoch 26/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 1.5140e-04 - val_loss: 0.0013
# Epoch 27/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 1.1671e-04 - val_loss: 0.0036
# Epoch 28/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 1.5587e-04 - val_loss: 8.6389e-04
# Epoch 29/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 1.7336e-04 - val_loss: 0.0012
# Epoch 30/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 1.1701e-04 - val_loss: 0.0011
# Epoch 31/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 1.2665e-04 - val_loss: 8.1606e-04
# Epoch 32/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.2869e-04 - val_loss: 9.3044e-04
# Epoch 33/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 1.2562e-04 - val_loss: 9.0233e-04
# Epoch 34/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 1.1919e-04 - val_loss: 9.5608e-04
# Epoch 35/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 1.1930e-04 - val_loss: 0.0011
# Epoch 36/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - loss: 1.1617e-04 - val_loss: 9.8105e-04
# Epoch 37/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 1.2002e-04 - val_loss: 7.4914e-04
# Epoch 38/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: 1.2401e-04 - val_loss: 0.0021
# Epoch 39/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - loss: 1.4473e-04 - val_loss: 7.8943e-04
# Epoch 40/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 1.0986e-04 - val_loss: 0.0010
# Epoch 41/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 1.3738e-04 - val_loss: 7.3112e-04
# Epoch 42/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 7s 63ms/step - loss: 1.2278e-04 - val_loss: 0.0011
# Epoch 43/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 1.2879e-04 - val_loss: 0.0011
# Epoch 44/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: 1.0585e-04 - val_loss: 7.2597e-04
# Epoch 45/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 9.8085e-05 - val_loss: 7.4310e-04
# Epoch 46/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 1.1843e-04 - val_loss: 7.4901e-04
# Epoch 47/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 1.0110e-04 - val_loss: 0.0041
# Epoch 48/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 1.3584e-04 - val_loss: 9.2139e-04
# Epoch 49/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 1.0861e-04 - val_loss: 0.0011
# Epoch 50/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 1.3436e-04 - val_loss: 7.1144e-04
# Epoch 51/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 1.0390e-04 - val_loss: 0.0020
# Epoch 52/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 1.1619e-04 - val_loss: 8.6635e-04
# Epoch 53/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 9.4937e-05 - val_loss: 0.0015
# Epoch 54/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 1.1588e-04 - val_loss: 0.0021
# Epoch 55/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 9.7100e-05 - val_loss: 7.2051e-04
# Epoch 56/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 1.0092e-04 - val_loss: 8.0423e-04
# Epoch 57/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 1.0782e-04 - val_loss: 0.0018
# Epoch 58/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 1.1271e-04 - val_loss: 0.0016
# Epoch 59/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 9.3508e-05 - val_loss: 0.0013
# Epoch 60/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 1.2258e-04 - val_loss: 9.7379e-04
# Epoch 61/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 1.1341e-04 - val_loss: 0.0011
# Epoch 62/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - loss: 1.2061e-04 - val_loss: 0.0011
# Epoch 63/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 1.0878e-04 - val_loss: 0.0012
# Epoch 64/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 1.0002e-04 - val_loss: 0.0014
# Epoch 65/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 1.0214e-04 - val_loss: 9.5330e-04
# Epoch 66/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 9.2288e-05 - val_loss: 0.0016
# Epoch 67/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 1.0341e-04 - val_loss: 9.3018e-04
# Epoch 68/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: 1.0365e-04 - val_loss: 8.5741e-04
# Epoch 69/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - loss: 9.6547e-05 - val_loss: 0.0011
# Epoch 70/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 1.0440e-04 - val_loss: 0.0012
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step
# R2: 0.8661
# MAPE: 0.0315
# RMSE: 272.5159
# RMSE_normalizeddata: 0.0334
# MAE: 215.4053

# %%
model_lstm.save('model_lstm_bajajfin2_8.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(412, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.001), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=39, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 38s 116ms/step - loss: 0.0137 - val_loss: 0.0038
# Epoch 2/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - loss: 1.6304e-04 - val_loss: 0.0013
# Epoch 3/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - loss: 1.7240e-04 - val_loss: 0.0012
# Epoch 4/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 1.5755e-04 - val_loss: 0.0014
# Epoch 5/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 1.6284e-04 - val_loss: 0.0016
# Epoch 6/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 1.5824e-04 - val_loss: 0.0021
# Epoch 7/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - loss: 1.8289e-04 - val_loss: 0.0011
# Epoch 8/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 1.5229e-04 - val_loss: 0.0022
# Epoch 9/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: 1.6895e-04 - val_loss: 0.0017
# Epoch 10/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 1.7169e-04 - val_loss: 0.0016
# Epoch 11/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 1.3723e-04 - val_loss: 0.0011
# Epoch 12/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 1.6090e-04 - val_loss: 0.0023
# Epoch 13/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - loss: 1.5982e-04 - val_loss: 0.0013
# Epoch 14/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 10s 62ms/step - loss: 1.4668e-04 - val_loss: 0.0016
# Epoch 15/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 1.4838e-04 - val_loss: 0.0015
# Epoch 16/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 77ms/step - loss: 1.4048e-04 - val_loss: 0.0012
# Epoch 17/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - loss: 1.6801e-04 - val_loss: 0.0011
# Epoch 18/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - loss: 1.2826e-04 - val_loss: 0.0011
# Epoch 19/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - loss: 1.5895e-04 - val_loss: 0.0013
# Epoch 20/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 75ms/step - loss: 1.2272e-04 - val_loss: 0.0010
# Epoch 21/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - loss: 1.3533e-04 - val_loss: 0.0015
# Epoch 22/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 1.5340e-04 - val_loss: 9.7745e-04
# Epoch 23/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.2969e-04 - val_loss: 9.7692e-04
# Epoch 24/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 1.6891e-04 - val_loss: 0.0013
# Epoch 25/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 1.3390e-04 - val_loss: 9.3462e-04
# Epoch 26/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 1.3922e-04 - val_loss: 0.0010
# Epoch 27/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 1.4215e-04 - val_loss: 9.3574e-04
# Epoch 28/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 1.3417e-04 - val_loss: 9.1059e-04
# Epoch 29/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 1.3553e-04 - val_loss: 8.6427e-04
# Epoch 30/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 1.2023e-04 - val_loss: 0.0021
# Epoch 31/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 1.5470e-04 - val_loss: 0.0017
# Epoch 32/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 1.4042e-04 - val_loss: 8.3185e-04
# Epoch 33/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: 1.4068e-04 - val_loss: 8.1763e-04
# Epoch 34/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 7s 76ms/step - loss: 1.0449e-04 - val_loss: 0.0017
# Epoch 35/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 1.3932e-04 - val_loss: 7.9240e-04
# Epoch 36/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 7s 82ms/step - loss: 1.1712e-04 - val_loss: 0.0012
# Epoch 37/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - loss: 1.2627e-04 - val_loss: 7.9037e-04
# Epoch 38/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 1.0606e-04 - val_loss: 0.0012
# Epoch 39/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 1.1924e-04 - val_loss: 7.4394e-04
# Epoch 40/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step - loss: 1.3320e-04 - val_loss: 0.0013
# Epoch 41/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: 1.4287e-04 - val_loss: 7.9662e-04
# Epoch 42/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - loss: 1.2434e-04 - val_loss: 7.9850e-04
# Epoch 43/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 77ms/step - loss: 1.2260e-04 - val_loss: 7.6954e-04
# Epoch 44/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 1.1206e-04 - val_loss: 0.0020
# Epoch 45/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - loss: 1.0389e-04 - val_loss: 0.0018
# Epoch 46/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 79ms/step - loss: 1.3374e-04 - val_loss: 0.0014
# Epoch 47/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 9s 59ms/step - loss: 1.3296e-04 - val_loss: 0.0016
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 210ms/step
# R2: 0.8153
# MAPE: 0.0388
# RMSE: 320.0757
# RMSE_normalizeddata: 0.0392
# MAE: 265.1356

# %%
model_lstm.save('model_lstm_bajajfin2_9.keras')

# %%
model_lstm = tf.keras.Sequential()
model_lstm.add(tf.keras.layers.LSTM(412, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.compile(optimizer=Nadam(learning_rate=0.001), loss='mse')
model_lstm.fit(X_train, y_train, epochs=200, batch_size=39, validation_data=(X_test, y_test), callbacks=[EarlyStopping(monitor='loss', patience=5)])

predictions_lstm = model_lstm.predict(X_test)
predictions_LSTM = scaler.inverse_transform(predictions_lstm)
y_test_actual_LSTM = scaler.inverse_transform(y_test.reshape(-1, 1))

r2=r2_score(y_test_actual_LSTM, predictions_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_test_actual_LSTM, predictions_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_test, predictions_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae=mean_absolute_error(y_test_actual_LSTM, predictions_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# Epoch 1/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 33s 100ms/step - loss: 0.0127 - val_loss: 0.0013
# Epoch 2/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 8s 67ms/step - loss: 1.7705e-04 - val_loss: 0.0016
# Epoch 3/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: 1.8171e-04 - val_loss: 0.0012
# Epoch 4/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - loss: 1.6123e-04 - val_loss: 0.0012
# Epoch 5/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - loss: 1.8336e-04 - val_loss: 0.0014
# Epoch 6/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 1.8005e-04 - val_loss: 0.0011
# Epoch 7/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 1.2824e-04 - val_loss: 0.0012
# Epoch 8/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: 1.8312e-04 - val_loss: 0.0011
# Epoch 9/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 1.3119e-04 - val_loss: 0.0016
# Epoch 10/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 1.3746e-04 - val_loss: 0.0013
# Epoch 11/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 1.4379e-04 - val_loss: 0.0011
# Epoch 12/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 1.4817e-04 - val_loss: 0.0017
# Epoch 13/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 1.4907e-04 - val_loss: 0.0011
# Epoch 14/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - loss: 1.5800e-04 - val_loss: 0.0012
# Epoch 15/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 1.5085e-04 - val_loss: 0.0021
# Epoch 16/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 1.5767e-04 - val_loss: 0.0010
# Epoch 17/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 1.7509e-04 - val_loss: 0.0011
# Epoch 18/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 1.5868e-04 - val_loss: 0.0010
# Epoch 19/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 1.5157e-04 - val_loss: 0.0013
# Epoch 20/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 1.4900e-04 - val_loss: 0.0015
# Epoch 21/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - loss: 1.3831e-04 - val_loss: 9.5869e-04
# Epoch 22/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 1.2682e-04 - val_loss: 0.0011
# Epoch 23/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 1.4672e-04 - val_loss: 0.0014
# Epoch 24/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 1.2710e-04 - val_loss: 0.0012
# Epoch 25/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 12s 87ms/step - loss: 1.4127e-04 - val_loss: 0.0020
# Epoch 26/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 8s 62ms/step - loss: 1.4875e-04 - val_loss: 8.4539e-04
# Epoch 27/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - loss: 1.3717e-04 - val_loss: 9.1403e-04
# Epoch 28/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - loss: 1.1717e-04 - val_loss: 8.2002e-04
# Epoch 29/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 1.2661e-04 - val_loss: 0.0011
# Epoch 30/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 79ms/step - loss: 1.2187e-04 - val_loss: 8.0810e-04
# Epoch 31/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 82ms/step - loss: 1.3296e-04 - val_loss: 0.0014
# Epoch 32/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - loss: 1.2043e-04 - val_loss: 0.0027
# Epoch 33/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 9s 63ms/step - loss: 1.2355e-04 - val_loss: 8.1391e-04
# Epoch 34/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step - loss: 1.1033e-04 - val_loss: 7.7578e-04
# Epoch 35/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - loss: 1.0827e-04 - val_loss: 9.8134e-04
# Epoch 36/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 1.1304e-04 - val_loss: 7.6478e-04
# Epoch 37/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - loss: 1.0699e-04 - val_loss: 0.0015
# Epoch 38/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 9s 52ms/step - loss: 1.1184e-04 - val_loss: 0.0015
# Epoch 39/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 9.7157e-05 - val_loss: 8.1940e-04
# Epoch 40/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 1.3861e-04 - val_loss: 9.4645e-04
# Epoch 41/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 1.2159e-04 - val_loss: 8.0049e-04
# Epoch 42/200
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 1.2330e-04 - val_loss: 7.4224e-04
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 135ms/step
# R2: 0.9139
# MAPE: 0.0243
# RMSE: 218.5376
# RMSE_normalizeddata: 0.0268
# MAE: 161.9998

# %%
predictions_train_lstm = model_lstm.predict(X_train)
predictions_train_LSTM = scaler.inverse_transform(predictions_train_lstm)
y_train_actual_LSTM = scaler.inverse_transform(y_train.reshape(-1, 1))

r2=r2_score(y_train_actual_LSTM, predictions_train_LSTM)
print(f"R2: {r2:.4f}")

mape=mean_absolute_percentage_error(y_train_actual_LSTM, predictions_train_LSTM)
print(f"MAPE: {mape:.4f}")

mse=mean_squared_error(y_train_actual_LSTM, predictions_train_LSTM)
rmse=np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

mse_normalizeddata=mean_squared_error(y_train, predictions_train_lstm)
rmse_normalizeddata=np.sqrt(mse_normalizeddata)
print(f"RMSE_normalizeddata: {rmse_normalizeddata:.4f}")

mae_n=mean_absolute_error(y_train, predictions_train_lstm)
print(f"MAE_normalizeddata: {mae_n:.4f}")

mae=mean_absolute_error(y_train_actual_LSTM, predictions_train_LSTM)
print(f"MAE: {mae:.4f}")
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# R2: 0.9964
# MAPE: 0.1149
# RMSE: 83.6693
# RMSE_normalizeddata: 0.0102
# MAE_normalizeddata: 0.0050
# MAE: 40.5207

# %%
model_lstm.save('model_lstm_bajajfin2_10.keras')
